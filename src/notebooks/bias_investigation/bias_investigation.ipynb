# %%
import anndata as ad
import scanpy as sc
from tqdm import tqdm
import pickle as pkl

# %%
adata_pp = ad.read_h5ad("../../../data/sciplex_qc_ann.h5ad")

# %%
adata_pp
# Out:
# AnnData object with n_obs × n_vars = 401917 × 27544
#     obs: 'cell_type', 'dose', 'dose_character', 'dose_pattern', 'g1s_score', 'g2m_score', 'pathway', 'pathway_level_1', 'pathway_level_2', 'product_dose', 'product_name', 'proliferation_index', 'replicate', 'size_factor', 'target', 'vehicle', 'SMILES', 'fmfp', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'outlier', 'mt_outlier', 'drug_celltype_dose', 'match_index'
#     var: 'id', 'num_cells_expressed-0-0', 'num_cells_expressed-1-0', 'num_cells_expressed-1', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells'

# %% [markdown]
# ## All DEGS

# %%
def calculate_degs(adata_pp, method='wilcoxon'):
    adata = adata_pp.copy()
    sc.pp.filter_genes(adata, min_cells = 10)
    sc.pp.normalize_total(adata, inplace=True)
    sc.pp.log1p(adata)
    adata.obs['drug_celltype_dose'] = adata.obs['cell_type'].astype(str) + "_" + adata.obs['product_name'].astype(
        str) + "_" + adata.obs['dose'].astype(str)

    results = dict()

    for condition in tqdm(adata.obs.drug_celltype_dose.unique()):
        adata_cond = adata[adata.obs.drug_celltype_dose == condition].copy()
        if adata_cond.n_obs == 0:
            continue

        if list(adata_cond.obs.product_name.unique())[0] == "Vehicle":
            continue

        adata_ref = adata[adata.obs.cell_type == list(adata_cond.obs.cell_type.unique())[0]].copy()
        adata_ref = adata_ref[adata_ref.obs.product_name == "Vehicle"]
        ref_cond = list(adata_ref.obs.drug_celltype_dose.unique())[0]
        
        adata_comb = ad.concat([adata_ref, adata_cond])

        sc.tl.rank_genes_groups(adata_comb, groupby='drug_celltype_dose', reference=ref_cond, method=method)
        df = sc.get.rank_genes_groups_df(adata_comb, group=condition, pval_cutoff = 0.05)

        df['abs_logfc'] = abs(df['logfoldchanges'])
        df = df[df['abs_logfc'] >= 0.1]

        results[condition] = list(df['names'])

        del adata_cond
        del adata_ref
        del adata_comb
        
    return results

# %%
all_degs = calculate_degs(adata_pp)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2218/2218 [20:32<00:00,  1.80it/s]

# %%
all_degs
# Out:
# {'A549_Enzastaurin (LY317615)_1000.0': ['MT-CO1'],
#  'A549_Raltitrexed_10.0': [],
#  'A549_Lenalidomide (CC-5013)_10.0': [],
#  'A549_Divalproex Sodium_1000.0': [],
#  'A549_MLN8054_100.0': ['MDM2',
#   'PAPPA',
#   'MT-CO3',
#   'NEAT1',
#   'MT-ATP6',
#   'NFAT5',
#   'ALDH3A1',
#   'LINC01021',
#   'ITGB5',
#   'MKI67'],
#  'A549_Sodium Phenylbutyrate_1000.0': [],
#  'A549_Celecoxib_100.0': [],
#  'A549_Linifanib (ABT-869)_100.0': [],
#  'A549_Thalidomide_1000.0': ['GAPDH'],
#  'A549_Linifanib (ABT-869)_10000.0': ['KRT8',
#   'KRT18',
#   'PRRC2C',
#   'RNF213',
#   'ALDH3A1',
#   'CYP24A1',
#   'ABCC2',
#   'NQO1',
#   'NEAT1',
#   'ABCC3'],
#  'A549_(+)-JQ1_10.0': [],
#  'A549_S3I-201_10.0': [],
#  'A549_PF-573228_10.0': [],
#  'A549_CEP-33779_1000.0': [],
#  'A549_Resminostat_1000.0': ['MALAT1',
#   'MT-ND5',
#   'MT-CO3',
#   'MT-CO1',
#   'MT-CYB',
#   'MT-ND4',
#   'MT-ATP6',
#   'CAST',
#   'KRT8',
#   'SCD',
#   'MT-ND2',
#   'RAB10'],
#  'A549_Tie2 kinase inhibitor_1000.0': [],
#  'A549_Nintedanib (BIBF 1120)_100.0': [],
#  'A549_SRT3025 HCl_10.0': [],
#  'A549_Avagacestat (BMS-708163)_100.0': [],
#  'A549_Quisinostat (JNJ-26481585) 2HCl_10.0': ['MALAT1',
#   'COL26A1',
#   'AC010197.1',
#   'CEACAM22P',
#   'AC008050.1',
#   'PARP16',
#   'ACSBG1',
#   'CRIM1',
#   'NEAT1',
#   'ACSL3',
#   'PTEN',
#   'CLU',
#   'PSAP',
#   'USP9X',
#   'MALAT1-1',
#   'STAT3',
#   'DNAJC1',
#   'CBLB',
#   'TNFRSF10B',
#   'GPRC5A',
#   'KMT2C',
#   'MACROD2',
#   'UBR3',
#   'RPL3L',
#   'SPAG9',
#   'PCYOX1',
#   'MT-ND5',
#   'RORA',
#   'SQSTM1',
#   'TFPI2',
#   'EXOC6B',
#   'AKAP13',
#   'AC008014.1',
#   'SYT1',
#   'SMYD3',
#   'CALR',
#   'TAOK3',
#   'LINC02506',
#   'CD81',
#   'AP000769.1',
#   'LINC00624',
#   'NPC1',
#   'DNM3',
#   'RGL1',
#   'TMTC2',
#   'ZSWIM6',
#   'KDM5B',
#   'EXT1',
#   'ZFP90',
#   'AC008250.1',
#   'FBXL20',
#   'VCL',
#   'PPM1E',
#   'TXNRD1',
#   'RALGAPA2',
#   'SLC2A3',
#   'LIMA1',
#   'ATP6V0A1',
#   'MT-CO1',
#   'UBE2H',
#   'DHRS2',
#   'ATP6V1A',
#   'PLD3',
#   'RTN3',
#   'GMCL1',
#   'EML6',
#   'IGFL2-AS1',
#   'CPM',
#   'HERC4',
#   'EXTL3',
#   'MT-CO3',
#   'AREG',
#   'HERC1',
#   'ADAMTSL4-AS1',
#   'MORF4L1',
#   'LRBA',
#   'SEL1L',
#   'CDC14B',
#   'TYW1B',
#   'DCBLD2',
#   'VMP1',
#   'APLP2',
#   'NR6A1',
#   'DAAM1',
#   'AC011476.3',
#   'SREBF1',
#   'SAT1',
#   'TIMP2',
#   'USP25',
#   'RB1CC1',
#   'SSBP2',
#   'ITPR2',
#   'CCNYL1',
#   'ABTB2',
#   'P4HB',
#   'TMEM135',
#   'MICU1',
#   'AC097478.1',
#   'NCEH1',
#   'RERE',
#   'FRYL',
#   'TEX14',
#   'MT-ND4',
#   'LINC01511',
#   'CCDC88A',
#   'MARCH6',
#   'ZKSCAN1',
#   'AL356804.1',
#   'CEACAM20',
#   'SNX29',
#   'FBXL2',
#   'GOLGA4',
#   'PPP3CA',
#   'TOM1L2',
#   'PEAK1',
#   'AGTPBP1',
#   'IQCH',
#   'HEATR5A',
#   'PEG10',
#   'SORBS1',
#   'SERPINE1',
#   'TASP1',
#   'TMEM241',
#   'OTUD7A',
#   'LINC02204',
#   'OSBPL8',
#   'MAP2',
#   'TMEM41B',
#   'BSG',
#   'GLS',
#   'RAB11FIP1',
#   'IDI1',
#   'CALN1',
#   'SERTAD2',
#   'MAGT1',
#   'MLF1',
#   'INSIG1',
#   'AC138819.1',
#   'MAGI1',
#   'PCLO',
#   'DOCK4',
#   'AC002066.1',
#   'ATP6V1D',
#   'UBE2B',
#   'CAVIN1',
#   'TOR1AIP2',
#   'SLC9A3R1',
#   'AC008736.1',
#   'CLPTM1',
#   'FAM126B',
#   'FRMD5',
#   'LUCAT1',
#   'RABGAP1L',
#   'GDE1',
#   'TXNIP',
#   'TANC2',
#   'WASHC4',
#   'PIP5K1A',
#   'DNAH12',
#   'TMPRSS9',
#   'NSMCE2',
#   'CTGF',
#   'MLEC',
#   'HIP1',
#   'LPIN1',
#   'GOLGB1',
#   'AMN1',
#   'MT-CYB',
#   'ZER1',
#   'MLLT3',
#   'FAM189A1',
#   'LAMP2',
#   'GBF1',
#   'SPIDR',
#   'TEAD1',
#   'FLNA',
#   'USP49',
#   'BTAF1',
#   'MAPT',
#   'CHKA',
#   'SIRT2',
#   'RIOK3',
#   'HLTF',
#   'DNAH3',
#   'KIF1B',
#   'KTN1',
#   'ANKRD27',
#   'VPS53',
#   'H3F3B',
#   'RNF216',
#   'GRB2',
#   'KLHL29',
#   'MLPH',
#   'GTF2I',
#   'JMJD1C',
#   'NSD1',
#   'GRAMD1B',
#   'FAM107B',
#   'PON2',
#   'PARD3',
#   'ME1',
#   'PDE3A',
#   'EGLN1',
#   'EPB41L1',
#   'CTBP2',
#   'ZBTB38',
#   'TOP2A',
#   'CUEDC1',
#   'RBFOX3',
#   'ATE1',
#   'TPM4',
#   'TMOD3',
#   'PTGR1',
#   'MIR31HG',
#   'PATJ',
#   'CACNA1D',
#   'DHRS3',
#   'CENPF',
#   'AC016205.1',
#   'SLC3A2',
#   'NUCKS1',
#   'RBPMS',
#   'SHANK2',
#   'ST6GAL2',
#   'MKI67',
#   'RAB10',
#   'PAPPA',
#   'KPNB1',
#   'NPAS2',
#   'NFIC',
#   'TUBB',
#   'TM4SF1',
#   'TBC1D8',
#   'PDE8A',
#   'GLIS3',
#   'AGR2',
#   'EFNA5',
#   'IGF2BP1',
#   'ASPH',
#   'CACNA2D1',
#   'PDLIM5',
#   'ENO1',
#   'BMPR1B',
#   'C9orf3',
#   'PTPRJ',
#   'NRCAM',
#   'MID1',
#   'NFIA',
#   'ABCC1',
#   'CPLX2',
#   'CNTNAP3B',
#   'NQO1',
#   'ANXA4',
#   'PDE10A',
#   'KRT8',
#   'MYOF',
#   'CD44',
#   'CCND1',
#   'MAP7',
#   'SIPA1L3',
#   'SLC12A2',
#   'HNF1A-AS1',
#   'IGFBP4',
#   'LPP',
#   'MAML3',
#   'PTPRM',
#   'KRT7',
#   'MGST1',
#   'PVT1',
#   'NRP1',
#   'SLC7A5',
#   'CSGALNACT1',
#   'DOCK5',
#   'THSD7A',
#   'LINC00511',
#   'SLC7A11',
#   'PDE4B',
#   'ALDH3A1',
#   'AKR1C1',
#   'GAPDH',
#   'KRT81',
#   'PGD',
#   'GPX2',
#   'TNS3',
#   'KRT18',
#   'CUX1',
#   'CYP24A1',
#   'EHBP1',
#   'MTUS1',
#   'AKR1C2',
#   'THSD4',
#   'KYNU',
#   'AKR1C3',
#   'PDE4D',
#   'CA12',
#   'ABCC2',
#   'ALDH1A1',
#   'ABCC3',
#   'AKR1B10'],
#  'A549_MC1568_100.0': [],
#  'A549_Temsirolimus (CCI-779, NSC 683864)_100.0': ['MT-ND1',
#   'MT-ND5',
#   'MT-CO1'],
#  'A549_IOX2_10000.0': [],
#  'A549_Bosutinib (SKI-606)_100.0': [],
#  'A549_Regorafenib (BAY 73-4506)_100.0': [],
#  'A549_Sodium Phenylbutyrate_10.0': [],
#  'A549_Aurora A Inhibitor I_1000.0': [],
#  'A549_ENMD-2076_1000.0': ['MALAT1', 'NEAT1', 'MDM2'],
#  'A549_Curcumin_10000.0': [],
#  'A549_Crizotinib (PF-02341066)_1000.0': ['NEAT1', 'MALAT1', 'MDM2'],
#  'A549_Panobinostat (LBH589)_1000.0': ['MALAT1',
#   'COL26A1',
#   'AC010197.1',
#   'ACSL3',
#   'INSIG1',
#   'CEACAM22P',
#   'ACSBG1',
#   'UBR3',
#   'AC139491.2',
#   'PARP16',
#   'NPC1',
#   'HMGCS1',
#   'AC008050.1',
#   'SREBF1',
#   'RPL3L',
#   'LINC02506',
#   'MORF4L1',
#   'TNFRSF10B',
#   'LINC02204',
#   'SPAG9',
#   'HMGCR',
#   'TMEM135',
#   'SQSTM1',
#   'NEAT1',
#   'RGL1',
#   'MARCH6',
#   'STAT3',
#   'AC008250.1',
#   'MACROD2',
#   'ACLY',
#   'FASN',
#   'IDI1',
#   'AC138819.1',
#   'MALAT1-1',
#   'AREG',
#   'PHF14',
#   'LPIN1',
#   'PEG10',
#   'CLU',
#   'DNAJC1',
#   'AC068152.1',
#   'LDLR',
#   'FDFT1',
#   'LINC00540',
#   'TYW1B',
#   'LINC00624',
#   'SMYD3',
#   'CTGF',
#   'ZSWIM6',
#   'AC011476.3',
#   'SERPINE1',
#   'RALGAPA2',
#   'GRB2',
#   'CD81',
#   'PSAP',
#   'DHRS2',
#   'LINC02328',
#   'AP000769.1',
#   'TEX14',
#   'SAT1',
#   'TOM1L2',
#   'MT-ND5',
#   'NME7',
#   'ACACA',
#   'KNTC1',
#   'AC139493.2',
#   'ZFP90',
#   'P4HB',
#   'CGREF1',
#   'TMEM41B',
#   'PLD3',
#   'EXT1',
#   'SCD',
#   'PCYOX1',
#   'ADAMTSL4-AS1',
#   'USP9X',
#   'CYP4F2',
#   'DNAH3',
#   'AC097478.1',
#   'APLP2',
#   'DNM3',
#   'RB1CC1',
#   'FBXL20',
#   'SETX',
#   'AC008014.1',
#   'SYAP1',
#   'ODC1',
#   'RPS5',
#   'HIP1',
#   'KLHL13',
#   'STAT1',
#   'SLC9A3R1',
#   'FRMD5',
#   'KIDINS220',
#   'KATNBL1',
#   'TAOK3',
#   'FADS1',
#   'ACSS2',
#   'FOXK2',
#   'ARMC9',
#   'ZKSCAN1',
#   'ACTG1',
#   'ZER1',
#   'CEACAM20',
#   'TOR1AIP2',
#   'TMTC2',
#   'ADIPOR2',
#   'TFPI2',
#   'PIKFYVE',
#   'AC092100.1',
#   'IQCH',
#   'LIMA1',
#   'VPS53',
#   'KMT2C',
#   'EXOC6B',
#   'MT-ND4',
#   'SSBP2',
#   'DAAM1',
#   'LMBR1',
#   'JPT1',
#   'DNAH12',
#   'LINC01511',
#   'NEU1',
#   'SUFU',
#   'NR1H4',
#   'LPCAT3',
#   'ABTB2',
#   'DHCR7',
#   'KCNAB1',
#   'SERPINB9',
#   'R3HCC1',
#   'PKM',
#   'HSP90AA1',
#   'NOSIP',
#   'TRAPPC9',
#   'RORA',
#   'RERE',
#   'CCNYL1',
#   'TASP1',
#   'SQLE',
#   'CCSER2',
#   'VCL',
#   'GBF1',
#   'PPM1E',
#   'CCDC88A',
#   'ALDOC',
#   'ATG4B',
#   'WSCD1',
#   'SORBS1',
#   'ACSL4',
#   'GMCL1',
#   'PEAK1',
#   'HIST1H2AC',
#   'ITPR2',
#   'AC093001.1',
#   'ZNF815P',
#   'HCG27',
#   'DPM1',
#   'ATP6V1D',
#   'CLEC16A',
#   'CPM',
#   'SKAP2',
#   'CALR',
#   'WDR37',
#   'HERC1',
#   'RPL18',
#   'TTC37',
#   'RPL28',
#   'NUCKS1',
#   'ANXA2',
#   'RPH3AL',
#   'DLEU2',
#   'ARID1B',
#   'BICC1',
#   'SPATS2',
#   'IGF1R',
#   'TOP2A',
#   'CACNA1D',
#   'SHANK2',
#   'GRAMD1B',
#   'KIF21A',
#   'ST6GAL2',
#   'ZBTB38',
#   'TTC28',
#   'ENO1',
#   'GCLM',
#   'EPB41L1',
#   'CAMK2D',
#   'NRG1',
#   'DST',
#   'MAP3K20',
#   'PDE8A',
#   'TMOD3',
#   'MSI2',
#   'RBFOX3',
#   'PLCH1',
#   'GPC6',
#   'HNRNPUL1',
#   'ATP2A2',
#   'FTL',
#   'RBPMS',
#   'PAPPA',
#   'MED13L',
#   'AC016205.1',
#   'PATJ',
#   'NF1',
#   'SLC35F3',
#   'CENPF',
#   'PCDH9',
#   'WWTR1',
#   'SLC3A2',
#   'SIPA1L3',
#   'MYO1E',
#   'LPGAT1',
#   'IGF2BP1',
#   'EGLN1',
#   'ZFHX3',
#   'TM4SF1',
#   'CUEDC1',
#   'ABCC4',
#   'CDC42BPA',
#   'TUBB',
#   'KPNB1',
#   'ZBTB20',
#   'JMJD1C',
#   'FTX',
#   'NFIC',
#   'AGR2',
#   'KANSL1',
#   'CPLX2',
#   'DENND5B',
#   'SPTBN1',
#   'LGR4',
#   'HNF1A-AS1',
#   'MIR31HG',
#   'CD44',
#   'MYO10',
#   'IGF2BP3',
#   'ME1',
#   'MKI67',
#   'LINC-PINT',
#   'LIMCH1',
#   'CACNA2D1',
#   'KRT8',
#   'CCND1',
#   'TPM4',
#   'IGFBP4',
#   'PGD',
#   'NPAS2',
#   'UGDH',
#   'BMPR1B',
#   'PRKCA',
#   'CNTNAP3B',
#   'RBM47',
#   'RAB10',
#   'PTPRJ',
#   'MYOF',
#   'TBC1D8',
#   'EFNA5',
#   'KRT7',
#   'MGST1',
#   'NQO1',
#   'GLIS3',
#   'PTGR1',
#   'SMAD3',
#   'CNTN1',
#   'ALDH3A1',
#   'PDE3A',
#   'PDLIM5',
#   'MID1',
#   'NRP1',
#   'PARD3',
#   'NRCAM',
#   'ABCC1',
#   'SLC7A5',
#   'LPP',
#   'AKR1C1',
#   'CSGALNACT1',
#   'LINC00511',
#   'NFIA',
#   'PTPRM',
#   'SLC12A2',
#   'MAP7',
#   'ANXA4',
#   'PDE10A',
#   'ASPH',
#   'GPX2',
#   'C9orf3',
#   'THSD7A',
#   'PDE4B',
#   'DOCK5',
#   'TNS3',
#   'KRT81',
#   'PVT1',
#   'MAML3',
#   'KRT18',
#   'THSD4',
#   'CUX1',
#   'AKR1C2',
#   'SLC7A11',
#   'CYP24A1',
#   'MTUS1',
#   'EHBP1',
#   'CA12',
#   'AKR1C3',
#   'KYNU',
#   'ABCC2',
#   'ALDH1A1',
#   'ABCC3',
#   'AKR1B10',
#   'PDE4D'],
#  'A549_Alvespimycin (17-DMAG) HCl_10.0': [],
#  'A549_Sorafenib Tosylate_1000.0': ['MT-CO1', 'MT-ND5'],
#  'A549_Maraviroc_10000.0': [],
#  'A549_Mesna _1000.0': ['MT-CO3', 'MT-ND5', 'MT-RNR2', 'MT-CO1'],
#  'A549_Fedratinib (SAR302503, TG101348)_1000.0': [],
#  'A549_Trametinib (GSK1120212)_1000.0': ['MALAT1',
#   'NEAT1',
#   'SYNE2',
#   'PTPRJ',
#   'ZBTB20',
#   'CA12',
#   'GPRC5A',
#   'TNS3',
#   'MIR193BHG',
#   'ACTN4',
#   'ABHD3',
#   'ATP8B1',
#   'ABCC4',
#   'PTPRK',
#   'SRGAP1',
#   'MEGF9',
#   'MCU',
#   'LAMA3',
#   'MYOF',
#   'LINC00511',
#   'MALAT1-1',
#   'MLXIP',
#   'PARD3',
#   'CLIP1',
#   'IGFL2-AS1',
#   'GBE1',
#   'ZFPM2-AS1',
#   'PDLIM5',
#   'XPO1',
#   'RPS2',
#   'RPL8',
#   'RPLP0',
#   'AC016205.1',
#   'CFL1',
#   'HSP90B1',
#   'TUBB',
#   'RIF1',
#   'MED13L',
#   'ASPH',
#   'PDIA6',
#   'EML4',
#   'MT-CO2',
#   'CDC42BPA',
#   'FAM107B',
#   'HSP90AA1',
#   'TMBIM6',
#   'FTL',
#   'CENPF',
#   'LAMB1',
#   'RPS19',
#   'CD44',
#   'MUC5B',
#   'BSG',
#   'ENO1',
#   'IGFBP4',
#   'MKI67',
#   'MT-ND4L',
#   'MT-CYB',
#   'TOP2A',
#   'MT-ATP8',
#   'PDE4B',
#   'FN1',
#   'ATP2B1',
#   'MAML3',
#   'PDE10A',
#   'MT-CO3',
#   'MYO10',
#   'ALDH3A1',
#   'NPAS2',
#   'MT-ND4',
#   'CCND1',
#   'MT-ND5',
#   'KYNU',
#   'PKM',
#   'SIPA1L3',
#   'ARHGAP26',
#   'MT-CO1',
#   'ABCC3',
#   'AGR2',
#   'MT-ND1',
#   'GAPDH',
#   'MT-ND2',
#   'SLC12A2',
#   'CYP24A1',
#   'THSD4',
#   'AKR1B10'],
#  'A549_Roscovitine (Seliciclib,CYC202)_1000.0': ['MT-CO1', 'MT-RNR2'],
#  'A549_S-Ruxolitinib (INCB018424)_10000.0': ['PKM',
#   'SLC12A2',
#   'ALDH3A1',
#   'MT-CO3'],
#  'A549_JNJ-26854165 (Serdemetan)_100.0': [],
#  'A549_CEP-33779_100.0': [],
#  'A549_Tofacitinib (CP-690550) Citrate_1000.0': ['MT-ATP6',
#   'MT-CO3',
#   'MT-CO2',
#   'MT-CO1'],
#  'A549_Hesperadin_10000.0': ['MT-CO1',
#   'MT-CO2',
#   'AC011287.1',
#   'MT-ND4',
#   'TAF15',
#   'HERC4',
#   'MT-CYB',
#   'ACYP2',
#   'MT-ATP6',
#   'FLNA',
#   'SQSTM1',
#   'MT-CO3',
#   'MDM2',
#   'CLIP1',
#   'DSTN',
#   'RPS9',
#   'RPS16',
#   'MALAT1',
#   'MT-ND2',
#   'MKLN1',
#   'MT-ATP8',
#   'CPLX2',
#   'NPAS2',
#   'PCDH9',
#   'PRKCA',
#   'NCOA3',
#   'MED13L',
#   'NFIA',
#   'ABCC3',
#   'CMIP',
#   'TBC1D8',
#   'AKR1B10',
#   'MTUS1',
#   'PDE4B',
#   'KYNU',
#   'CUX1',
#   'ARHGAP26',
#   'SIPA1L3',
#   'CYP24A1',
#   'MYO1E',
#   'PDE10A',
#   'SLC12A2',
#   'THSD4',
#   'PDE4D'],
#  'A549_UNC0379_10.0': [],
#  'A549_TGX-221_10000.0': [],
#  'A549_Filgotinib (GLPG0634)_1000.0': [],
#  'A549_G007-LK_10.0': [],
#  'A549_WHI-P154_10.0': [],
#  'A549_Triamcinolone Acetonide_1000.0': ['KRT18',
#   'FKBP5',
#   'KRT8',
#   'AKAP13',
#   'BTBD11',
#   'TBC1D8',
#   'FGD4',
#   'KRT7',
#   'ANXA2',
#   'DOCK4',
#   'PYGB',
#   'ERRFI1',
#   'ABHD2',
#   'ZBTB20',
#   'PTPRM',
#   'PCDH9',
#   'SERPINE1',
#   'TFCP2L1',
#   'IGFBP4',
#   'AHNAK',
#   'EMP2',
#   'EPB41L4A',
#   'TRIO',
#   'STOM',
#   'AKR1C2',
#   'SDK2',
#   'NEAT1',
#   'PTK2',
#   'TNS3',
#   'GPC6',
#   'S100A10',
#   'HPGD',
#   'PDE7B',
#   'CNTNAP3B',
#   'CAST',
#   'ATP2B1',
#   'RAD51B',
#   'BASP1',
#   'PDE8A',
#   'TUBB',
#   'MCU',
#   'MED13L',
#   'CENPF',
#   'AC016205.1',
#   'CA12',
#   'TOP2A',
#   'HSP90AA1',
#   'PDLIM5',
#   'NQO1',
#   'ARHGAP26',
#   'MKI67',
#   'MID1',
#   'FAM107B',
#   'KYNU',
#   'SLC7A11',
#   'MYO10',
#   'PDE10A',
#   'MAP7',
#   'FTL',
#   'AKR1B10',
#   'CYP24A1',
#   'SLC12A2'],
#  'A549_BMS-911543_100.0': [],
#  'A549_Flavopiridol HCl_10000.0': [],
#  'A549_Ruxolitinib (INCB018424)_1000.0': [],
#  'A549_Mesna _10.0': [],
#  'A549_Ruxolitinib (INCB018424)_10.0': [],
#  'A549_CYC116_1000.0': [],
#  'A549_AT9283_10.0': ['MDM2'],
#  'A549_PJ34_1000.0': [],
#  'A549_GSK-LSD1 2HCl_100.0': [],
#  'A549_Droxinostat_10.0': [],
#  'A549_Momelotinib (CYT387)_10000.0': ['ALDH3A1',
#   'MT-CO1',
#   'PKM',
#   'MT-ND1',
#   'MT-ND4',
#   'SLC7A11',
#   'MT-ATP6',
#   'SLC38A1',
#   'MT-CO3',
#   'TM4SF1',
#   'AKR1B10',
#   'MT-ND2',
#   'CCT3',
#   'RHOA',
#   'TOB1',
#   'GPRC5A',
#   'BRI3BP',
#   'IRS2',
#   'MORC4',
#   'RPS16',
#   'ZRANB3',
#   'IGFBP4',
#   'MT-CYB',
#   'ANXA1',
#   'DDX21',
#   'MT-CO2',
#   'IMMP2L',
#   'CKAP5',
#   'TESC',
#   'MLPH',
#   'P3H4',
#   'PA2G4',
#   'IKBIP',
#   'CD81',
#   'LDHB',
#   'PAQR5',
#   'RACK1',
#   'DNAJC22',
#   'SQSTM1',
#   'PYGB',
#   'FAT1',
#   'GRAMD1B',
#   'ACTB',
#   'COPA',
#   'MT-ATP8',
#   'HSPH1',
#   'RPLP2',
#   'RSPO3',
#   'G6PD',
#   'EPAS1',
#   'ACYP2',
#   'TEAD1',
#   'CCAR1',
#   'ARL4C',
#   'ZBTB38',
#   'MKLN1',
#   'UBR4',
#   'CNTN1'],
#  'A549_Mesna _100.0': [],
#  'A549_Azacitidine _10.0': [],
#  'A549_AT9283_10000.0': ['ALDH3A1',
#   'MDM2',
#   'NKD1',
#   'DCBLD2',
#   'RACK1',
#   'PTGS2',
#   'LHFPL2'],
#  'A549_Roxadustat (FG-4592)_100.0': [],
#  'A549_Glesatinib?(MGCD265)_10000.0': ['MALAT1',
#   'SCD',
#   'FADS1',
#   'MT-ATP8',
#   'MT-ND5',
#   'MT-ND4',
#   'MT-ND1',
#   'MT-ND2'],
#  'A549_Belinostat (PXD101)_1000.0': ['MALAT1',
#   'ANXA1',
#   'CRIM1',
#   'NEAT1',
#   'TFPI2',
#   'IGFL2-AS1',
#   'CLU',
#   'FNDC3B',
#   'HIF1A',
#   'TXNRD1',
#   'GPRC5A',
#   'MKLN1',
#   'MALAT1-1',
#   'PSAP',
#   'LINC-PINT',
#   'CYP24A1',
#   'AC008014.1',
#   'AKR1B1',
#   'DCBLD2',
#   'DNM3',
#   'LIMCH1',
#   'NR3C1',
#   'MYO1E',
#   'CAVIN1',
#   'RORA',
#   'VMP1',
#   'USP9X',
#   'UBE2H',
#   'ATP1B1',
#   'IGF1R',
#   'PDE4D',
#   'PTEN',
#   'TRIO',
#   'NFAT5',
#   'LUCAT1',
#   'FBXL20',
#   'NCOA7',
#   'AFF1',
#   'AC002066.1',
#   'NRG1',
#   'EGFR',
#   'FANCI',
#   'NUCKS1',
#   'MUC5B',
#   'TUBB',
#   'SIPA1L3',
#   'CSGALNACT1',
#   'PATJ',
#   'TOP2A',
#   'SLC7A5',
#   'CCND1',
#   'CACNA1D',
#   'ST6GAL2',
#   'PGD',
#   'PDE10A',
#   'AC016205.1',
#   'CNTNAP3B',
#   'CPLX2',
#   'CENPF',
#   'ABCC2',
#   'GAPDH',
#   'MGST1',
#   'RBFOX3',
#   'MKI67',
#   'KRT81',
#   'HNF1A-AS1',
#   'CA12',
#   'AKR1B10',
#   'ABCC3',
#   'ALDH3A1',
#   'WWOX'],
#  'A549_Hesperadin_1000.0': ['MDM2',
#   'MT-ND4',
#   'MT-RNR2',
#   'MT-CO3',
#   'MT-ND5',
#   'MT-ATP6',
#   'FLNA',
#   'MT-CO1',
#   'MKLN1',
#   'PAPPA',
#   'MT-CO2',
#   'TRIO',
#   'CAVIN1',
#   'CA12',
#   'SRGAP1',
#   'MKI67',
#   'PDE10A',
#   'AKR1B10'],
#  'A549_Fluorouracil (5-Fluoracil, 5-FU)_10.0': [],
#  'A549_BMS-265246_10.0': [],
#  'A549_Fasudil (HA-1077) HCl_100.0': [],
#  'A549_BRD4770_10.0': [],
#  'A549_WP1066_100.0': [],
#  'A549_Celecoxib_10.0': [],
#  'A549_TGX-221_1000.0': [],
#  'A549_Gandotinib (LY2784544)_100.0': [],
#  'A549_Avagacestat (BMS-708163)_1000.0': [],
#  'A549_Alisertib (MLN8237)_10.0': ['MDM2', 'PAPPA'],
#  'A549_AR-42_10000.0': ['MALAT1',
#   'COL26A1',
#   'CEACAM22P',
#   'ACSL3',
#   'AC010197.1',
#   'INSIG1',
#   'SREBF1',
#   'ACSBG1',
#   'SQSTM1',
#   'TNFRSF10B',
#   'NPC1',
#   'AC008050.1',
#   'MORF4L1',
#   'LINC02204',
#   'PARP16',
#   'UBR3',
#   'RPL3L',
#   'LPIN1',
#   'ZSWIM6',
#   'SPAG9',
#   'STAT3',
#   'HMGCS1',
#   'CLU',
#   'AC138819.1',
#   'PEG10',
#   'IDI1',
#   'AC008250.1',
#   'AC139491.2',
#   'LINC02506',
#   'TMEM135',
#   'CTGF',
#   'NEAT1',
#   'RGL1',
#   'DHRS2',
#   'SAT1',
#   'MALAT1-1',
#   'HMGCR',
#   'FDFT1',
#   'MACROD2',
#   'AC068152.1',
#   'LINC00624',
#   'MARCH6',
#   'ACACA',
#   'FASN',
#   'AP000769.1',
#   'EXT1',
#   'RALGAPA2',
#   'CPM',
#   'LINC00540',
#   'TYW1B',
#   'TAOK3',
#   'PSAP',
#   'LDLR',
#   'PLD3',
#   'SNX29',
#   'LINC01511',
#   'MT-ND5',
#   'ACTG1',
#   'PHF14',
#   'ACLY',
#   'FBXL20',
#   'PCYOX1',
#   'TMEM41B',
#   'DNAH3',
#   'DNM3',
#   'ZFP90',
#   'CD81',
#   'GRB2',
#   'VPS53',
#   'AREG',
#   'AC139493.2',
#   'JPT1',
#   'KCNAB1',
#   'SERPINE1',
#   'ABTB2',
#   'PCLO',
#   'DNAJC1',
#   'AC011476.3',
#   'ATP6V0D1',
#   'TOM1L2',
#   'P4HB',
#   'CGREF1',
#   'SYT11',
#   'SMYD3',
#   'ODC1',
#   'ACSL4',
#   'SLC9A3R1',
#   'ATP6V0A1',
#   'LPCAT3',
#   'CLPTM1',
#   'GPRC5A',
#   'ADAMTSL4-AS1',
#   'LIMA1',
#   'KIDINS220',
#   'SERPINB9',
#   'VCL',
#   'PPM1E',
#   'HERC1',
#   'ADIPOR2',
#   'TOR1AIP2',
#   'CDC14B',
#   'CCNYL1',
#   'SEL1L',
#   'CALR',
#   'USP9X',
#   'WSCD1',
#   'SQLE',
#   'NEU1',
#   'ZER1',
#   'TFPI2',
#   'CEACAM20',
#   'MT-CO3',
#   'AKAP13',
#   'IQCH',
#   'RPS5',
#   'HSP90AA1',
#   'RAB11FIP1',
#   'HSD17B12',
#   'CYP4F2',
#   'ATP6V1D',
#   'RABEP1',
#   'POR',
#   'NME7',
#   'TMEM241',
#   'SCD',
#   'SBNO1',
#   'RTN3',
#   'LMBR1',
#   'RORA',
#   'RHOA',
#   'MT-CO1',
#   'SSBP2',
#   'GBF1',
#   'STAT1',
#   'TEX14',
#   'SORBS1',
#   'TRAPPC9',
#   'H3F3B',
#   'PTPN1',
#   'KMT2C',
#   'SKAP2',
#   'KLHL13',
#   'SUPT6H',
#   'RARS',
#   'APLP2',
#   'OTUD7A',
#   'DAAM1',
#   'ZNF815P',
#   'TCN2',
#   'SUPT5H',
#   'ZKSCAN1',
#   'TASP1',
#   'NR6A1',
#   'BICDL1',
#   'USP15',
#   'GNG7',
#   'CALM1',
#   'CCSER2',
#   'AL356804.1',
#   'LINC02328',
#   'AC008014.1',
#   'FRMD5',
#   'CCDC88A',
#   'KDM5B',
#   'CKB',
#   'CLEC16A',
#   'HIP1',
#   'R3HCC1',
#   'CALU',
#   'TIMP2',
#   'SYAP1',
#   'DCAF7',
#   'OS9',
#   'RPL18',
#   'LMTK3',
#   'ARL6IP1',
#   'EXOC6B',
#   'RPS16',
#   'VMP1',
#   'MFSD8',
#   'TMBIM6',
#   'HIST1H4H',
#   'NXN',
#   'RBBP5',
#   'NARF',
#   'RNF216',
#   'PIP5K1A',
#   'PKM',
#   'STC1',
#   'SETX',
#   'USP49',
#   'FBXO18',
#   'CALN1',
#   'KATNBL1',
#   'TXNIP',
#   'FAM91A1',
#   'RAE1',
#   'HIST1H2BD',
#   'PRDX1',
#   'OSBPL8',
#   'CPEB4',
#   'EXTL3',
#   'WDR70',
#   'KNTC1',
#   'EPB41L5',
#   'ATP1B2',
#   'TMPRSS9',
#   'HCG27',
#   'STRBP',
#   'PTEN',
#   'RB1CC1',
#   'UBE4A',
#   'MAGT1',
#   'YME1L1',
#   'PCBP3',
#   'LRPPRC',
#   'UBN1',
#   'ARMC9',
#   'CTR9',
#   'CLTA',
#   'CD46',
#   'FAM126B',
#   'RNF24',
#   'KIF3A',
#   'FBXL2',
#   'GDE1',
#   'NOSIP',
#   'SLC4A8',
#   'MT-ND4',
#   'TM7SF2',
#   'MLEC',
#   'DNAL1',
#   'DNAH12',
#   'VGF',
#   'CRISPLD2',
#   'FRYL',
#   'TPI1',
#   'CBLB',
#   'LAMP2',
#   'HSPA4',
#   'CRIM1',
#   'LUZP1',
#   'CBFA2T2',
#   'ITPR2',
#   'TPM3',
#   'ORC4',
#   'AC092069.1',
#   'LIPE-AS1',
#   'SIRT2',
#   'NSMCE2',
#   'OAZ1',
#   'IFT172',
#   'KLHL28',
#   'ERP44',
#   'PNPLA2',
#   'TAF3',
#   'HADHB',
#   'IGF2R',
#   'DCBLD2',
#   'CDKN1A',
#   'ERN1',
#   'UBE2B',
#   'DHCR7',
#   'ABCA7',
#   'DHCR24',
#   'GRN',
#   'RIOK3',
#   'DNAJB1',
#   'BCAM',
#   'CAVIN1',
#   'DIAPH1',
#   'FLNA',
#   'TMCO1',
#   'LSS',
#   'HIST1H2AC',
#   'ACOT7',
#   'LIPA',
#   'ACAD10',
#   'C16orf45',
#   'AMN1',
#   'SPTAN1',
#   'TTC37',
#   'PPP1R13B',
#   'UBAP2',
#   'ETV7',
#   'AC093001.1',
#   'AC005006.1',
#   'ATP6V1A',
#   'PPFIA1',
#   'ATG4B',
#   'CASC4',
#   'GPATCH2L',
#   'PSMD2',
#   'OGDH',
#   'NARS2',
#   'DCAF10',
#   'ULK4',
#   'NR4A1',
#   'COG5',
#   'RPS9',
#   'TUBA1A',
#   'EDA',
#   'AC092100.1',
#   'AFTPH',
#   'POLR2L',
#   'FAM117A',
#   'FAM126A',
#   'CSPP1',
#   'HIVEP3',
#   'PLEKHB2',
#   'SERINC3',
#   'PIKFYVE',
#   'BSG',
#   'EFR3A',
#   'MTMR14',
#   'EHD1',
#   'TOP2A',
#   'FNDC3B',
#   'TGIF1',
#   'GULP1',
#   'ITGB5',
#   'METTL16',
#   'TACC2',
#   'ZMYND8',
#   'NR3C1',
#   'CKAP4',
#   'TTC28',
#   'ALDH3A1',
#   'MAP1B',
#   'ANXA2',
#   'HIPK2',
#   'DST',
#   'CENPF',
#   'NF1',
#   'SPATS2',
#   'CAMK2D',
#   'PLCH1',
#   'MSI2',
#   'NSD1',
#   'PAPPA',
#   'DHRS3',
#   'AC016205.1',
#   'SEPT9',
#   'SIPA1L3',
#   'ARID1B',
#   'GRAMD1A',
#   'LAMB1',
#   'CTBP2',
#   'AGR2',
#   'DENND5B',
#   'IGF1R',
#   'SLC3A2',
#   'ME1',
#   'TMOD3',
#   'SHANK2',
#   'CACNA1D',
#   'MT-RNR2',
#   'NFIC',
#   'TUBB',
#   'MKI67',
#   'PTGR1',
#   'GRAMD1B',
#   'MAP3K20',
#   'RBM47',
#   'ST6GAL2',
#   'WWTR1',
#   'CUEDC1',
#   'IGF2BP3',
#   'KANSL1',
#   'TM4SF1',
#   'RBFOX3',
#   'RBPMS',
#   'RNF213',
#   'IGF2BP1',
#   'ZBTB20',
#   'ZFHX3',
#   'TPM4',
#   'GPC6',
#   'ABCC4',
#   'UGDH',
#   'SPTBN1',
#   'LINC-PINT',
#   'LGR4',
#   'RAB10',
#   'CD44',
#   'LIMCH1',
#   'EGLN1',
#   'CCND1',
#   'CPLX2',
#   'PDE8A',
#   'TBC1D8',
#   'HNF1A-AS1',
#   'MIR31HG',
#   'PTPRJ',
#   'PGD',
#   'FTX',
#   'PRKCA',
#   'MYO10',
#   'JMJD1C',
#   'CNTNAP3B',
#   'NPAS2',
#   'MGST1',
#   'IGFBP4',
#   'CNTN1',
#   'PDE3A',
#   'KRT7',
#   'CACNA2D1',
#   'PDLIM5',
#   'GLIS3',
#   'NRCAM',
#   'NRP1',
#   'SLC7A5',
#   'LINC00511',
#   'SMAD3',
#   'MID1',
#   'BMPR1B',
#   'MYOF',
#   'KRT81',
#   'ABCC1',
#   'LPP',
#   'SLC12A2',
#   'KRT8',
#   'PARD3',
#   'THSD7A',
#   'EFNA5',
#   'NFIA',
#   'CSGALNACT1',
#   'ASPH',
#   'AKR1C1',
#   'PTPRM',
#   'C9orf3',
#   'MAP7',
#   'ANXA4',
#   'NQO1',
#   'PDE4B',
#   'TNS3',
#   'PDE10A',
#   'MAML3',
#   'GPX2',
#   'DOCK5',
#   'CYP24A1',
#   'PVT1',
#   'AKR1C2',
#   'KRT18',
#   'MTUS1',
#   'THSD4',
#   'EHBP1',
#   'SLC7A11',
#   'AKR1C3',
#   'CA12',
#   'KYNU',
#   'CUX1',
#   'ABCC2',
#   'ALDH1A1',
#   'ABCC3',
#   'AKR1B10',
#   'PDE4D'],
#  'A549_Toremifene Citrate_1000.0': [],
#  'A549_Divalproex Sodium_10000.0': [],
#  'A549_Tranylcypromine (2-PCPA) HCl_1000.0': [],
#  'A549_Dacinostat (LAQ824)_1000.0': ['MALAT1',
#   'ACSL3',
#   'COL26A1',
#   'AC010197.1',
#   'CEACAM22P',
#   'INSIG1',
#   'SREBF1',
#   'PARP16',
#   'SQSTM1',
#   'ACSBG1',
#   'UBR3',
#   'HMGCS1',
#   'LINC02506',
#   'MORF4L1',
#   'TNFRSF10B',
#   'AC008050.1',
#   'RGL1',
#   'STAT3',
#   'IDI1',
#   'CLU',
#   'NPC1',
#   'SPAG9',
#   'AREG',
#   'NEAT1',
#   'RPL3L',
#   'DNAJC1',
#   'AP000769.1',
#   'MALAT1-1',
#   'LPIN1',
#   'AC138819.1',
#   'PSAP',
#   'ACACA',
#   'MT-ND5',
#   'TMEM135',
#   'AC139491.2',
#   'GPRC5A',
#   'FBXL20',
#   'EXT1',
#   'TFPI2',
#   'TAOK3',
#   'ZSWIM6',
#   'TEX14',
#   'LINC02204',
#   'SAT1',
#   'AC008250.1',
#   'MACROD2',
#   'DHRS2',
#   'TYW1B',
#   'PEG10',
#   'LDLR',
#   'SERPINE1',
#   'MARCH6',
#   'HERC1',
#   'LINC00624',
#   'FASN',
#   'TOM1L2',
#   'AKAP13',
#   'ABTB2',
#   'USP9X',
#   'CRIM1',
#   'GRB2',
#   'RPS5',
#   'HMGCR',
#   'CCNYL1',
#   'CD81',
#   'PCYOX1',
#   'FADS1',
#   'CTGF',
#   'GBF1',
#   'PHF14',
#   'DNM3',
#   'AL356804.1',
#   'AC139493.2',
#   'TMEM41B',
#   'CPM',
#   'ZFP90',
#   'JPT1',
#   'RALGAPA2',
#   'FBXL2',
#   'PIKFYVE',
#   'PTEN',
#   'DNAH3',
#   'SMYD3',
#   'SERPINB9',
#   'DAAM1',
#   'AC008014.1',
#   'FDFT1',
#   'AC011476.3',
#   'CLPTM1',
#   'RTN3',
#   'ADAMTSL4-AS1',
#   'RAB11FIP1',
#   'SQLE',
#   'OTUD7A',
#   'ATP6V0D1',
#   'WSB1',
#   'LINC02328',
#   'KIDINS220',
#   'CPEB4',
#   'PIP5K1A',
#   'APLP2',
#   'ITPR2',
#   'SLC9A3R1',
#   'PLD3',
#   'ZKSCAN1',
#   'ATP6V1D',
#   'ACTG1',
#   'CLEC16A',
#   'AC068152.1',
#   'ACLY',
#   'KDM5B',
#   'RNF216',
#   'SLC2A3',
#   'ATP6V1A',
#   'STAT1',
#   'SERPINB1',
#   'PTPN1',
#   'VPS53',
#   'PNPLA2',
#   'CCDC88A',
#   'WSCD1',
#   'ATP6AP2',
#   'MT-CO1',
#   'EXTL3',
#   'FRMD5',
#   'ODC1',
#   'HERC4',
#   'PPM1E',
#   'TASP1',
#   'VCL',
#   'NXN',
#   'LIMA1',
#   'LPCAT3',
#   'NME7',
#   'RERE',
#   'ZER1',
#   'TRAPPC9',
#   'RPL18',
#   'SSBP2',
#   'GOLGB1',
#   'CDC14B',
#   'UBE2H',
#   'CAVIN1',
#   'NEDD4L',
#   'CALN1',
#   'TIMP2',
#   'UBAP2',
#   'GSK3B',
#   'SNX29',
#   'KRT19',
#   'TMEM241',
#   'RNGTT',
#   'NEU1',
#   'P4HB',
#   'KIF3A',
#   'PEAK1',
#   'TM7SF2',
#   'NSMCE2',
#   'CACUL1',
#   'DHCR7',
#   'ATP6V0A1',
#   'GLS',
#   'TMTC2',
#   'CALR',
#   'ALDOC',
#   'ATP1B2',
#   'LINC01511',
#   'SCD',
#   'MT-CYB',
#   'EXOC6B',
#   'PCMT1',
#   'BSG',
#   'ACSS2',
#   'LIPA',
#   'TANC2',
#   'KMT2C',
#   'LINC00540',
#   'CBLB',
#   'IQCH',
#   'H3F3B',
#   'RORA',
#   'PKM',
#   'NR6A1',
#   'GCLC',
#   'PBX1',
#   'PLCH1',
#   'RAB10',
#   'ATE1',
#   'DHRS3',
#   'DAPK1',
#   'TOP2A',
#   'KPNB1',
#   'DIAPH2',
#   'ATP2A2',
#   'SEPT9',
#   'MSI2',
#   'KRT8',
#   'ZBTB20',
#   'CUEDC1',
#   'MAP3K20',
#   'WWTR1',
#   'NUCKS1',
#   'LPGAT1',
#   'PDLIM5',
#   'CKAP4',
#   'ITGB5',
#   'PAPPA',
#   'EPB41L1',
#   'SPATS2',
#   'SLC3A2',
#   'DOCK1',
#   'RNF213',
#   'DST',
#   'CENPF',
#   'RBPMS',
#   'IGF2BP1',
#   'CAMK2D',
#   'PRKCA',
#   'AC016205.1',
#   'SHANK2',
#   'ST6GAL2',
#   'TUBB',
#   'ME1',
#   'PCDH9',
#   'MYO10',
#   'UGDH',
#   'NFIC',
#   'GRAMD1A',
#   'TTC28',
#   'MKI67',
#   'DENND5B',
#   'PTGR1',
#   'RBM47',
#   'CACNA1D',
#   'ENO1',
#   'EGLN1',
#   'AGR2',
#   'TM4SF1',
#   'MID1',
#   'IGF1R',
#   'PDE8A',
#   'FTX',
#   'ZFHX3',
#   'PTPRJ',
#   'MIR31HG',
#   'CD44',
#   'TMOD3',
#   'HNF1A-AS1',
#   'JMJD1C',
#   'CCND1',
#   'SMAD3',
#   'PGD',
#   'RBFOX3',
#   'CPLX2',
#   'MAP7',
#   'CNTN1',
#   'ALDH3A1',
#   'TPM4',
#   'CACNA2D1',
#   'MYOF',
#   'PDE3A',
#   'NPAS2',
#   'TBC1D8',
#   'GLIS3',
#   'CNTNAP3B',
#   'SIPA1L3',
#   'MGST1',
#   'IGFBP4',
#   'KRT7',
#   'BMPR1B',
#   'C9orf3',
#   'SLC7A5',
#   'NRCAM',
#   'ABCC1',
#   'ASPH',
#   'PARD3',
#   'LINC00511',
#   'CSGALNACT1',
#   'NFIA',
#   'NRP1',
#   'AKR1C1',
#   'ANXA4',
#   'LPP',
#   'EFNA5',
#   'NQO1',
#   'SLC12A2',
#   'PDE10A',
#   'PTPRM',
#   'THSD7A',
#   'KRT81',
#   'PDE4B',
#   'MAML3',
#   'CYP24A1',
#   'TNS3',
#   'AKR1C2',
#   'DOCK5',
#   'PVT1',
#   'KRT18',
#   'EHBP1',
#   'MTUS1',
#   'SLC7A11',
#   'KYNU',
#   'GPX2',
#   'CUX1',
#   'CA12',
#   'THSD4',
#   'AKR1C3',
#   'ABCC2',
#   'ALDH1A1',
#   'ABCC3',
#   'AKR1B10',
#   'PDE4D'],
#  'A549_Enzastaurin (LY317615)_10000.0': ['SQSTM1',
#   'RPL13A',
#   'FTL',
#   'RACK1',
#   'IGFL2-AS1',
#   'SLC38A1',
#   'RPS7',
#   'RPLP1',
#   'SET',
#   'RPLP0',
#   'PKM',
#   'ALDH3A1',
#   'RPS16',
#   'PABPC1',
#   'VIM',
#   'SCD',
#   'PRKDC',
#   'MT-ND1',
#   'LRPPRC',
#   'RPS9',
#   'FTH1',
#   'RPS5',
#   'HSP90AA1',
#   'RPL18',
#   'RPS2',
#   'FRMD5',
#   'RPS6',
#   'RPL19',
#   'EEF2',
#   'CPLX2',
#   'NCL',
#   'RPS3',
#   'NFAT5',
#   'PRRC2C',
#   'TPI1',
#   'NAP1L1',
#   'DNM3',
#   'RPL37',
#   'RPL28',
#   'RPL13',
#   'ARL4C',
#   'PTMA',
#   'HSP90AB1',
#   'DCBLD2',
#   'NOLC1',
#   'RPS8',
#   'KPNB1',
#   'EIF4G1',
#   'FADS2',
#   'PA2G4',
#   'RPSA',
#   'RPS4X',
#   'MT-ND2',
#   'RNF43',
#   'TUBA1B',
#   'LRBA',
#   'TRIM28',
#   'RSL1D1',
#   'RPLP2',
#   'PSAP',
#   'SLTM',
#   'RPL3',
#   'RPL23A',
#   'CRIM1',
#   'LGR4',
#   'GPRC5A',
#   'ST6GAL2',
#   'TBC1D8',
#   'DOCK5',
#   'TXNRD1',
#   'SMAD3',
#   'SIPA1L3',
#   'ARHGAP26',
#   'ACTN4',
#   'ABCC3',
#   'PDE10A',
#   'MYO1E',
#   'CSGALNACT1',
#   'ALDH1A1',
#   'KYNU',
#   'MT-RNR2',
#   'AGR2',
#   'MAML3',
#   'PDE4D'],
#  'A549_Patupilone (EPO906, Epothilone B)_10.0': ['MDM2',
#   'LINC01021',
#   'SQSTM1',
#   'CA12',
#   'THSD4',
#   'MTUS1',
#   'WWOX',
#   'PDE10A',
#   'PDE4D',
#   'ABCC3'],
#  'A549_GSK J1_10.0': [],
#  'A549_Capecitabine _10.0': [],
#  'A549_Toremifene Citrate_10.0': [],
#  'A549_AR-42_100.0': ['MALAT1',
#   'CYP24A1',
#   'TFPI2',
#   'MT-ND5',
#   'NEAT1',
#   'FNDC3B',
#   'ANXA1',
#   'MT-CO1',
#   'DCBLD2',
#   'IGFL2-AS1',
#   'MT-CO3',
#   'PSAP',
#   'CRIM1',
#   'CLU',
#   'KRT8',
#   'ATP2B1',
#   'CYB5B',
#   'HIF1A',
#   'ITGB1',
#   'KRT18',
#   'DST',
#   'SYT1',
#   'RORA',
#   'CAST',
#   'ZMYND8',
#   'GPRC5A',
#   'MALAT1-1',
#   'SAT1',
#   'PGD',
#   'RAB10',
#   'AKR1B10',
#   'MKI67',
#   'STAG1',
#   'SLC7A5',
#   'TOP2A',
#   'ABCC3',
#   'HNF1A-AS1',
#   'ALDH3A1',
#   'KRT81',
#   'WWOX',
#   'ABCC2'],
#  'A549_UNC0379_1000.0': [],
#  'A549_Crizotinib (PF-02341066)_100.0': [],
#  'A549_Ellagic acid_1000.0': [],
#  'A549_MC1568_1000.0': [],
#  'A549_Streptozotocin (STZ)_1000.0': [],
#  'A549_Ellagic acid_10.0': [],
#  'A549_Resminostat_100.0': [],
#  'A549_RG108_1000.0': [],
#  'A549_Tacedinaline (CI994)_10.0': [],
#  'A549_Ofloxacin_10.0': [],
#  'A549_FLLL32_1000.0': [],
#  'A549_AG-490 (Tyrphostin B42)_100.0': [],
#  'A549_Altretamine_100.0': [],
#  'A549_Sirtinol_10000.0': [],
#  'A549_KW-2449_10.0': [],
#  'A549_Temsirolimus (CCI-779, NSC 683864)_10000.0': [],
#  'A549_UNC1999_1000.0': [],
#  'A549_UNC0631_1000.0': ['MT-CO3', 'MT-ATP6', 'MT-CO1', 'MT-ND4'],
#  'A549_GSK J1_10000.0': [],
#  'A549_Obatoclax Mesylate (GX15-070)_1000.0': ['ACTN4'],
#  'A549_Lapatinib (GW-572016) Ditosylate_100.0': [],
#  'A549_MK-5108 (VX-689)_10000.0': ['MDM2',
#   'PAPPA',
#   'ALDH3A1',
#   'NFAT5',
#   'LINC01021',
#   'MT-CO3',
#   'MT-CO1',
#   'MT-ATP6',
#   'MT-ND4',
#   'ALCAM',
#   'SQSTM1',
#   'NRG1',
#   'REV3L',
#   'MT-ND5'],
#  'A549_Fasudil (HA-1077) HCl_10000.0': [],
#  'A549_Valproic acid sodium salt (Sodium valproate)_10000.0': ['MT-CO1'],
#  'A549_AC480 (BMS-599626)_10000.0': ['SCD',
#   'MALAT1',
#   'FADS1',
#   'NEAT1',
#   'MT-ND1',
#   'MT-ND2'],
#  'A549_Bisindolylmaleimide IX (Ro 31-8220 Mesylate)_1000.0': [],
#  'A549_Sorafenib Tosylate_10000.0': ['MALAT1',
#   'KRT7',
#   'MAP1B',
#   'KRT81',
#   'ITGA3',
#   'FLNA',
#   'RPS5',
#   'GFPT1',
#   'MUC5AC',
#   'RPL13A',
#   'S100A6',
#   'AC008014.1',
#   'DCBLD2',
#   'FLNB',
#   'SPTBN1',
#   'PFN1',
#   'BCAS3',
#   'RPLP1',
#   'TNS3',
#   'ANXA4',
#   'FAM107B',
#   'TXNRD1',
#   'PDE4D',
#   'RAB10',
#   'CYP24A1',
#   'MT-ND4L',
#   'SLC12A2',
#   'MTUS1',
#   'MT-CYB',
#   'MT-CO2',
#   'MT-ND1',
#   'MT-ND4',
#   'MT-ATP8',
#   'MT-ATP6',
#   'MT-ND2',
#   'MT-CO3',
#   'MT-CO1',
#   'MT-ND5',
#   'MT-RNR2',
#   'MT-RNR1'],
#  'A549_Tazemetostat (EPZ-6438)_100.0': [],
#  'A549_ENMD-2076 L-(+)-Tartaric acid _100.0': [],
#  'A549_ZM 447439_100.0': [],
#  'A549_Resminostat_10.0': [],
#  'A549_Ki16425_1000.0': [],
#  'A549_Bisindolylmaleimide IX (Ro 31-8220 Mesylate)_100.0': [],
#  'A549_Tazemetostat (EPZ-6438)_10.0': [],
#  'A549_BMS-754807_100.0': [],
#  'A549_2-Methoxyestradiol (2-MeOE2)_1000.0': [],
#  'A549_ENMD-2076_10000.0': ['NEAT1',
#   'MALAT1',
#   'MDM2',
#   'SQSTM1',
#   'MT-RNR2',
#   'IGFL2-AS1',
#   'CA12',
#   'GPCPD1',
#   'SCD',
#   'NFAT5',
#   'LRMDA',
#   'NRG1',
#   'FTX',
#   'ALCAM',
#   'LINC-PINT',
#   'ABHD3',
#   'SYNE2',
#   'ACSS2',
#   'BCAS3',
#   'FMNL2',
#   'PAPPA',
#   'MT-CO1',
#   'FBXL20',
#   'MT-ATP6',
#   'TFPI',
#   'NBEA',
#   'MALAT1-1',
#   'MIR31HG',
#   'AC105243.1',
#   'MT-ND4',
#   'TOP2A',
#   'TUBB',
#   'AKR1B10',
#   'CENPF',
#   'MKI67',
#   'KRT8',
#   'HSP90AA1',
#   'ACTN4',
#   'GAPDH',
#   'KRT81'],
#  'A549_Navitoclax (ABT-263)_1000.0': ['NEAT1', 'MALAT1', 'MT-ND5'],
#  'A549_Abexinostat (PCI-24781)_1000.0': ['MALAT1',
#   'COL26A1',
#   'NEAT1',
#   'TFPI2',
#   'ACSL3',
#   'CRIM1',
#   'ANXA1',
#   'GPRC5A',
#   'MALAT1-1',
#   'CLU',
#   'CEACAM22P',
#   'MACROD2',
#   'PSAP',
#   'PTEN',
#   'TXNRD1',
#   'LUCAT1',
#   'STAT3',
#   'UBE2H',
#   'SQSTM1',
#   'IGFL2-AS1',
#   'PRAG1',
#   'AC008014.1',
#   'MT-ND5',
#   'SLC2A3',
#   'AP000769.1',
#   'DNM3',
#   'RORA',
#   'ZSWIM6',
#   'ADAMTSL4-AS1',
#   'DCBLD2',
#   'AC010197.1',
#   'SAT1',
#   'HERC4',
#   'HIF1A',
#   'SERPINE1',
#   'SREBF1',
#   'TMTC2',
#   'AKAP13',
#   'EXT1',
#   'CDC14B',
#   'AREG',
#   'BSG',
#   'SYT1',
#   'CPEB4',
#   'PKM',
#   'TNFRSF10B',
#   'USP9X',
#   'PEG10',
#   'DNAJC1',
#   'AC002066.1',
#   'RTN3',
#   'TGM2',
#   'TANC2',
#   'SEMA3C',
#   'LINC02506',
#   'CD81',
#   'AC008050.1',
#   'MT-CO1',
#   'CBLB',
#   'GRB2',
#   'KRT19',
#   'GMCL1',
#   'NCEH1',
#   'MT-CO3',
#   'ARID5B',
#   'HIP1',
#   'VMP1',
#   'WWC1',
#   'KMT2C',
#   'MYO1B',
#   'APLP2',
#   'GLS',
#   'PPM1E',
#   'SLC38A2',
#   'EXOC6B',
#   'MYO1E',
#   'CPM',
#   'FBXL20',
#   'TIMP2',
#   'SMYD3',
#   'RB1CC1',
#   'CAVIN1',
#   'PARP16',
#   'CCNYL1',
#   'LPCAT3',
#   'CCDC88A',
#   'ABTB2',
#   'TMEM241',
#   'DKK1',
#   'MBNL1',
#   'SPAG9',
#   'RALGAPA2',
#   'ACSBG1',
#   'DHRS2',
#   'MAP2',
#   'TCF7L2',
#   'MCM8',
#   'RBPMS',
#   'AKR1C1',
#   'PAPPA',
#   'SHANK2',
#   'NPAS2',
#   'CCND1',
#   'MCM4',
#   'SMC4',
#   'DLEU2',
#   'KYNU',
#   'ATE1',
#   'MAML3',
#   'AGR2',
#   'PCDH9',
#   'IGF2BP1',
#   'CD44',
#   'FANCI',
#   'SLC12A2',
#   'ABCC1',
#   'TMOD3',
#   'LINC00511',
#   'MAP7',
#   'CACNA1D',
#   'NFIC',
#   'BMPR1B',
#   'TBC1D8',
#   'NFIA',
#   'LPP',
#   'KRT7',
#   'SLC3A2',
#   'ST6GAL2',
#   'NRP1',
#   'ASPM',
#   'AC016205.1',
#   'PDE4B',
#   'NUCKS1',
#   'CUX1',
#   'MAP3K20',
#   'RBFOX3',
#   'TUBB',
#   'IGFBP4',
#   'CNTNAP3B',
#   'KRT18',
#   'CENPF',
#   'ENO1',
#   'CACNA2D1',
#   'PDE4D',
#   'TOP2A',
#   'THSD7A',
#   'SLC7A5',
#   'MTUS1',
#   'PDE10A',
#   'GPX2',
#   'SIPA1L3',
#   'CPLX2',
#   'HNF1A-AS1',
#   'SLC7A11',
#   'MKI67',
#   'TNS3',
#   'MGST1',
#   'GAPDH',
#   'PGD',
#   'EHBP1',
#   'CSGALNACT1',
#   'ALDH3A1',
#   'THSD4',
#   'AKR1C3',
#   'KRT81',
#   'ALDH1A1',
#   'CA12',
#   'ABCC2',
#   'ABCC3',
#   'AKR1B10'],
#  'A549_Mocetinostat (MGCD0103)_100.0': ['KRT18'],
#  'A549_Pracinostat (SB939)_100.0': ['MALAT1',
#   'CYP24A1',
#   'MT-ND5',
#   'MT-CO3',
#   'IGFL2-AS1',
#   'FNDC3B',
#   'MACROD2',
#   'MT-CO1',
#   'MT-ND4',
#   'DNM3',
#   'CLU',
#   'DOCK5',
#   'NFAT5',
#   'ALDH3A1',
#   'HNF1A-AS1',
#   'HSP90AA1',
#   'RAB10',
#   'AKR1B10'],
#  'A549_CYC116_100.0': ['ALDH3A1', 'PDE10A'],
#  'A549_Pracinostat (SB939)_10.0': [],
#  'A549_Trichostatin A (TSA)_100.0': [],
#  'A549_Fedratinib (SAR302503, TG101348)_10.0': [],
#  'A549_TGX-221_10.0': [],
#  'A549_Motesanib Diphosphate (AMG-706)_10000.0': ['ALDH3A1'],
#  'A549_Veliparib (ABT-888)_10000.0': [],
#  'A549_MK-5108 (VX-689)_100.0': [],
#  'A549_Alisertib (MLN8237)_100.0': ['MDM2',
#   'PAPPA',
#   'MT-ND4',
#   'MT-ATP6',
#   'PVT1',
#   'NEAT1',
#   'NRG1',
#   'MT-CO1',
#   'MT-ND5',
#   'MIR34AHG',
#   'FBXL20',
#   'NFAT5',
#   'LRMDA',
#   'MT-RNR2',
#   'MALAT1'],
#  'A549_Tofacitinib (CP-690550) Citrate_100.0': [],
#  'A549_Bisindolylmaleimide IX (Ro 31-8220 Mesylate)_10.0': [],
#  'A549_Azacitidine _1000.0': [],
#  'A549_Cimetidine _100.0': [],
#  'A549_BMS-536924_10.0': [],
#  'A549_Vandetanib (ZD6474)_1000.0': [],
#  'A549_Mercaptopurine (6-MP)_100.0': ['NEAT1', 'MALAT1'],
#  'A549_Quercetin_10.0': ['MT-CO3'],
#  'A549_GSK-LSD1 2HCl_10.0': [],
#  'A549_TG101209_100.0': [],
#  'A549_Avagacestat (BMS-708163)_10000.0': [],
#  'A549_Amisulpride_1000.0': [],
#  'A549_M344_100.0': ['MT-CO3'],
#  'A549_Aminoglutethimide _100.0': [],
#  'A549_AC480 (BMS-599626)_100.0': [],
#  'A549_Lapatinib (GW-572016) Ditosylate_10000.0': ['MALAT1',
#   'NEAT1',
#   'MT-ND4L',
#   'HSP90AA1',
#   'MT-CO3',
#   'MT-CO1',
#   'MT-ND2',
#   'MT-ND1',
#   'MT-ND5'],
#  'A549_PD173074_10.0': [],
#  'A549_Tofacitinib (CP-690550) Citrate_10.0': [],
#  'A549_Resminostat_10000.0': ['MALAT1',
#   'ACSL3',
#   'COL26A1',
#   'IGFL2-AS1',
#   'MALAT1-1',
#   'CEACAM22P',
#   'MT-ND5',
#   'SREBF1',
#   'CRIM1',
#   'AP000769.1',
#   'SQSTM1',
#   'AC010197.1',
#   'NEAT1',
#   'PTEN',
#   'ANXA1',
#   'INSIG1',
#   'PSAP',
#   'GPRC5A',
#   'MT-CO1',
#   'TFPI2',
#   'MACROD2',
#   'CLU',
#   'USP9X',
#   'AC008014.1',
#   'TXNRD1',
#   'LINC02506',
#   'ZSWIM6',
#   'TNFRSF10B',
#   'AKAP13',
#   'SCD',
#   'SPAG9',
#   'MT-ND4',
#   'STAT3',
#   'LPIN1',
#   'SAT1',
#   'FADS1',
#   'LDLR',
#   'LUCAT1',
#   'ADAMTSL4-AS1',
#   'PEG10',
#   'TMEM135',
#   'EXOC6B',
#   'NPC1',
#   'RTN3',
#   'HIF1A',
#   'RGL1',
#   'CPEB4',
#   'DNAJC1',
#   'MT-CYB',
#   'PCYOX1',
#   'HERC4',
#   'ACSBG1',
#   'UBE2H',
#   'MT-CO3',
#   'AC008250.1',
#   'CD81',
#   'UBR3',
#   'DNM3',
#   'FASN',
#   'EXT1',
#   'AREG',
#   'PARP16',
#   'AFF1',
#   'RPL3L',
#   'TMEM41B',
#   'DCBLD2',
#   'RB1CC1',
#   'IDI1',
#   'SYT1',
#   'AC008050.1',
#   'CBLB',
#   'PHF14',
#   'KDM5B',
#   'VMP1',
#   'AC138819.1',
#   'GRB2',
#   'TANC2',
#   'CCDC88A',
#   'PRAG1',
#   'LINC01504',
#   'MT-CO2',
#   'TMTC2',
#   'RORA',
#   'NCEH1',
#   'TEAD1',
#   'PPARG',
#   'TAOK3',
#   'GLS',
#   'FBXL2',
#   'VCL',
#   'ATP1B1',
#   'TMEM241',
#   'PIP5K1A',
#   'PKM',
#   'DHRS2',
#   'PPM1E',
#   'DENND4A',
#   'GOLGB1',
#   'KRT19',
#   'EML6',
#   'CCNYL1',
#   'ATP6V0A1',
#   'TOR1AIP2',
#   'CDC14B',
#   'SERPINE1',
#   'ACSL4',
#   'DAAM1',
#   'HIST1H2BD',
#   'HERC1',
#   'PLD3',
#   'CPM',
#   'KMT2C',
#   'CEACAM20',
#   'PRDX1',
#   'GBF1',
#   'ABTB2',
#   'SLC38A2',
#   'KTN1',
#   'ATAD1',
#   'DOCK4',
#   'SMYD3',
#   'LIMA1',
#   'MYO1B',
#   'AMN1',
#   'OSBPL8',
#   'NEDD4L',
#   'AC091212.1',
#   'APLP2',
#   'USP25',
#   'ZNF217',
#   'LIPA',
#   'FBXL20',
#   'RPS5',
#   'ACTG1',
#   'SLC2A3',
#   'SKAP2',
#   'MORF4L1',
#   'GMCL1',
#   'HMGCS1',
#   'RAB1A',
#   'SNX29',
#   'MT-ATP6',
#   'RPL18',
#   'HABP4',
#   'TRAPPC9',
#   'STAT1',
#   'MT-ND4L',
#   'CTGF',
#   'HLTF',
#   'POR',
#   'ACACA',
#   'TOM1L2',
#   'PLOD2',
#   'NEU1',
#   'RERE',
#   'RALGAPA2',
#   'RAB11FIP1',
#   'FDFT1',
#   'HSDL2',
#   'CD46',
#   'MAP2',
#   'MT-ATP8',
#   'NSMCE2',
#   'OLMALINC',
#   'LUZP1',
#   'AL356804.1',
#   'TIMP2',
#   'NME7',
#   'SNAPC1',
#   'CYTH3',
#   'ACSS2',
#   'SOAT1',
#   'RTN4',
#   'MLLT3',
#   'IQCH',
#   'AC139491.2',
#   'JPT1',
#   'ATRN',
#   'ADIPOR2',
#   'SPTAN1',
#   'PIK3C2A',
#   'ZKSCAN1',
#   'JAK1',
#   'MCM4',
#   'HNRNPUL1',
#   'GRAMD1A',
#   'ATE1',
#   'NFIC',
#   'NSD2',
#   'MCM8',
#   'PDE3A',
#   'RBPMS',
#   'ANXA4',
#   'FANCI',
#   'TMOD3',
#   'PTPRJ',
#   'CUEDC1',
#   'AKR1C2',
#   'SLC3A2',
#   'MYOF',
#   'SHANK2',
#   'NUCKS1',
#   'MSI2',
#   'DHRS3',
#   'CENPF',
#   'ENO1',
#   'CACNA1D',
#   'PVT1',
#   'NRCAM',
#   'ASPM',
#   'MYO10',
#   'ZFHX3',
#   'NPAS2',
#   'TOP2A',
#   'KRT18',
#   'KPNB1',
#   'PDLIM5',
#   'PAPPA',
#   'SLC7A11',
#   'TUBB',
#   'AC016205.1',
#   'MKI67',
#   'PATJ',
#   'SLC12A2',
#   'PTPRM',
#   'ST6GAL2',
#   'IGF2BP1',
#   'GPX2',
#   'TBC1D8',
#   'KRT7',
#   'CCND1',
#   'DOCK5',
#   'RBFOX3',
#   'BMPR1B',
#   'MGST1',
#   'IGFBP4',
#   'HNF1A-AS1',
#   'CACNA2D1',
#   'MAML3',
#   'CPLX2',
#   'CNTNAP3B',
#   'MAP7',
#   'PGD',
#   'NRP1',
#   'NFIA',
#   'SIPA1L3',
#   'LINC00511',
#   'PDE4B',
#   'CSGALNACT1',
#   'PDE10A',
#   'MTUS1',
#   'GAPDH',
#   'SLC7A5',
#   'KRT81',
#   'THSD7A',
#   'KYNU',
#   'ALDH3A1',
#   'TNS3',
#   'AKR1C3',
#   'CUX1',
#   'PDE4D',
#   'EHBP1',
#   'THSD4',
#   'ALDH1A1',
#   'CA12',
#   'ABCC2',
#   'ABCC3',
#   'AKR1B10'],
#  'A549_Triamcinolone Acetonide_100.0': ['KRT18',
#   'KRT8',
#   'FKBP5',
#   'BTBD11',
#   'TBC1D8',
#   'KRT7',
#   'DOCK4',
#   'AKAP13',
#   'ERRFI1',
#   'FGD4',
#   'ANXA2',
#   'SERPINE1',
#   'PCDH9',
#   'SDK2',
#   'TRIO',
#   'AHNAK',
#   'NEAT1',
#   'ABHD2',
#   'KRT81',
#   'IGFBP4',
#   'NEDD4',
#   'PYGB',
#   'ZBTB20',
#   'EMP2',
#   'MT-CO3',
#   'DCBLD2',
#   'AKR1C2',
#   'CALD1',
#   'EPB41L4A',
#   'AHNAK2',
#   'B4GALT1',
#   'TFCP2L1',
#   'PHLDB2',
#   'ITGB4',
#   'MT-ATP6',
#   'MALAT1',
#   'SYBU',
#   'RBM20',
#   'STOM',
#   'BICDL1',
#   'BMPR1B',
#   'TUBB',
#   'ARHGAP26',
#   'AGAP1',
#   'BASP1',
#   'CAST',
#   'ASPM',
#   'MKI67',
#   'CSGALNACT1',
#   'AGR2',
#   'MID1',
#   'AC016205.1',
#   'FTL',
#   'TOP2A',
#   'EGLN1',
#   'FAM107B',
#   'KYNU',
#   'MED13L',
#   'CENPF',
#   'MYO10',
#   'AKR1B10',
#   'MAP7',
#   'SLC7A11',
#   'CYP24A1',
#   'PDE10A',
#   'SLC12A2'],
#  'A549_PD173074_10000.0': ['SCD', 'SQSTM1'],
#  'A549_Nilotinib (AMN-107)_10000.0': [],
#  'A549_Lomustine _10000.0': [],
#  'A549_Divalproex Sodium_10.0': [],
#  'A549_SL-327_1000.0': ['NEAT1',
#   'MT-ND4L',
#   'MT-ATP8',
#   'MT-ND1',
#   'MT-ND4',
#   'MT-RNR2',
#   'MT-RNR1',
#   'MT-ND2',
#   'MT-ATP6',
#   'MT-CO3',
#   'MT-ND5',
#   'MT-CO1'],
#  'A549_Ruxolitinib (INCB018424)_10000.0': [],
#  'A549_Toremifene Citrate_100.0': [],
#  'A549_Rucaparib (AG-014699,PF-01367338) phosphate_1000.0': ['MT-ATP6'],
#  'A549_Amisulpride_10000.0': [],
#  'A549_AICAR (Acadesine)_10.0': [],
#  'A549_Entinostat (MS-275)_1000.0': ['MALAT1',
#   'CYP24A1',
#   'KRT18',
#   'NFAT5',
#   'KRT8'],
#  'A549_Regorafenib (BAY 73-4506)_10000.0': ['MALAT1',
#   'RAB10',
#   'KYNU',
#   'MT-CO2',
#   'MT-ND4L',
#   'MT-ND4',
#   'MT-RNR2',
#   'MT-CYB',
#   'MT-ATP8',
#   'MT-ATP6',
#   'MT-CO1',
#   'MT-CO3',
#   'MT-ND1',
#   'MT-RNR1',
#   'MT-ND2',
#   'MT-ND5'],
#  'A549_BMS-536924_1000.0': ['MT-ND5',
#   'MT-CYB',
#   'MT-CO3',
#   'MT-RNR1',
#   'MT-CO1',
#   'MT-RNR2'],
#  'A549_SRT3025 HCl_100.0': [],
#  'A549_JNJ-26854165 (Serdemetan)_10000.0': ['MALAT1',
#   'NEAT1',
#   'SCD',
#   'MALAT1-1',
#   'GAPDH'],
#  'A549_Bosutinib (SKI-606)_10.0': [],
#  'A549_Entacapone_10000.0': [],
#  'A549_A-366_10000.0': ['MT-ND2', 'MT-RNR1'],
#  'A549_(+)-JQ1_1000.0': ['NEAT1',
#   'PKM',
#   'MALAT1',
#   'G6PD',
#   'FTL',
#   'MT-ND5',
#   'TXNRD1',
#   'MT-CO3',
#   'RPLP1',
#   'MT-CO1',
#   'GAPDH',
#   'MT-ND4',
#   'MT-ATP6',
#   'EPHX1',
#   'SQSTM1',
#   'CPLX2',
#   'CNTN1',
#   'GLIS3',
#   'PTPRM',
#   'PDE3A',
#   'SHANK2',
#   'ST6GAL2',
#   'LPP',
#   'FAM107B',
#   'LINC00511',
#   'ABCC2',
#   'PDLIM5',
#   'MTUS1',
#   'TBC1D8',
#   'MYO1E',
#   'CACNA1D',
#   'CYP24A1',
#   'TNS3',
#   'AGR2',
#   'EGLN1',
#   'THSD4',
#   'MAML3',
#   'HNF1A-AS1',
#   'KRT81',
#   'CSGALNACT1',
#   'PDE10A',
#   'CUX1'],
#  'A549_Valproic acid sodium salt (Sodium valproate)_10.0': [],
#  'A549_Ivosidenib (AG-120)_10000.0': [],
#  'A549_PD98059_1000.0': ['MT-CO3', 'MT-RNR1', 'MT-ND5', 'MT-RNR2', 'MT-CO1'],
#  'A549_AMG-900_10000.0': ['LPGAT1',
#   'KRT8',
#   'KRT18',
#   'PAPPA',
#   'MDM2',
#   'CCDC80',
#   'RPS16',
#   'CD81',
#   'FAT1',
#   'PTPRF',
#   'IGFBP3',
#   'BCAS3',
#   'EGFR',
#   'GABRB3',
#   'ZMYND8',
#   'RTN4RL2',
#   'TKT',
#   'THSD4',
#   'MYO1B',
#   'SYT1',
#   'LRMDA',
#   'ASCC1',
#   'ABCC3'],
#  'A549_Sorafenib Tosylate_100.0': [],
#  'A549_M344_1000.0': ['MALAT1',
#   'MT-ND5',
#   'MT-CO1',
#   'PSAP',
#   'MT-CO3',
#   'CYP24A1',
#   'MT-CYB',
#   'MT-ND4',
#   'FNDC3B',
#   'MT-ATP6',
#   'CAST',
#   'CLU',
#   'TARID',
#   'NFAT5',
#   'MACROD2',
#   'MALAT1-1',
#   'TFPI2',
#   'ATP1B1',
#   'DCBLD2',
#   'AKR1B10',
#   'SLC7A5',
#   'MKI67',
#   'HNF1A-AS1',
#   'RAB10',
#   'ALDH3A1',
#   'WWOX'],
#  'A549_Motesanib Diphosphate (AMG-706)_1000.0': [],
#  'A549_MC1568_10000.0': [],
#  'A549_Busulfan _100.0': [],
#  'A549_Cyclocytidine HCl_10000.0': ['MDM2',
#   'CDKN1A',
#   'DDB2',
#   'ALDH3A1',
#   'GDF15',
#   'FDXR',
#   'PPM1D',
#   'REV3L',
#   'IKBIP',
#   'TRIML2',
#   'SERPINE1',
#   'AXL',
#   'ASCC3',
#   'IGF1R',
#   'ASTN2',
#   'CRIM1',
#   'PALLD',
#   'TNFRSF10A',
#   'CENPP',
#   'ZFPM2-AS1',
#   'LINC01021',
#   'TNFRSF10B',
#   'CLIP1',
#   'ABLIM1',
#   'ADK',
#   'PVT1',
#   'MIR34AHG',
#   'YBX3',
#   'SAMD4A',
#   'SYNE1',
#   'BCL2L1',
#   'TRAM1',
#   'EGFR',
#   'DST',
#   'MACF1',
#   'LRP10',
#   'DDX21',
#   'PRRC2C',
#   'PAPPA',
#   'CSNK1G1',
#   'POLH',
#   'LMO7',
#   'XPC',
#   'TMEM131',
#   'COL4A5',
#   'RAB1A',
#   'RBMS1',
#   'PHLDA3',
#   'YME1L1',
#   'SPATS2L',
#   'RPS9',
#   'TP53I3',
#   'CKAP5',
#   'NTN4',
#   'SMG6',
#   'VPS13C',
#   'SQSTM1',
#   'NRG1',
#   'SAT1',
#   'STOM',
#   'SFN',
#   'MAST4',
#   'SYTL2',
#   'TPX2',
#   'MSI2',
#   'APOBEC3C',
#   'SEC61A1',
#   'RIN2',
#   'NHS',
#   'RACK1',
#   'FBXL5',
#   'AEN',
#   'HSPA9',
#   'ITFG1',
#   'FAT1',
#   'DCBLD2',
#   'SEMA3C',
#   'DRAM1',
#   'TNFAIP8',
#   'TIGAR',
#   'MKI67',
#   'PTEN',
#   'TAF3',
#   'USP15',
#   'MAP1B',
#   'TM7SF3',
#   'E2F7',
#   'ZBTB20',
#   'KDM4B',
#   'SPTBN1',
#   'ACER2',
#   'ESYT2',
#   'ALCAM',
#   'MYO1B',
#   'IQGAP1',
#   'GOLGB1',
#   'PTP4A1',
#   'ABTB2',
#   'YAP1',
#   'FBXO22',
#   'WDR43',
#   'FRMD5',
#   'GCC2',
#   'TARID',
#   'UBR4',
#   'LMNA',
#   'TRIO',
#   'BDP1',
#   'UACA',
#   'PRR11',
#   'RRM2B',
#   'BRCA1',
#   'RTN4',
#   'METTL8',
#   'STK17A',
#   'HADHA',
#   'STAT3',
#   'TGFB2',
#   'MGME1',
#   'PFKFB4',
#   'MIR100HG',
#   'UBC',
#   'CAPN2',
#   'GSK3B',
#   'SUSD6',
#   'GPHN',
#   'SETX',
#   'RPL18',
#   'NSMCE2',
#   'GOLGA4',
#   'MAP4K3',
#   'ATAD1',
#   'YARS',
#   'CD109',
#   'CPNE8',
#   'PPP1R15A',
#   'AP2B1',
#   'RRM1',
#   'BAX',
#   'VIM',
#   'SPAG9',
#   'RPS4X',
#   'RPS27L',
#   'HSPA4L',
#   'SULF2',
#   'CEP85L',
#   'SMC4',
#   'NDUFAF6',
#   'FBN2',
#   'PCDH9',
#   'ABCC1',
#   'ME1',
#   'MT-CO1',
#   'MAML3',
#   'MT-ND2',
#   'PGD',
#   'TXNRD1',
#   'THSD7A',
#   'MT-ND1',
#   'WWOX',
#   'PTGR1',
#   'C9orf3',
#   'AKR1C2',
#   'PDE4D',
#   'PDE10A',
#   'CYP24A1',
#   'NCOA3',
#   'EHBP1',
#   'MT-RNR1',
#   'CNTN1',
#   'ABCC3',
#   'MT-RNR2',
#   'MTUS1',
#   'ALDH1A1'],
#  'A549_BMS-265246_100.0': ['MT-ATP6', 'MT-CO3'],
#  'A549_Baricitinib (LY3009104, INCB028050)_10.0': [],
#  'A549_Danusertib (PHA-739358)_10.0': [],
#  'A549_Momelotinib (CYT387)_1000.0': ['ALDH3A1'],
#  'A549_TG101209_1000.0': [],
#  'A549_Alvespimycin (17-DMAG) HCl_1000.0': ['PTGR1',
#   'RAB10',
#   'ATP1B3',
#   'PTPRJ',
#   'HSP90AA1',
#   'TXNRD1',
#   'GLIS3',
#   'ARHGAP21',
#   'PDE10A',
#   'TEAD1',
#   'AKAP12',
#   'DAPK1',
#   'FOXK1',
#   'MALAT1',
#   'PDE4D',
#   'RBM47',
#   'MPRIP',
#   'NOTCH3',
#   'TAF15',
#   'GBE1',
#   'CLU',
#   'PDE7A',
#   'ALDH3A1',
#   'PKM',
#   'NFIA',
#   'MT-ND4L',
#   'NPAS2',
#   'MT-CO3',
#   'MT-RNR2',
#   'AGR2',
#   'SIPA1L3',
#   'ABCC3',
#   'CYP24A1',
#   'MT-ND4',
#   'MT-ATP8',
#   'SLC12A2',
#   'MT-ND2',
#   'MT-ND1',
#   'MT-RNR1',
#   'GAPDH',
#   'MT-ND5',
#   'MT-CO1'],
#  'A549_EED226_10.0': [],
#  'A549_PD173074_100.0': [],
#  'A549_Nintedanib (BIBF 1120)_10000.0': ['SCD',
#   'IGFL2-AS1',
#   'SQSTM1',
#   'FADS1',
#   'THSD4',
#   'MALAT1',
#   'SYNE2',
#   'NEAT1',
#   'LRMDA'],
#  'A549_BRD4770_10000.0': ['MT-CO3'],
#  'A549_Pirarubicin_1000.0': ['MALAT1',
#   'NEAT1',
#   'MDM2',
#   'NFAT5',
#   'PAPPA',
#   'ALDH3A1',
#   'GAPDH'],
#  'A549_Altretamine_1000.0': [],
#  'A549_MC1568_10.0': [],
#  'A549_AC480 (BMS-599626)_1000.0': ['MT-ND2', 'MT-ND1', 'MT-CO1'],
#  'A549_Daphnetin_100.0': [],
#  'A549_Fulvestrant_10000.0': [],
#  'A549_PD98059_100.0': [],
#  'A549_ZM 447439_1000.0': ['NEAT1', 'MDM2', 'MALAT1', 'PAPPA'],
#  'A549_CUDC-101_10.0': ['MT-RNR1'],
#  'A549_AZD1480_100.0': [],
#  'A549_Maraviroc_100.0': [],
#  'A549_Glesatinib?(MGCD265)_1000.0': [],
#  'A549_AG-490 (Tyrphostin B42)_1000.0': [],
#  'A549_Altretamine_10000.0': [],
#  'A549_Regorafenib (BAY 73-4506)_10.0': [],
#  'A549_Barasertib (AZD1152-HQPA)_100.0': ['MDM2',
#   'NEAT1',
#   'MT-RNR2',
#   'MT-CO3',
#   'MT-ND4',
#   'EPHX1',
#   'MT-ATP6',
#   'MT-CYB',
#   'NFAT5'],
#  'A549_S-Ruxolitinib (INCB018424)_100.0': [],
#  'A549_Gandotinib (LY2784544)_10.0': [],
#  'A549_Pirarubicin_10.0': [],
#  'A549_CUDC-907_100.0': ['MALAT1',
#   'MACROD2',
#   'MT-ND5',
#   'TFPI2',
#   'CYP24A1',
#   'ANXA1',
#   'MT-CO1',
#   'BCL2L1',
#   'AC008014.1',
#   'MYO1E',
#   'MT-CYB',
#   'MT-ND4',
#   'CLU',
#   'MALAT1-1',
#   'PSAP',
#   'MT-CO3',
#   'TXNRD1',
#   'IGFL2-AS1',
#   'RDX',
#   'LUCAT1',
#   'AC002066.1',
#   'TARID',
#   'ZMYND8',
#   'GPRC5A',
#   'BABAM2',
#   'MAP2',
#   'IGF1R',
#   'RORA',
#   'AC108062.1',
#   'ZNF217',
#   'SAT1',
#   'PLD1',
#   'DOCK5',
#   'VMP1',
#   'AUTS2',
#   'MT-ATP6',
#   'NEAT1',
#   'ZFPM2-AS1',
#   'GMDS',
#   'ASPM',
#   'ME1',
#   'MGST1',
#   'GPX2',
#   'CPLX2',
#   'CENPF',
#   'TUBB',
#   'ALDH3A1',
#   'TOP2A',
#   'AC016205.1',
#   'PGD',
#   'HNF1A-AS1',
#   'KRT81',
#   'ABCC3',
#   'PDE10A',
#   'MKI67',
#   'SLC7A5',
#   'CA12',
#   'AKR1B10'],
#  'A549_SRT1720 HCl_1000.0': [],
#  'A549_Tacedinaline (CI994)_10000.0': ['MALAT1',
#   'ANXA1',
#   'SCD',
#   'CYP24A1',
#   'FNDC3B',
#   'CYB5B',
#   'MYO1E',
#   'MACROD2',
#   'MT-CO3',
#   'SLC23A2',
#   'RERE',
#   'SYT1',
#   'DOCK5',
#   'MT-ND5',
#   'SAT1',
#   'AC108062.1',
#   'NEAT1',
#   'LIPE-AS1',
#   'MT-ND4',
#   'HIF1A',
#   'AUTS2',
#   'PRAG1',
#   'UBE2E2',
#   'CAST',
#   'KRT8',
#   'MALAT1-1',
#   'RORA',
#   'USP9X',
#   'SIPA1L3',
#   'THSD7A',
#   'MGST1',
#   'SLC7A11',
#   'ALDH1A1',
#   'SLC7A5',
#   'CSGALNACT1',
#   'PGD',
#   'HNF1A-AS1',
#   'KRT81',
#   'PDE10A',
#   'ALDH3A1',
#   'GAPDH',
#   'AKR1B10',
#   'ABCC2',
#   'ABCC3'],
#  'A549_Barasertib (AZD1152-HQPA)_1000.0': ['NEAT1',
#   'MDM2',
#   'ALDH3A1',
#   'MT-ATP6',
#   'MT-CO3'],
#  'A549_Zileuton_1000.0': [],
#  'A549_AICAR (Acadesine)_1000.0': [],
#  'A549_Fulvestrant_10.0': [],
#  'A549_Momelotinib (CYT387)_10.0': [],
#  'A549_Zileuton_10.0': [],
#  'A549_Baricitinib (LY3009104, INCB028050)_1000.0': [],
#  'A549_PFI-1 (PF-6405761)_10.0': [],
#  'A549_2-Methoxyestradiol (2-MeOE2)_10.0': [],
#  'A549_G007-LK_1000.0': [],
#  'A549_Dasatinib_100.0': ['MALAT1', 'MT-ND2', 'AKR1B10', 'AKR1C3', 'GAPDH'],
#  'A549_AG-14361_10000.0': ['ALDH3A1', 'MT-CO3', 'PKM', 'ANXA2'],
#  'A549_Nilotinib (AMN-107)_10.0': [],
#  'A549_Busulfan _10000.0': [],
#  'A549_TAK-901_1000.0': ['MDM2',
#   'LINC01021',
#   'MT-CO1',
#   'MT-ATP6',
#   'MT-CO3',
#   'MKLN1',
#   'LRP10',
#   'SQSTM1',
#   'MT-CYB',
#   'NFAT5',
#   'NRG1',
#   'MT-ATP8',
#   'PSAP',
#   'MT-ND5',
#   'MKI67'],
#  'A549_(+)-JQ1_10000.0': ['NEAT1',
#   'FTL',
#   'MALAT1',
#   'TXNRD1',
#   'SQSTM1',
#   'PKM',
#   'G6PD',
#   'KRT8',
#   'GAPDH',
#   'HSP90AA1',
#   'RPLP1',
#   'TPI1',
#   'MT-ND5',
#   'PCYOX1',
#   'ENO1',
#   'ALDOA',
#   'PDE4B',
#   'PTPRM',
#   'CACNA2D1',
#   'C9orf3',
#   'NPAS2',
#   'FAM107B',
#   'MT-RNR2',
#   'EGLN1',
#   'CNTNAP3B',
#   'PAPPA',
#   'PDE3A',
#   'LPP',
#   'TTC28',
#   'PDE4D',
#   'CPLX2',
#   'MYO10',
#   'CACNA1D',
#   'LINC00511',
#   'TBC1D8',
#   'MED13L',
#   'GLIS3',
#   'SHANK2',
#   'ZBTB20',
#   'ARHGAP26',
#   'KYNU',
#   'MAML3',
#   'CYP24A1',
#   'MAP7',
#   'PDLIM5',
#   'ABCC2',
#   'RAD51B',
#   'BMPR1B',
#   'MTUS1',
#   'EHBP1',
#   'MYO1E',
#   'AGR2',
#   'HNF1A-AS1',
#   'TNS3',
#   'SIPA1L3',
#   'CSGALNACT1',
#   'CNTN1',
#   'PDE10A',
#   'ABCC3',
#   'CUX1',
#   'THSD4'],
#  'A549_EED226_100.0': [],
#  'A549_CEP-33779_10000.0': ['MT-ND1', 'MT-ND2', 'ALDH3A1', 'MT-ND4'],
#  'A549_Prednisone _10000.0': [],
#  'A549_Glesatinib?(MGCD265)_10.0': [],
#  'A549_Dasatinib_10.0': [],
#  'A549_PD98059_10000.0': [],
#  'A549_JNJ-7706621_100.0': [],
#  'A549_UNC1999_100.0': [],
#  'A549_Disulfiram _100.0': [],
#  'A549_SL-327_10000.0': ['MALAT1',
#   'NEAT1',
#   'MT-ATP6',
#   'KRT81',
#   'MT-ATP8',
#   'AGR2',
#   'MT-ND4L',
#   'MT-CO2',
#   'MT-CO3',
#   'MT-ND4',
#   'MT-CO1',
#   'MT-ND2',
#   'MT-ND1',
#   'MT-ND5'],
#  'A549_RG108_10.0': [],
#  'A549_INO-1001 (3-Aminobenzamide)_10000.0': [],
#  'A549_Navitoclax (ABT-263)_10000.0': ['KRT7',
#   'MAP1B',
#   'KRT81',
#   'ANKRD11',
#   'FLNB',
#   'G6PD',
#   'FLNA',
#   'PKM',
#   'ENO1',
#   'SERPINE1',
#   'PLEC',
#   'SQSTM1',
#   'AKAP12',
#   'KRT18',
#   'SLC35F3',
#   'MYOF',
#   'HSPA5',
#   'ACTN4',
#   'EGFR',
#   'EREG',
#   'ACTG1',
#   'NRG1',
#   'SAMD4A',
#   'ITGB1',
#   'TRIO',
#   'ANXA4',
#   'CNTN1',
#   'LINC00511',
#   'GPX2',
#   'RAB10',
#   'SLC12A2',
#   'MT-CYB',
#   'MT-CO2',
#   'MT-ND4L',
#   'PDE4D',
#   'MT-ND1',
#   'MT-ATP6',
#   'MT-ND4',
#   'MT-ATP8',
#   'MT-ND2',
#   'MT-ND5',
#   'MT-CO3',
#   'MT-RNR1',
#   'MT-CO1',
#   'MT-RNR2'],
#  'A549_GSK1070916_10000.0': ['FADS1',
#   'SQSTM1',
#   'SCD',
#   'MDM2',
#   'MT-CO3',
#   'FTL',
#   'NEAT1',
#   'MALAT1',
#   'MT-CO1',
#   'CA12',
#   'SYNE2',
#   'RPL13A',
#   'MT-CO2',
#   'MT-ND4',
#   'FADS2',
#   'HMGCS1',
#   'DHCR7',
#   'NFAT5',
#   'ALCAM',
#   'TFPI',
#   'MT-ND5',
#   'CYB5B',
#   'PSAP',
#   'LINC01021',
#   'MT-ATP6',
#   'CTSD',
#   'IGFL2-AS1',
#   'RPS16',
#   'NRG1',
#   'THSD7A',
#   'LDLR',
#   'NAMPT',
#   'RPS12',
#   'FLVCR1',
#   'FASN',
#   'MKI67',
#   'TOP2A',
#   'AC016205.1'],
#  'A549_TMP195_10.0': [],
#  'A549_Zileuton_10000.0': [],
#  'A549_WP1066_1000.0': [],
#  'A549_Tozasertib (VX-680, MK-0457)_10.0': [],
#  'A549_Pelitinib (EKB-569)_10000.0': ['MALAT1',
#   'SQSTM1',
#   'IGFL2-AS1',
#   'CA12',
#   'IMMP2L',
#   'HNF1A-AS1',
#   'MALAT1-1',
#   'SLC12A2',
#   'KYNU',
#   'MT-RNR1',
#   'MT-CO3',
#   'MT-CO1',
#   'KRT18',
#   'MT-ND2',
#   'MT-ND1'],
#  'A549_Prednisone _100.0': [],
#  'A549_Triamcinolone Acetonide_10.0': ['FKBP5',
#   'BTBD11',
#   'KRT18',
#   'TBC1D8',
#   'KRT8',
#   'DOCK4',
#   'AKAP13',
#   'ERRFI1',
#   'NEAT1',
#   'SDK2',
#   'ZBTB20',
#   'PYGB',
#   'KRT7',
#   'FGD4',
#   'EPB41L4A',
#   'MALAT1',
#   'ABHD2',
#   'MEGF9',
#   'ANXA2',
#   'SERPINE1',
#   'AHNAK',
#   'CAPN2',
#   'TFCP2L1',
#   'PHLDB2',
#   'JAK1',
#   'PCDH9',
#   'STOM',
#   'AHNAK2',
#   'FGD6',
#   'NQO1',
#   'CAST',
#   'EML4',
#   'PDLIM5',
#   'CLU',
#   'MID1',
#   'PDE8A',
#   'CA12',
#   'CSGALNACT1',
#   'CENPF',
#   'AC016205.1',
#   'BSG',
#   'MKI67',
#   'NPAS2',
#   'AGR2',
#   'GAPDH',
#   'MYO10',
#   'FAM107B',
#   'KYNU',
#   'SLC7A11',
#   'MAP7',
#   'FTL',
#   'CYP24A1',
#   'AKR1B10',
#   'PDE10A',
#   'SLC12A2'],
#  'A549_Tranylcypromine (2-PCPA) HCl_10000.0': ['MT-CO3'],
#  'A549_AZ 960_10.0': [],
#  'A549_Anacardic Acid_10.0': [],
#  'A549_ABT-737_10.0': [],
#  'A549_Tubastatin A HCl_10000.0': ['MT-CO3'],
#  'A549_PF-573228_1000.0': [],
#  'A549_Daphnetin_10000.0': [],
#  'A549_Valproic acid sodium salt (Sodium valproate)_100.0': [],
# ...
#  'MCF7_(+)-JQ1_100.0': ['NEAT1',
#   'SLC12A2',
#   'NCOA3',
#   'KRT19',
#   'KRT8',
#   'GPRC5A',
#   'GAPDH',
#   'TRIM33',
#   'NQO1',
#   'SIDT1',
#   'TRIM56',
#   'AMZ1',
#   'PLXDC2',
#   'GREB1',
#   'DSCAM-AS1',
#   'CHD9',
#   'TMEM164',
#   'BRIP1',
#   'RAB31',
#   'ATRNL1',
#   'IRS1',
#   'NRCAM',
#   'AL138720.1',
#   'SCUBE2',
#   'CCDC170',
#   'MIR4713HG',
#   'ADCY1',
#   'HSPB1',
#   'NAALADL2',
#   'AC099520.1',
#   'HMCN1',
#   'MALRD1',
#   'SDK1',
#   'EMP2',
#   'NCKAP5',
#   'ZMYND8',
#   'INPP4B',
#   'SEMA3C',
#   'DSCAM',
#   'SULF2',
#   'GFRA1',
#   'AC112206.2'],
#  'MCF7_SB431542_10.0': [],
#  'MCF7_Filgotinib (GLPG0634)_100.0': [],
#  'MCF7_Valproic acid sodium salt (Sodium valproate)_100.0': [],
#  'MCF7_AZ 960_10000.0': ['NEAT1', 'MALAT1', 'MLPH', 'RAB10'],
#  'MCF7_Resminostat_1000.0': ['KRT8',
#   'KRT19',
#   'CTSD',
#   'NEAT1',
#   'ABCA12',
#   'MALAT1',
#   'MT-CO1',
#   'TPM4',
#   'VMP1',
#   'ADAMTSL4-AS1',
#   'KRT18',
#   'SCD',
#   'SPTSSB',
#   'FHIT',
#   'ZNF217',
#   'BCAS4',
#   'DNMBP',
#   'AC099520.1',
#   'SAMD12',
#   'USP34',
#   'FANCA',
#   'CENPP',
#   'BRIP1'],
#  'MCF7_PHA-680632_10.0': [],
#  'MCF7_Ellagic acid_10000.0': [],
#  'MCF7_S3I-201_100.0': ['MT-RNR2'],
#  'MCF7_Trichostatin A (TSA)_10.0': [],
#  'MCF7_Pracinostat (SB939)_100.0': ['KRT19',
#   'KRT8',
#   'NCOA3',
#   'CTSD',
#   'DSCAM',
#   'TANC2',
#   'KRT18',
#   'SAMD12',
#   'VMP1',
#   'ABCA12',
#   'KYNU',
#   'IGF1R',
#   'MALAT1',
#   'NEAT1',
#   'ZMYND8',
#   'BCAS3',
#   'TPM4',
#   'PACS1',
#   'AC099520.1',
#   'NAV1',
#   'FLNA',
#   'ACTG1',
#   'G6PD',
#   'HSPB1',
#   'HSH2D',
#   'HMCN1',
#   'ACTB',
#   'PTPRK',
#   'RIMS2',
#   'MYO5C',
#   'AC005746.2',
#   'TAPBP',
#   'IFI6',
#   'TP53',
#   'NCAPG2',
#   'AC016205.1',
#   'MT-ND4L',
#   'BRCA1',
#   'LINC01572',
#   'NIPBL',
#   'CTCF',
#   'RPRD2',
#   'SPIDR',
#   'ELP2',
#   'MKI67',
#   'MACROD2',
#   'MT-CO3',
#   'RNF216',
#   'ESR1',
#   'MT-ND2',
#   'FANCA',
#   'MED13',
#   'SRRM2',
#   'CREBBP',
#   'BRCA2',
#   'CSE1L',
#   'MT-CO1',
#   'KAT6B',
#   'MT-ATP6',
#   'ADAMTS19',
#   'STAG1',
#   'NUCKS1',
#   'MT-ND5',
#   'ATAD2',
#   'BPTF',
#   'CENPP',
#   'BRIP1'],
#  'MCF7_Temsirolimus (CCI-779, NSC 683864)_1000.0': ['BCAS3',
#   'MALAT1',
#   'BCAS4',
#   'CCSER1',
#   'BRIP1',
#   'SCD',
#   'GAPDH'],
#  'MCF7_PF-573228_10.0': [],
#  'MCF7_Mesna _100.0': [],
#  'MCF7_Patupilone (EPO906, Epothilone B)_10000.0': ['TPX2', 'TUBB', 'WWOX'],
#  'MCF7_Alendronate sodium trihydrate_100.0': ['NEAT1'],
#  'MCF7_GSK-LSD1 2HCl_10.0': ['OVOL2'],
#  'MCF7_TGX-221_10.0': [],
#  'MCF7_Regorafenib (BAY 73-4506)_10000.0': ['MALAT1',
#   'NEAT1',
#   'MALAT1-1',
#   'HSPB1',
#   'BCAS3',
#   'BCAS4',
#   'GAS5',
#   'NCOA3',
#   'REXO5',
#   'MT-CO2',
#   'FBXL17',
#   'RMND1',
#   'LRP1B',
#   'HSPA8',
#   'FRYL',
#   'PTPRG',
#   'SFXN2',
#   'SYTL2',
#   'THADA',
#   'IRS1',
#   'KAT6B',
#   'GATA3',
#   'TMEM164',
#   'ADAMTS19',
#   'TPM4',
#   'MT-RNR2',
#   'MT-ND4L',
#   'NRIP1',
#   'MT-ND5',
#   'MALRD1',
#   'MT-ND4',
#   'MT-ATP8',
#   'MT-ND1',
#   'THSD4',
#   'ESR1',
#   'PLXDC2',
#   'GPC6',
#   'GFRA1',
#   'WWOX',
#   'MT-RNR1',
#   'MT-CO1',
#   'SEMA3C',
#   'MT-ND2',
#   'MT-ATP6',
#   'MT-CYB',
#   'MT-CO3'],
#  'MCF7_TMP195_100.0': [],
#  'MCF7_M344_1000.0': ['AC099520.1',
#   'CTSD',
#   'ABCA12',
#   'MT-CO1',
#   'MT-RNR2',
#   'MT-RNR1',
#   'FTX',
#   'TPM4',
#   'ZNF217',
#   'ZMYND8',
#   'DSCAM-AS1',
#   'KRT19',
#   'MT-ND4',
#   'SAMD12',
#   'KRT8',
#   'NEAT1',
#   'DSCAM',
#   'MT-ND5',
#   'S100A10',
#   'MT-CO2',
#   'MALAT1',
#   'CLU',
#   'AC103770.1',
#   'VMP1',
#   'KRT18',
#   'MT-CYB',
#   'KIAA1217',
#   'MKI67',
#   'STAG1',
#   'NCAPG2',
#   'NDUFAF6',
#   'MACROD2',
#   'SYNE2',
#   'NUCKS1',
#   'SRRM2',
#   'FANCA',
#   'ATAD2',
#   'CENPP',
#   'BRIP1'],
#  'MCF7_CEP-33779_100.0': [],
#  'MCF7_FLLL32_10.0': [],
#  'MCF7_Linifanib (ABT-869)_1000.0': [],
#  'MCF7_Trametinib (GSK1120212)_10.0': ['KRT19',
#   'GPC6',
#   'CALCR',
#   'MYOF',
#   'KRT8',
#   'SLC24A3',
#   'HSPB1',
#   'FLNB',
#   'TMEM64',
#   'KRT18',
#   'BRCA2',
#   'CENPP',
#   'TPM4',
#   'SEPT9',
#   'BRIP1',
#   'UGDH',
#   'PVT1',
#   'TIAM1',
#   'AREG',
#   'ADAMTSL4-AS1',
#   'INPP4B',
#   'BMP7'],
#  'MCF7_PHA-680632_10000.0': ['TFF1',
#   'KIAA1324',
#   'MT-CO2',
#   'MT-ATP6',
#   'UBE2H',
#   'MLPH',
#   'MT-CYB',
#   'COX6C',
#   'MT-ND4',
#   'RABEP1',
#   'SLC12A2',
#   'MT-ATP8',
#   'SLC39A6',
#   'ST3GAL1',
#   'NAV1',
#   'EVL',
#   'MT-RNR2',
#   'LARGE1',
#   'ERC2',
#   'PMEPA1',
#   'CENPP',
#   'PRKDC',
#   'ATAD2',
#   'SYNE2',
#   'INPP4B',
#   'TANC2',
#   'CCND1',
#   'FANCA',
#   'NUCKS1',
#   'BRIP1',
#   'BMP7',
#   'SULF2',
#   'SEMA3C'],
#  'MCF7_Selisistat (EX 527)_100.0': [],
#  'MCF7_Givinostat (ITF2357)_10000.0': ['COL26A1',
#   'PPM1E',
#   'RPL3L',
#   'TEX14',
#   'CEACAM22P',
#   'MALAT1',
#   'MARCH6',
#   'NPC1',
#   'NEAT1',
#   'LINC02506',
#   'ACSL3',
#   'AC008050.1',
#   'PHF14',
#   'ACSBG1',
#   'RAE1',
#   'TNFRSF10B',
#   'LINC00624',
#   'UBR3',
#   'ZSWIM6',
#   'DHRS2',
#   'INSIG1',
#   'MORF4L1',
#   'PARP16',
#   'RGL1',
#   'AL356804.1',
#   'NCOA3',
#   'AC092957.1',
#   'AP000769.1',
#   'SPAG9',
#   'MFSD8',
#   'KNTC1',
#   'PTPN1',
#   'MALAT1-1',
#   'HMGCR',
#   'ADAMTSL4-AS1',
#   'AKAP13',
#   'EXT1',
#   'AC008736.1',
#   'TYW1B',
#   'TOR1AIP2',
#   'SREBF1',
#   'CCNYL1',
#   'TRIM37',
#   'TIMP3',
#   'GGNBP1',
#   'CLU',
#   'IDI1',
#   'CEACAM20',
#   'PSAP',
#   'DENND2C',
#   'NBEA',
#   'DPM1',
#   'EXOC6B',
#   'FDFT1',
#   'VCL',
#   'HCG27',
#   'LPIN1',
#   'GCLC',
#   'LINC02204',
#   'ZFP90',
#   'DNAJC1',
#   'CCSER2',
#   'MACROD2',
#   'HIST1H2BG',
#   'RNFT2',
#   'RALGAPA2',
#   'NR6A1',
#   'SQSTM1',
#   'LINC02328',
#   'LINC02158',
#   'VMP1',
#   'GRB2',
#   'PLD3',
#   'AC110285.6',
#   'HIP1',
#   'ARHGAP26',
#   'COG5',
#   'TRIM2',
#   'ERBB4',
#   'XPR1',
#   'TUBA1A',
#   'CCDC88A',
#   'NME7',
#   'CGREF1',
#   'PCBP3',
#   'CEP112',
#   'BOLA1',
#   'SLC35F4',
#   'TASP1',
#   'ETV7',
#   'HIST1H2BD',
#   'TAOK3',
#   'RPS5',
#   'AGTPBP1',
#   'JPT1',
#   'GUSBP1',
#   'SORBS1',
#   'TEX2',
#   'HIST1H4H',
#   'UBE4A',
#   'PIP5K1A',
#   'ROBO1',
#   'AC093001.1',
#   'ODC1',
#   'PMEL',
#   'TMBIM6',
#   'FBXL2',
#   'FBXO33',
#   'CDC14B',
#   'GNS',
#   'SGPL1',
#   'P4HB',
#   'ACTG1',
#   'DHCR7',
#   'RAD51B',
#   'FBP2',
#   'ATP2B4',
#   'TCN2',
#   'CLEC16A',
#   'SBNO1',
#   'KIDINS220',
#   'ACACA',
#   'CPEB4',
#   'CYP46A1',
#   'HMGCS1',
#   'RNF19A',
#   'ZKSCAN1',
#   'MTHFR',
#   'LDLR',
#   'LIMA1',
#   'APLP2',
#   'TMPRSS9',
#   'C1orf228',
#   'LIPE-AS1',
#   'AGMO',
#   'SPTAN1',
#   'GBF1',
#   'COTL1',
#   'LSS',
#   'TMEM135',
#   'GPR155',
#   'ATP6V0D1',
#   'NEU1',
#   'DDIT3',
#   'SCD',
#   'LMTK3',
#   'PCYOX1',
#   'ACAP2',
#   'MAP3K13',
#   'DNAI1',
#   'GLS',
#   'ZCCHC14',
#   'UBE2H',
#   'H3F3B',
#   'CALN1',
#   'LINC00243',
#   'USP49',
#   'ATP6V1D',
#   'ZBTB20',
#   'POR',
#   'GDE1',
#   'GPR137C',
#   'P4HA1',
#   'SSBP2',
#   'CPM',
#   'GM2A',
#   'BBS9',
#   'ZHX3',
#   'MCCC1',
#   'KDM5B',
#   'SEL1L',
#   'ACSS2',
#   'ABTB2',
#   'SND1',
#   'ALDOC',
#   'NXN',
#   'SEZ6L2',
#   'PABPC1',
#   'LINC02484',
#   'ATG4B',
#   'BAIAP2L1',
#   'CALU',
#   'MT-CO1',
#   'PPM1D',
#   'NBEAL1',
#   'XRRA1',
#   'LPCAT3',
#   'KIF5C',
#   'AC010197.1',
#   'LINC01291',
#   'DAD1',
#   'IRGM',
#   'AC138819.1',
#   'FAM117A',
#   'RSU1',
#   'ACLY',
#   'DACH2',
#   'FHIT',
#   'DOCK4',
#   'TENM1',
#   'PHF2P2',
#   'RNF114',
#   'CRISPLD2',
#   'WDR47',
#   'LINC00674',
#   'CCDC47',
#   'ATP6V0A1',
#   'FRMD5',
#   'CYTH3',
#   'DNAH3',
#   'ULK4',
#   'AC139491.2',
#   'MAP2',
#   'ACOT7',
#   'ELL2',
#   'FADS1',
#   'RERE',
#   'HERC1',
#   'HOMER1',
#   'GDPD1',
#   'CLTC',
#   'RPL28',
#   'TTC37',
#   'STAT3',
#   'CADM2',
#   'RNFT1',
#   'AC010168.2',
#   'IQCH',
#   'PCLO',
#   'PPFIA1',
#   'SRRM3',
#   'PCDH9',
#   'AMN1',
#   'LMTK2',
#   'DENND4A',
#   'TMOD2',
#   'ARIH1',
#   'HIST1H3J',
#   'PIAS1',
#   'PGM2L1',
#   'SLC4A8',
#   'DPF3',
#   'SH3GL3',
#   'HIST1H2BN',
#   'CLIP2',
#   'IFT88',
#   'UBAP2',
#   'ARF4',
#   'PPARD',
#   'MAN1A1',
#   'AC005006.1',
#   'WSCD1',
#   'ZER1',
#   'MAGT1',
#   'CALM1',
#   'ABCB9',
#   'SLC16A10',
#   'NCEH1',
#   'FAM91A1',
#   'NR4A3',
#   'PAG1',
#   'AC007216.4',
#   'STK3',
#   'FSTL5',
#   'C4orf22',
#   'TUFT1',
#   'KTN1',
#   'FTCD',
#   'KIF3A',
#   'CYP4F2',
#   'OLMALINC',
#   'RARS',
#   'MT1X',
#   'FAM234A',
#   'USP9X',
#   'GLCE',
#   'ENOX1',
#   'GPATCH2L',
#   'LAMP2',
#   'OSBPL8',
#   'ADAMTS6',
#   'VPS53',
#   'FAM105A',
#   'PTPRN2',
#   'ELOVL5',
#   'G6PD',
#   'CLEC4C',
#   'BSG',
#   'WDR70',
#   'ZKSCAN5',
#   'NOSIP',
#   'OTUD7A',
#   'FAM126B',
#   'EGLN3',
#   'ERN1',
#   'LINC02296',
#   'AC012435.1',
#   'HSP90AA1',
#   'MLF1',
#   'NARS2',
#   'ZNF217',
#   'TXNDC16',
#   'SPTLC2',
#   'SLC9A1',
#   'SMIM8',
#   'TM7SF2',
#   'NSMCE2',
#   'DLG2',
#   'THEM4',
#   'LINC01647',
#   'SYT11',
#   'GMCL1',
#   'SCHLAP1',
#   'EXTL3',
#   'SIRT2',
#   'ATP6V1A',
#   'CLTCL1',
#   'TOP1',
#   'PTPRG-AS1',
#   'HABP4',
#   'AAMDC',
#   'NEK1',
#   'MED9',
#   'PPP4R4',
#   'TMEM41B',
#   'SQLE',
#   'PKM',
#   'KREMEN1',
#   'SPATA5',
#   'MT-ND5',
#   'BCKDHB',
#   'WDR44',
#   'WDR17',
#   'EVI5',
#   'RFC1',
#   'CDKL5',
#   'LGMN',
#   'CALR',
#   'TXNRD1',
#   'DCAF7',
#   'FTL',
#   'TNIK',
#   'PRIM2',
#   'EPPK1',
#   'MAP1LC3B',
#   'SNAPC1',
#   'ITPR1',
#   'RBM10',
#   'PTBP2',
#   'ZNF785',
#   'CPA6',
#   'GALNT7',
#   'HNRNPA1',
#   'S100A10',
#   'COMMD10',
#   'E2F3',
#   'ATRAID',
#   'ZNF148',
#   'SF3B3',
#   'TRA2A',
#   'CDK17',
#   'PKP4',
#   'MIR34AHG',
#   'EIF4G2',
#   'BRCA1',
#   'KIF21A',
#   'CARMIL1',
#   'ADAR',
#   'ADCY3',
#   'MYBL2',
#   'ITGB5',
#   'TPBG',
#   'SLC9A2',
#   'FAM35A',
#   'S100A16',
#   'PLK2',
#   'RMST',
#   'NELFCD',
#   'PTBP3',
#   'NFKB1',
#   'BCAS4',
#   'SON',
#   'FAM83H',
#   'UBXN4',
#   'DIP2B',
#   'RGS3',
#   'TPI1',
#   'GPATCH8',
#   'CBFA2T3',
#   'SLC2A10',
#   'PCNX1',
#   'RPL7A',
#   'MAVS',
#   'LMX1B',
#   'SMARCA4',
#   'UBA2',
#   'NIPBL',
#   'TFAP2C',
#   'SMARCB1',
#   'HSPA9',
#   'PRSS23',
#   'RACK1',
#   'SGCG',
#   'ANKRD11',
#   'ABHD12',
#   'BCLAF1',
#   'DDOST',
#   'PIP4K2A',
#   'MED13L',
#   'PRR12',
#   'UBE4B',
#   'SULT2B1',
#   'BBX',
#   'JADE2',
#   'UBE2R2',
#   'CHD9',
#   'LMNB1',
#   'TSC22D1',
#   'DNMT1',
#   'NUMA1',
#   'ZBTB1',
#   'WAC',
#   'NRBP1',
#   'CHD6',
#   'MBNL1',
#   'DGKH',
#   'POU2F1',
#   'ARPC2',
#   'ZC3HAV1',
#   'TRIP11',
#   'SLC25A29',
#   'SPIN1',
#   'NRG3',
#   'ZNF33A',
#   'SETDB1',
#   'AGPAT3',
#   'PBRM1',
#   'SMURF2',
#   'PSPC1',
#   'DOCK7',
#   'CRAT37',
#   'SMARCC1',
#   'BAGE2',
#   'PDE8A',
#   'JAK2',
#   'HIPK3',
#   'PRC1',
#   'NPM1',
#   'NPNT',
#   'PLEC',
#   'GRIP1',
#   'CHD3',
#   'KRT80',
#   'ATF5',
#   'PTPN14',
#   'CLIP1',
#   'ARSD',
#   'LSM14A',
#   'H2AFY',
#   'ATRNL1',
#   'AC097515.1',
#   'PHC3',
#   'REST',
#   'SPATS2L',
#   'LRMDA',
#   'MDM2',
#   'KLHL36',
#   'FANCI',
#   'RNF115',
#   'MRPS18B',
#   'EEF2K',
#   'KDM3B',
#   'PCBD2',
#   'TACC1',
#   'HNRNPK',
#   'DIP2C',
#   'N4BP3',
#   'IRF3',
#   'PPP4R3B',
#   'DIAPH3',
#   'ZFP36L2',
#   'LINC01290',
#   'ATIC',
#   'ABCA12',
#   'BCAS1',
#   'PTPA',
#   'KCNK1',
#   'SH3BGRL',
#   'CBX5',
#   'CCNY',
#   'BTBD7',
#   'DLC1',
#   'MIR193BHG',
#   'METTL16',
#   'CYC1',
#   'RDX',
#   'ZNF652',
#   'RAPGEF1',
#   'MYO1B',
#   'RFWD2',
#   'YAP1',
#   'SERPINA3',
#   'GPD2',
#   'XRCC5',
#   'DST',
#   'SLC25A21',
#   'TRIM28',
#   'PFKL',
#   'CABLES1',
#   'AREG',
#   'CD151',
#   'FXYD3',
#   'BMPR1A',
#   'ARMT1',
#   'HNRNPA2B1',
#   'PCSK6',
#   'TMPO',
#   'HS3ST3A1',
#   'LRP5',
#   'DDX17',
#   'NIPAL2',
#   'SLC1A5',
#   'UBL3',
#   'ARHGEF10L',
#   'STARD13',
#   'SLC37A1',
#   'EIF3A',
#   'AC090502.1',
#   'GSPT1',
#   'ABR',
#   'SLCO3A1',
#   'TCERG1',
#   'NUP62',
#   'DENND4C',
#   'SGMS1',
#   'NEK7',
#   'NCAPG2',
#   'ARHGAP11B',
#   'TMCC1',
#   'MZT2A',
#   'REEP3',
#   'USP3',
#   'TRERF1',
#   'LINC-PINT',
#   'N4BP2L2',
#   'ATXN7',
#   'MCM9',
#   'RHOD',
#   'PRR11',
#   'CLSTN1',
#   'GPR107',
#   'WNK1',
#   'PRKCH',
#   'BMP7',
#   'NCOA6',
#   'ASPM',
#   'KAZN',
#   'CD24',
#   'TOP2B',
#   'ATRX',
#   'ZNF718',
#   'PRKAR1B',
#   'NPEPPS',
#   'CKAP4',
#   'SLC25A24',
#   'KDM2A',
#   'SPOPL',
#   'AL139383.1',
#   'YY1',
#   'TBL1XR1',
#   'RBM39',
#   'AL354993.2',
#   'MCM4',
#   'EPS15',
#   'SOS2',
#   'PHACTR2',
#   'EPS15L1',
#   'DEK',
#   'ZMYM2',
#   'PARD6B',
#   'AVL9',
#   'CENPB',
#   'PDS5A',
#   'HSPA8',
#   'SETD1B',
#   'ARHGAP24',
#   'TOM1L1',
#   'RN7SL674P',
#   'LURAP1L',
#   'ALCAM',
#   'JPX',
#   'HNRNPF',
#   'ARID1A',
#   'HS6ST3',
#   'SCMH1',
#   'TJP1',
#   'PTK2',
#   'MAZ',
#   'RERG',
#   'DNAJC22',
#   'TRIP12',
#   'THRB',
#   'AC099850.1',
#   'CSE1L',
#   'ACTN1',
#   'AC005746.2',
#   'JUP',
#   'FNBP4',
#   'DYRK1A',
#   'TRIO',
#   'ADGRG6',
#   'HMCN1',
#   'HMGB1',
#   'VGLL4',
#   'ASAP2',
#   'OSBPL10',
#   'C9orf3',
#   'COBLL1',
#   'SCRN1',
#   'ATAD2',
#   'DENND1A',
#   'HNRNPU',
#   'ARFGEF3',
#   'TOPBP1',
#   'UBTF',
#   'CAPN1',
#   'ATP5G2',
#   'LY6E',
#   'STARD10',
#   'HECW2',
#   'ATAD2B',
#   'MYB',
#   'CYB561',
#   'RPS8',
#   'APP',
#   'VSIG10',
#   'TUBB',
#   'NUP210',
#   'DCAF5',
#   'PFN1',
#   'SLTM',
#   'RASSF8',
#   'HCFC1',
#   'AL117329.1',
#   'STRN3',
#   'PTPRJ',
#   'MUC1',
#   'PCDH7',
#   'SH3D19',
#   'UBR5',
#   'LNPEP',
#   'JARID2',
#   'NPDC1',
#   'LRP10',
#   'MYH9',
#   'DICER1',
#   'NMD3',
#   'ST8SIA6',
#   'PTPRG',
#   'SLC25A25',
#   'MAP4',
#   'PIK3CB',
#   'KIF13A',
#   'RUNX1',
#   'MCCC2',
#   'FBP1',
#   'LPP',
#   'VAV2',
#   'PGR',
#   'EIF4G1',
#   'DANT2',
#   'MTA3',
#   'SPPL2A',
#   'KDM2B',
#   'XIAP',
#   'EEF1A2',
#   'NPAS3',
#   'FANCA',
#   'AF241726.2',
#   'DDAH1',
#   'THOC7',
#   'SRSF4',
#   'NCOA1',
#   'NXNL2',
#   'HACD2',
#   'EIF2AK2',
#   'SOS1',
#   'MAGED2',
#   'DOCK5',
#   'PHIP',
#   'LGALS3',
#   'ATXN7L1',
#   'ENOSF1',
#   'RTN4RL1',
#   'SMC4',
#   'FGF13',
#   'XPO1',
#   'DLEU2',
#   'EIF4G3',
#   'RPL10',
#   'BRCA2',
#   'BAZ1B',
#   'QKI',
#   'LGALS3BP',
#   'ST6GALNAC2',
#   'LONRF2',
#   'IQANK1',
#   'PUM2',
#   'SET',
#   'ARHGAP10',
#   'RAF1',
#   'PIEZO1',
#   'ERBIN',
#   'DDX6',
#   'NEBL',
#   'AC104170.1',
#   'TLK2',
#   'SPATS2',
#   'SOGA1',
#   'MIS18BP1',
#   'RALGPS2',
#   'RABL6',
#   'TENM3',
#   'PDXK',
#   'MAST4',
#   'FOXA1',
#   'MAP3K1',
#   'KCNK6',
#   'C6orf141',
#   'ZFR',
#   'GTF2IRD1',
#   'SLC44A1',
#   'PERP',
#   'CA12',
#   'RSF1',
#   'PTMA',
#   'SSFA2',
#   'RBPMS',
#   'ARFGEF1',
#   'S100A11',
#   'DIDO1',
#   'HNRNPUL1',
#   'AC134511.1',
#   'TPD52',
#   'GNB1',
#   'NAV1',
#   'CDV3',
#   'AGO2',
#   'KANSL1',
#   'UNK',
#   'KIAA1324',
#   'BIRC6',
#   'IGFBP4',
#   'IGFBP5',
#   'LPCAT1',
#   'NF1',
#   'LYPD6B',
#   'MAP4K3',
#   'SVIL',
#   'PLEKHA7',
#   'NAALADL2',
#   'RGS6',
#   'OPA3',
#   'RAI1',
#   'ESRP1',
#   'RXRA',
#   'SFXN2',
#   'C1orf21',
#   'FAM120A',
#   'MYO1C',
#   'ARSG',
#   'PARD3B',
#   'FAM49B',
#   'YWHAE',
#   'TET3',
#   'PDS5B',
#   'MAP3K20',
#   'STAG2',
#   'STC2',
#   'MB21D2',
#   'TBL1X',
#   'NFIB',
#   'MKI67',
#   'TAPBP',
#   'AC099520.1',
#   'ANP32B',
#   'HIPK2',
#   'LDLRAD4',
#   'ZNRF1',
#   'ZMYND11',
#   'SHISA9',
#   'GABPB2',
#   'MACROD1',
#   'NSD2',
#   'SH3BP5',
#   'AC016205.1',
#   'ATP8B1',
#   'PBX3',
#   'ATXN2',
#   'SLC6A14',
#   'TP53',
#   'UBE2E1',
#   'MAP7',
#   'BRWD1',
#   'TCF12',
#   'RPS29',
#   'PTPRK',
#   'LRP1B',
#   'B4GALT1',
#   'BCL2',
#   'HDGF',
#   'KYNU',
#   'GNA14',
#   'TCF25',
#   'PAN3',
#   'LARGE1',
#   'LARP1',
#   'BAZ1A',
#   'TLK1',
#   'EIF4B',
#   'FAM102A',
#   'AC104041.1',
#   'NCOR1',
#   'AGAP1',
#   'NOS1AP',
#   'TPM4',
#   'NT5C2',
#   'KIAA0368',
#   'AMZ1',
#   'ZHX2',
#   'CAP2',
#   'LINC01004',
#   'PTPRF',
#   'PAK2',
#   'TFF1',
#   'GPC6',
#   'ADCY1',
#   'MREG',
#   'SRGAP1',
#   'ENO1',
#   'TBC1D5',
#   'TET2',
#   'JMJD1C',
#   'SMIM14',
#   'CTCF',
#   'AC103770.1',
#   'HDGFL3',
#   'DCDC2',
#   'BAZ2B',
#   'SENP6',
#   'NFIC',
#   'APPBP2',
#   'CUEDC1',
#   'SIPA1L1',
#   'WDFY3',
#   'SCAF11',
#   'SDK1',
#   'KRT19',
#   'AHNAK',
#   'DNMBP',
#   'ASH1L',
#   'ITGB4',
#   'CLDN3',
#   'NECAB1',
#   'TPD52L1',
#   'USP34',
#   'KPNB1',
#   'PCED1B',
#   'NCOA2',
#   'ERBB3',
#   'GNAS',
#   'MED13',
#   'CDH1',
#   'CREBBP',
#   'REV3L',
#   'GPRC5A',
#   'CELSR1',
#   'BMPR2',
#   'AL138720.1',
#   'ALOX12P2',
#   'SRRM2',
#   'ATXN1',
#   'NRP1',
#   'FBXL17',
#   'TMEM164',
#   'NHSL1',
#   'HECTD1',
#   'RMND1',
#   'SIDT1',
#   'CALCR',
#   'ADNP',
#   'ARID1B',
#   'SYNE2',
#   'CTSD',
#   'SEPT9',
#   'MACF1',
#   'APBB2',
#   'RBM47',
#   'TBC1D9',
#   'CXXC5',
#   'FUT8',
#   'PBX1',
#   'SCUBE2',
#   'PATJ',
#   'RAB31',
#   'ELF1',
#   'RHOBTB3',
#   'GNAQ',
#   'NCKAP5',
#   'PRLR',
#   'PRRC2B',
#   'PLCB1',
#   'NR2F2',
#   'RPRD2',
#   'GNGT1',
#   'SMAD3',
#   'DLG5',
#   'CTBP2',
#   'CACNG4',
#   'ADAMTS19',
#   'MIR4713HG',
#   'TMEM64',
#   'TRIM56',
#   'STAG1',
#   'GTF2I',
#   'SHANK2',
#   'PRKCE',
#   'ZMYND8',
#   'TMEM150C',
#   'NSD1',
#   'PITPNC1',
#   'TANC2',
#   'AGR2',
#   'PARD3',
#   'MYO5C',
#   'ATP9A',
#   'FTX',
#   'PAWR',
#   'ARID2',
#   'FOXP1',
#   'DOCK1',
#   'UGDH',
#   'CCDC170',
#   'FAM83B',
#   'GRHL2',
#   'CELSR2',
#   'MYOF',
#   'MSI2',
#   'KAT6B',
#   'IRS1',
#   'PACS1',
#   'NUCKS1',
#   'ELP2',
#   'TNRC18',
#   'CSDE1',
#   'GSE1',
#   'ANK3',
#   'ZFHX3',
#   'AC112206.2',
#   'MALRD1',
#   'MLPH',
#   'XBP1',
#   'SLC24A3',
#   'SLC7A2',
#   'BPTF',
#   'DSCAM-AS1',
#   'TRPS1',
#   'SYTL2',
#   'DSP',
#   'NRIP1',
#   'EMP2',
#   'SPTSSB',
#   'SLC38A1',
#   'THSD4',
#   'HSPB1',
#   'DSCAM',
#   'PLXDC2',
#   'CCND1',
#   'SULF2',
#   'NRCAM',
#   'KRT8',
#   'PVT1',
#   'INPP4B',
#   'SLC39A6',
#   'SEMA3C',
#   'KRT18',
#   'GFRA1',
#   'CUX1',
#   'EVL',
#   'GATA3',
#   'ESR1',
#   'GREB1',
#   'IGF1R'],
#  'MCF7_Tubastatin A HCl_10000.0': ['MT-CO1',
#   'FHIT',
#   'SAMD12',
#   'DANT2',
#   'VMP1',
#   'ZNF217',
#   'PVT1',
#   'CTSD',
#   'BRIP1'],
#  'MCF7_Enzastaurin (LY317615)_100.0': [],
#  'MCF7_RG108_100.0': ['MT-CO1'],
#  'MCF7_Streptozotocin (STZ)_10.0': [],
#  'MCF7_FLLL32_1000.0': ['GAPDH'],
#  'MCF7_Lenalidomide (CC-5013)_1000.0': [],
#  ...}

# %%
with open("./all_degs.pkl", 'wb') as f:
    pkl.dump(all_degs, f)

# %%
gene_degs = list()
for key in all_degs.keys():
    gene_degs.extend(all_degs[key])

gene_degs = list(set(gene_degs))

# %%
len(gene_degs)
# Out:
# 3210

# %% [markdown]
# ## Feature Agreement between each pp condition

# %%
def get_feature_agreement(adata_pp):
    results = list()
    
    for feature_select_method in ['cell_ranger', 'seurat_v3', 'seurat']:
        for feature_number in [500, 1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000]:

            adata = adata_pp.copy()
            adata.obs['drug_celltype_dose'] = adata.obs['cell_type'].astype(str) + "_" + adata.obs['product_name'].astype(str) + "_" + adata.obs['dose'].astype(str)

            print("Runnign HVG Selection for:", feature_select_method, feature_number)
            
            if feature_select_method == "random":
                sc.pp.normalize_total(adata, inplace=True)
                sc.pp.log1p(adata)
                genes_random = random.sample(list(adata.var_names), feature_number)
                adata = adata[:, adata.var_names.isin(genes_random)].copy()

            elif feature_select_method == "seurat":
                sc.pp.normalize_total(adata, inplace=True)
                sc.pp.log1p(adata)
                sc.pp.highly_variable_genes(adata, flavor='seurat', n_top_genes=feature_number)
                adata = adata[:, adata.var['highly_variable']].copy()

            elif feature_select_method == "seurat_v3":
                sc.pp.highly_variable_genes(adata, flavor='seurat_v3', n_top_genes=feature_number)
                sc.pp.normalize_total(adata, inplace=True)
                sc.pp.log1p(adata)
                adata = adata[:, adata.var['highly_variable']].copy()

            elif feature_select_method == "cell_ranger":
                sc.pp.normalize_total(adata, inplace=True)
                sc.pp.log1p(adata)
                sc.pp.highly_variable_genes(adata, flavor='cell_ranger', n_top_genes=feature_number)
                adata = adata[:, adata.var['highly_variable']].copy()

            if adata.n_obs == 0:
                continue

            results.append({
                "feature_selection_method": feature_select_method,
                "n_features": feature_number,
                "genes": list(adata.var_names)
            })
    return results

# %%
feature_agreement = get_feature_agreement(adata_pp)
# Out:
# Runnign HVG Selection for: cell_ranger 500
# Runnign HVG Selection for: cell_ranger 1000
# Runnign HVG Selection for: cell_ranger 2000
# Runnign HVG Selection for: cell_ranger 3000
# Runnign HVG Selection for: cell_ranger 4000
# Runnign HVG Selection for: cell_ranger 5000
# Runnign HVG Selection for: cell_ranger 6000
# Runnign HVG Selection for: cell_ranger 7000
# Runnign HVG Selection for: cell_ranger 8000
# Runnign HVG Selection for: seurat_v3 500
# Runnign HVG Selection for: seurat_v3 1000
# Runnign HVG Selection for: seurat_v3 2000
# Runnign HVG Selection for: seurat_v3 3000
# Runnign HVG Selection for: seurat_v3 4000
# Runnign HVG Selection for: seurat_v3 5000
# Runnign HVG Selection for: seurat_v3 6000
# Runnign HVG Selection for: seurat_v3 7000
# Runnign HVG Selection for: seurat_v3 8000
# Runnign HVG Selection for: seurat 500
# Runnign HVG Selection for: seurat 1000
# Runnign HVG Selection for: seurat 2000
# Runnign HVG Selection for: seurat 3000
# Runnign HVG Selection for: seurat 4000
# Runnign HVG Selection for: seurat 5000
# Runnign HVG Selection for: seurat 6000
# Runnign HVG Selection for: seurat 7000
# Runnign HVG Selection for: seurat 8000

# %%
feature_agreement
# Out:
# [{'feature_selection_method': 'cell_ranger',
#   'n_features': 500,
#   'genes': ['CFH',
#    'SLC4A1',
#    'THSD7A',
#    'ACSM3',
#    'PRKAR2B',
#    'ETV1',
#    'TENM1',
#    'TYROBP',
#    'ALOX5',
#    'IGF1',
#    'SLC38A5',
#    'CNTN1',
#    'CYP24A1',
#    'CPS1',
#    'GRAMD1B',
#    'ABCC2',
#    'VIM',
#    'ANK1',
#    'VCAN',
#    'RIPOR3',
#    'ARHGAP6',
#    'CELF2',
#    'TNFRSF9',
#    'KCNH2',
#    'SLC2A3',
#    'BCAT1',
#    'LIMCH1',
#    'FAM107B',
#    'CD84',
#    'ACSL4',
#    'TGFBR3',
#    'FRMPD1',
#    'MYO3B',
#    'TP63',
#    'IGF2BP2',
#    'ST6GAL1',
#    'CA12',
#    'TXK',
#    'SEMA3A',
#    'SEMA3C',
#    'ARHGAP15',
#    'MCAM',
#    'ARG2',
#    'MEF2C',
#    'PTPRC',
#    'FYB1',
#    'SLCO1A2',
#    'AKR1B1',
#    'CEACAM6',
#    'CASS4',
#    'HEPH',
#    'LYZ',
#    'SEL1L3',
#    'NLRP1',
#    'ESR1',
#    'SORBS1',
#    'TPTEP1',
#    'GRAP2',
#    'DHRS2',
#    'GATA1',
#    'TIMP1',
#    'GABRE',
#    'FLT1',
#    'SLC7A5',
#    'ACSBG1',
#    'SCG3',
#    'CALB1',
#    'NCALD',
#    'TGFB1',
#    'SIGLEC6',
#    'TFPI2',
#    'STEAP1B',
#    'CPED1',
#    'EPHB6',
#    'TFR2',
#    'SERPINE1',
#    'POU6F2',
#    'PTGR1',
#    'GLIS3',
#    'GATA3',
#    'SORCS1',
#    'P2RX1',
#    'ALDH3A1',
#    'ABCC3',
#    'ALDOC',
#    'NMU',
#    'CTSC',
#    'SOX6',
#    'CEP85L',
#    'MAN1A1',
#    'RHAG',
#    'BACH2',
#    'PDE10A',
#    'VEGFA',
#    'PDE4D',
#    'BCL6',
#    'PFKFB4',
#    'FN1',
#    'IGFBP5',
#    'PLCL1',
#    'AC087235.1',
#    'EPHA4',
#    'AKT3',
#    'MUC5B',
#    'FILIP1',
#    'PLAGL1',
#    'RARRES1',
#    'GDA',
#    'ESRRB',
#    'HOXB3',
#    'MOB3B',
#    'EPX',
#    'TEX14',
#    'FAM117A',
#    'TMEM156',
#    'PAEP',
#    'SRGN',
#    'BICC1',
#    'P4HA1',
#    'NCKAP1L',
#    'CTCFL',
#    'PARD6B',
#    'DNAH8',
#    'SEPT6',
#    'STAT5A',
#    'FAM78A',
#    'PTPRB',
#    'ADGRE2',
#    'TPST2',
#    'RAC2',
#    'FLNC',
#    'PDE11A',
#    'ALDH1A2',
#    'MTUS1',
#    'EGLN3',
#    'ARHGEF6',
#    'APOE',
#    'HBZ',
#    'SLC6A8',
#    'PNCK',
#    'MPP1',
#    'AKAP12',
#    'ACSS2',
#    'LRRC4B',
#    'FCRLA',
#    'LINC00470',
#    'MYO18B',
#    'DOCK2',
#    'SOX5',
#    'SLC43A3',
#    'KCP',
#    'ADGRB3',
#    'CGA',
#    'KRT7',
#    'TEC',
#    'NPL',
#    'FAM129A',
#    'LCP1',
#    'TNS3',
#    'BRIP1',
#    'GALNT5',
#    'TMOD1',
#    'PIM1',
#    'GMPR',
#    'SLCO2B1',
#    'SYTL2',
#    'SLC44A5',
#    'ADAMTS14',
#    'CILP',
#    'FAM13A',
#    'BMP2K',
#    'STON2',
#    'CYP11A1',
#    'NTRK3',
#    'RPL3L',
#    'ABCA8',
#    'BCAS3',
#    'SLC39A6',
#    'MYO1F',
#    'SIGLEC10',
#    'CD53',
#    'ADAMTSL4',
#    'REN',
#    'PTPN7',
#    'ST6GAL2',
#    'PTH2R',
#    'IGSF11',
#    'IQGAP2',
#    'CPLX2',
#    'AIG1',
#    'VWDE',
#    'CREB5',
#    'IGFBP3',
#    'DOCK11',
#    'CSGALNACT1',
#    'SLC25A37',
#    'LRP12',
#    'FAM83A',
#    'FAM171A1',
#    'MS4A2',
#    'CNTN5',
#    'SLC7A11',
#    'BTBD11',
#    'AKR1C2',
#    'GFRA1',
#    'PDK1',
#    'PTPRR',
#    'CACNA2D1',
#    'CDH12',
#    'ANGPT1',
#    'ENPP3',
#    'TNIK',
#    'PPP1R3A',
#    'CNTNAP3B',
#    'SAMSN1',
#    'SLC16A1',
#    'SLC24A2',
#    'CFAP70',
#    'ADAMTS3',
#    'FRRS1',
#    'NRG1',
#    'ST3GAL2',
#    'MYO1E',
#    'TNFRSF14',
#    'DNAH3',
#    'ALAS2',
#    'EPB41',
#    'TFF1',
#    'GAB3',
#    'COL26A1',
#    'FBXL13',
#    'ITGA5',
#    'MEIOB',
#    'LAPTM5',
#    'BRINP3',
#    'SLAMF6',
#    'SPRR2D',
#    'ANTXR2',
#    'SPTA1',
#    'CDCP1',
#    'ADGRV1',
#    'EBF1',
#    'STXBP5',
#    'KIAA1324L',
#    'ALDH1A1',
#    'CLDN2',
#    'GABRB3',
#    'PRKCB',
#    'RBFOX3',
#    'CD3D',
#    'YIF1B',
#    'CD300A',
#    'NLRC3',
#    'XIRP1',
#    'RHOH',
#    'LRP1B',
#    'FAM178B',
#    'TM4SF20',
#    'ROR2',
#    'SCN9A',
#    'ZEB2',
#    'HIC2',
#    'TM4SF1',
#    'ZFPM2',
#    'SERPINB9',
#    'GTSF1',
#    'TANC2',
#    'S1PR1',
#    'SOSTDC1',
#    'KRT19',
#    'PDE7B',
#    'DSCAM',
#    'MIR31HG',
#    'PDE3A',
#    'XKR3',
#    'PTPRM',
#    'MARCH3',
#    'CNTNAP2',
#    'CADM2',
#    'ABO',
#    'LRRC25',
#    'GPX2',
#    'MTHFR',
#    'ERBB4',
#    'GPC5',
#    'HERC2P3',
#    'PLD5',
#    'ZBTB20',
#    'GABRG3',
#    'ZNF804B',
#    'HOXB4',
#    'PAPPA',
#    'SLC25A21',
#    'NEB',
#    'CSMD1',
#    'PTGDR2',
#    'CALN1',
#    'SLC35F3',
#    'DSCR4',
#    'PCDH9',
#    'EFNA5',
#    'MAML2',
#    'TMEM173',
#    'PDE4B',
#    'PRR16',
#    'WT1',
#    'ROBO2',
#    'F8',
#    'DLK1',
#    'PRAME',
#    'KCNQ5',
#    'IKZF1',
#    'EVI2B',
#    'RHD',
#    'AKR1C1',
#    'C17orf99',
#    'C22orf34',
#    'HBA2',
#    'RHCE',
#    'RELN',
#    'APOD',
#    'AC069277.1',
#    'AKR1C3',
#    'S100A4',
#    'GREB1',
#    'EVL',
#    'MME',
#    'SULF2',
#    'HBG2',
#    'MMP1',
#    'TCF4',
#    'DCHS2',
#    'SPN',
#    'AC068051.1',
#    'CR1L',
#    'S100A6',
#    'KEL',
#    'AKR1B10',
#    'CARD11',
#    'ASPH',
#    'TXNRD1',
#    'COLGALT2',
#    'RCSD1',
#    'DMD',
#    'C10orf128',
#    'COL5A2',
#    'FAM155A',
#    'LST1',
#    'TBC1D8',
#    'MALRD1',
#    'KRT6A',
#    'KRT81',
#    'LINC01446',
#    'HBA1',
#    'HBE1',
#    'HBG1',
#    'MTCP1',
#    'ISPD',
#    'MUC5AC',
#    'MIR17HG',
#    'LY86-AS1',
#    'SMPD4P1',
#    'AC073365.1',
#    'AC007319.1',
#    'MIR548XHG',
#    'MIR3681HG',
#    'AL513164.1',
#    'AL160162.1',
#    'AC002480.1',
#    'LINC02476',
#    'LINC00431',
#    'PROSER2-AS1',
#    'AP000561.1',
#    'LINC00351',
#    'LINC01811',
#    'LINC02089',
#    'LINC01876',
#    'LINC01748',
#    'LINC01203',
#    'LINC00511',
#    'LINC00355',
#    'AL033504.1',
#    'AL713998.1',
#    'LINC01344',
#    'CCDC26',
#    'AC011287.1',
#    'AC068533.2',
#    'NFE4',
#    'AC005208.1',
#    'AL160408.3',
#    'AC024084.1',
#    'CEACAM22P',
#    'AC092650.1',
#    'SGO1-AS1',
#    'LINC01090',
#    'ZBED9',
#    'AC078845.1',
#    'AC004870.4',
#    'LINC01162',
#    'CCDC144NL-AS1',
#    'LINC01687',
#    'AP001171.1',
#    'AC098617.1',
#    'AC009264.1',
#    'AL139042.1',
#    'LINC01287',
#    'LINC01524',
#    'AC016723.1',
#    'LINC01036',
#    'AC006369.1',
#    'AC010894.3',
#    'AL138828.1',
#    'AL109615.3',
#    'IRGM',
#    'LINC02096',
#    'LINC00879',
#    'LINC01192',
#    'HNF1A-AS1',
#    'XACT',
#    'AC109466.1',
#    'AC092957.1',
#    'FCGR2C',
#    'AC010230.1',
#    'NR2F2-AS1',
#    'LINC01194',
#    'MEF2C-AS1',
#    'LUCAT1',
#    'AC139491.2',
#    'LINC02484',
#    'LINC02428',
#    'FLJ46284',
#    'LINC01033',
#    'AC106744.1',
#    'LINC01088',
#    'AC112206.2',
#    'AC138819.1',
#    'AC091976.1',
#    'AC093607.1',
#    'GYPB',
#    'AC079160.1',
#    'AC025419.1',
#    'AC016687.3',
#    'AC097478.1',
#    'AC109830.1',
#    'LINC00923',
#    'LINC00958',
#    'HNRNPKP3',
#    'AC099520.1',
#    'LINC00534',
#    'AF279873.3',
#    'LINC01608',
#    'AC025524.2',
#    'AC103770.1',
#    'BBOX1-AS1',
#    'AP000781.2',
#    'AP003181.1',
#    'MIR100HG',
#    'JRKL-AS1',
#    'AC010197.1',
#    'AC090630.1',
#    'LINC02327',
#    'AL110292.1',
#    'HIF1A-AS2',
#    'LINC02296',
#    'AL390334.1',
#    'LINC02307',
#    'AC008050.1',
#    'LINC01169',
#    'AC020687.1',
#    'LINC02109',
#    'AC010601.1',
#    'AC005307.1',
#    'LINC00922',
#    'AP005328.1',
#    'AC079062.1',
#    'AC036222.1',
#    'LINC01029',
#    'AC079466.1',
#    'AC011476.3',
#    'AC009271.1',
#    'LINC01835',
#    'IGFL2-AS1',
#    'CCL5',
#    'CEACAM20',
#    'ZNF280B',
#    'AC015574.1',
#    'FCGBP',
#    'PRSS2',
#    'LINC00540',
#    'AL772337.4',
#    'AC087633.2',
#    'LINC00624',
#    'LINC02204',
#    'SCHLAP1',
#    'AL157778.1',
#    'MGC4859',
#    'AC087280.2',
#    'EXOC3L2',
#    'AC002472.2',
#    'AL354702.2']},
#  {'feature_selection_method': 'cell_ranger',
#   'n_features': 1000,
#   'genes': ['CFH',
#    'GCLC',
#    'HECW1',
#    'TFPI',
#    'PDK4',
#    'SLC4A1',
#    'CALCR',
#    'THSD7A',
#    'ACSM3',
#    'PRKAR2B',
#    'ETV1',
#    'TBXA2R',
#    'PAX6',
#    'TENM1',
#    'GIPR',
#    'BTK',
#    'FYN',
#    'ABHD5',
#    'PLAUR',
#    'TYROBP',
#    'ALOX5',
#    'IGF1',
#    'SLC38A5',
#    'CNTN1',
#    'CYP24A1',
#    'SAMD4A',
#    'NRXN3',
#    'CPS1',
#    'GRAMD1B',
#    'ABCC2',
#    'GCLM',
#    'VIM',
#    'AGPAT4',
#    'TNFRSF1B',
#    'ANK1',
#    'LRRC7',
#    'GAB2',
#    'VCAN',
#    'MSR1',
#    'RIPOR3',
#    'LCP2',
#    'MAGEC2',
#    'CP',
#    'ARHGAP6',
#    'CELF2',
#    'ADAMTS6',
#    'TNFRSF9',
#    'PTGER3',
#    'MCF2L2',
#    'PTPRN',
#    'KCNH2',
#    'DCBLD2',
#    'SLC2A3',
#    'BCAT1',
#    'LTK',
#    'LIMCH1',
#    'PRKCQ',
#    'FAM107B',
#    'ASPM',
#    'CD84',
#    'SPI1',
#    'ACSL4',
#    'PITX1',
#    'TGFBR3',
#    'SPTB',
#    'ST6GALNAC1',
#    'FRMPD1',
#    'ASNS',
#    'OSBPL3',
#    'MYO3B',
#    'RHOBTB1',
#    'FCGR2B',
#    'TP63',
#    'PTGS2',
#    'IGF2BP2',
#    'ST6GAL1',
#    'CA12',
#    'NTN4',
#    'TXK',
#    'SEMA3A',
#    'SEMA3C',
#    'ADD2',
#    'FSCN1',
#    'ARHGAP15',
#    'MCAM',
#    'ITM2A',
#    'ARG2',
#    'MEF2C',
#    'PTPRC',
#    'IL12RB2',
#    'FYB1',
#    'TRPM3',
#    'GSTP1',
#    'SLCO1A2',
#    'AKR1B1',
#    'CEACAM6',
#    'ERO1B',
#    'FTL',
#    'CASS4',
#    'GP6',
#    'ARHGAP28',
#    'TESC',
#    'SLC23A2',
#    'FXYD5',
#    'HEPH',
#    'ICAM1',
#    'LYZ',
#    'LAMB1',
#    'SEL1L3',
#    'NLRP1',
#    'ESR1',
#    'UNC13D',
#    'CDC45',
#    'PTGS1',
#    'CYP26A1',
#    'SORBS1',
#    'SMIM24',
#    'PCSK5',
#    'DERL3',
#    'UPB1',
#    'MAPK1',
#    'PPM1F',
#    'TPTEP1',
#    'GRAP2',
#    'MLC1',
#    'DHRS2',
#    'PLTP',
#    'BMP7',
#    'PPP1R16B',
#    'MID1',
#    'RENBP',
#    'GATA1',
#    'TIMP1',
#    'GABRE',
#    'FLT1',
#    'SLC7A5',
#    'ACSBG1',
#    'SCG3',
#    'CALB1',
#    'NDRG1',
#    'NCALD',
#    'BNIP3L',
#    'TUBB4A',
#    'LYL1',
#    'TGFB1',
#    'SIGLEC8',
#    'ICAM4',
#    'SIGLEC6',
#    'ZNF175',
#    'HAS1',
#    'KLF1',
#    'PDE4C',
#    'ISYNA1',
#    'TFPI2',
#    'NAMPT',
#    'PIK3CG',
#    'STEAP1B',
#    'CPED1',
#    'GRB10',
#    'EPHB6',
#    'TFR2',
#    'SERPINE1',
#    'ACTR3C',
#    'POU6F2',
#    'CLIP2',
#    'CNTNAP3',
#    'PTGR1',
#    'SUSD1',
#    'DOCK8',
#    'GLIS3',
#    'GATA3',
#    'VSIR',
#    'SH3PXD2A',
#    'SORCS1',
#    'UBTF',
#    'TRIM37',
#    'P2RX1',
#    'ALDH3A1',
#    'ABCC3',
#    'ALDOC',
#    'NMU',
#    'INPP4B',
#    'CPZ',
#    'CTSC',
#    'SOX6',
#    'CD69',
#    'SELPLG',
#    'WNT5B',
#    'SH2B3',
#    'LDHB',
#    'GCNT2',
#    'CEP85L',
#    'ADTRP',
#    'FAM184A',
#    'MAN1A1',
#    'PPARD',
#    'RHAG',
#    'BACH2',
#    'PDE10A',
#    'VEGFA',
#    'TBX18',
#    'HMGCS1',
#    'PDE4D',
#    'BCL6',
#    'PFKFB4',
#    'GBE1',
#    'IL1A',
#    'CCDC88A',
#    'FN1',
#    'IGFBP5',
#    'IL1RL1',
#    'DLX2',
#    'PLCL1',
#    'AC087235.1',
#    'PLEK',
#    'EPHA4',
#    'ARHGEF2',
#    'DNAJC6',
#    'PLA2G4A',
#    'AKT3',
#    'RSRP1',
#    'CENPF',
#    'MUC5B',
#    'FILIP1',
#    'PLAGL1',
#    'RARRES1',
#    'GDA',
#    'CSF3R',
#    'IRF2BPL',
#    'ESRRB',
#    'HOXB3',
#    'MOB3B',
#    'ARAP3',
#    'PLXDC2',
#    'CLU',
#    'EPX',
#    'TEX14',
#    'FAM117A',
#    'ADCY7',
#    'TMEM156',
#    'PAEP',
#    'FAM126A',
#    'SRGN',
#    'BICC1',
#    'P4HA1',
#    'NCKAP1L',
#    'NFE2',
#    'G0S2',
#    'CTCFL',
#    'PARD6B',
#    'HIST1H2BJ',
#    'DNAH8',
#    'ABCC4',
#    'SEPT6',
#    'TNFSF14',
#    'GPCPD1',
#    'TCF15',
#    'TMEM74B',
#    'STAT5A',
#    'FAM78A',
#    'CTAG2',
#    'PTPRB',
#    'LRRC61',
#    'ADGRE2',
#    'F2RL3',
#    'TPST2',
#    'RAC2',
#    'STRIP2',
#    'FLNC',
#    'PDE11A',
#    'ALDH1A2',
#    'PSMA1',
#    'MTUS1',
#    'EGLN3',
#    'ARHGEF6',
#    'FGF13',
#    'CDKN1C',
#    'APOE',
#    'APOC1',
#    'BST2',
#    'KLHDC7B',
#    'HBZ',
#    'GMFG',
#    'ZNF426',
#    'SLC6A8',
#    'PNCK',
#    'MPP1',
#    'AKAP12',
#    'ACSS2',
#    'LRRC4B',
#    'MAP1B',
#    'FCRLA',
#    'LINC00470',
#    'MYO18B',
#    'CA1',
#    'TEX15',
#    'LOXL2',
#    'IL6ST',
#    'DOCK2',
#    'SOX5',
#    'ZCCHC11',
#    'SLC43A3',
#    'APLNR',
#    'TCN1',
#    'ANXA1',
#    'GOLM1',
#    'KCP',
#    'ADGRB3',
#    'CGA',
#    'LMO2',
#    'TFCP2',
#    'KRT7',
#    'TEC',
#    'EGLN1',
#    'GLUL',
#    'NPL',
#    'FAM129A',
#    'ALDH1L2',
#    'LCP1',
#    'TNS3',
#    'IGF2BP3',
#    'BRIP1',
#    'GALNT5',
#    'RPS6KC1',
#    'TMOD1',
#    'HEMGN',
#    'PIM1',
#    'GMPR',
#    'SLCO2B1',
#    'SYTL2',
#    'SLC44A5',
#    'ADAMTS14',
#    'TET1',
#    'SLC40A1',
#    'CILP',
#    'PARP16',
#    'SEMA7A',
#    'FAM13A',
#    'GPAT3',
#    'BMP2K',
#    'INHBE',
#    'MBNL2',
#    'KCNH5',
#    'STON2',
#    'HDC',
#    'CYP11A1',
#    'NTRK3',
#    'MFGE8',
#    'RPL3L',
#    'ABCA8',
#    'BCAS3',
#    'SLC39A6',
#    'TMC6',
#    'NARF',
#    'RNF157',
#    'VAV1',
#    'EMP3',
#    'MYO1F',
#    'SIGLEC10',
#    'HSPG2',
#    'CD53',
#    'ECM1',
#    'ADAMTSL4',
#    'REN',
#    'PTPN7',
#    'ST6GAL2',
#    'PTH2R',
#    'GADL1',
#    'IGSF11',
#    'TMEM108',
#    'MYO10',
#    'IQGAP2',
#    'ARHGAP26',
#    'RNF145',
#    'CPLX2',
#    'GFOD1',
#    'RNF217',
#    'RSPO3',
#    'ARHGAP18',
#    'AIG1',
#    'VWDE',
#    'CREB5',
#    'IGFBP3',
#    'SSC4D',
#    'MSN',
#    'IL2RG',
#    'DOCK11',
#    'CSGALNACT1',
#    'SLC25A37',
#    'STAR',
#    'DPYS',
#    'LRP12',
#    'FAM83A',
#    'PLIN2',
#    'FAM171A1',
#    'ITPRIP',
#    'SLC5A12',
#    'FADS1',
#    'MS4A2',
#    'KIRREL3',
#    'FERMT3',
#    'CNTN5',
#    'ITPR1',
#    'SLC7A11',
#    'ENKUR',
#    'BTBD11',
#    'NPAS3',
#    'AKR1C2',
#    'VENTX',
#    'GFRA1',
#    'PDK1',
#    'PDE3B',
#    'OLAH',
#    'SYCP2L',
#    'PTPRR',
#    'CNKSR3',
#    'CACNA2D1',
#    'CDH12',
#    'ANGPT1',
#    'ENPP3',
#    'TNIK',
#    'PPP1R3A',
#    'FAM69A',
#    'CNTNAP3B',
#    'SAMSN1',
#    'SLC16A1',
#    'ELMO1',
#    'SLC24A2',
#    'CLIC2',
#    'CFAP70',
#    'ADAMTS3',
#    'NAA11',
#    'UNC5D',
#    'FRRS1',
#    'NRG1',
#    'SSBP3',
#    'ST3GAL2',
#    'MYO1E',
#    'TNFRSF14',
#    'HIST1H4H',
#    'DNAH3',
#    'ALAS2',
#    'PAGE5',
#    'EPB41',
#    'TFF1',
#    'GAB3',
#    'COL26A1',
#    'FBXL13',
#    'ZNF577',
#    'ITGA5',
#    'MEIOB',
#    'TAL1',
#    'DHRS3',
#    'LAPTM5',
#    'SDC3',
#    'IL23R',
#    'DIRAS3',
#    'BRINP3',
#    'KCNT2',
#    'SLAMF6',
#    'ARL5A',
#    'CTSS',
#    'SPRR2D',
#    'ANTXR2',
#    'COL6A3',
#    'PROK2',
#    'PDCL2',
#    'FEV',
#    'SPTA1',
#    'APBB2',
#    'CDCP1',
#    'HAND2',
#    'ADGRV1',
#    'EBF1',
#    'STXBP5',
#    'ANKRD55',
#    'PI16',
#    'GPR85',
#    'KIAA1324L',
#    'COL1A2',
#    'ALDH1A1',
#    'CLDN2',
#    'SSX3',
#    'VSTM4',
#    'BTNL9',
#    'GABRB3',
#    'TPP1',
#    'PRKCB',
#    'YPEL4',
#    'MAP1A',
#    'EVA1C',
#    'RBFOX3',
#    'CD3D',
#    'YIF1B',
#    'CD300A',
#    'NLRC3',
#    'DDIT4',
#    'XIRP1',
#    'RHOH',
#    'PHYHIP',
#    'LRP1B',
#    'FAM178B',
#    'TM4SF20',
#    'ROR2',
#    'CXCL8',
#    'SCN9A',
#    'CD52',
#    'PLEKHA2',
#    'CCDC8',
#    'ZEB2',
#    'HIC2',
#    'ROBO1',
#    'CTNND2',
#    'TM4SF1',
#    'ZFPM2',
#    'CST1',
#    'ZNF804A',
#    'DENND5B',
#    'NPAS2',
#    'HSD17B13',
#    'SERPINB9',
#    'GTSF1',
#    'HOXB9',
#    'TANC2',
#    'PDGFD',
#    'S1PR1',
#    'GRIK1',
#    'LRG1',
#    'SOSTDC1',
#    'CHST11',
#    'KRT19',
#    'PDE7B',
#    'FGG',
#    'FGA',
#    'DSCAM',
#    'NMUR1',
#    'NMRAL2P',
#    'RASGRP4',
#    'MIR31HG',
#    'PDE3A',
#    'TMEM217',
#    'MIR4435-2HG',
#    'XKR3',
#    'HSPA6',
#    'PTPRM',
#    'MOB1B',
#    'AP000769.1',
#    'STAT5B',
#    'CD7',
#    'HOXB2',
#    'MARCH3',
#    'SNX31',
#    'SLC6A19',
#    'CNTNAP2',
#    'ZDHHC14',
#    'CADM2',
#    'ABO',
#    'DDIT3',
#    'LRRC25',
#    'YES1',
#    'GPX2',
#    'MYO1D',
#    'FKBP9P1',
#    'MTHFR',
#    'B3GNT8',
#    'CD19',
#    'CAVIN1',
#    'LINC01658',
#    'TMPRSS9',
#    'ERBB4',
#    'GDPD4',
#    'GATA2',
#    'GPC5',
#    'SERTAD2',
#    'HERC2P3',
#    'FGD6',
#    'PLD5',
#    'PRF1',
#    'NQO1',
#    'PLAG1',
#    'ZBTB20',
#    'OR2Z1',
#    'UBA7',
#    'GABRG3',
#    'ZNF804B',
#    'NDN',
#    'HOXB4',
#    'PAPPA',
#    'SLC25A21',
#    'NEB',
#    'CSMD1',
#    'PTGDR2',
#    'CALN1',
#    'WT1-AS',
#    'FHL3',
#    'PI4KAP2',
#    'EFHC2',
#    'SLC35F3',
#    'UTY',
#    'DSCR4',
#    'PCDH9',
#    'SLIT3',
#    'EFNA5',
#    'MAML2',
#    'PROS1',
#    'TMEM173',
#    'PDE4B',
#    'PRR16',
#    'WT1',
#    'ROBO2',
#    'F8',
#    'SLC24A3',
#    'PRSS57',
#    'ZNF445',
#    'PRKN',
#    'METTL7A',
#    'GPRIN3',
#    'ROR1',
#    'DLK1',
#    'AHNAK2',
#    'KRT79',
#    'PRAME',
#    'KCNQ5',
#    'IKZF1',
#    'EVI2B',
#    'EDARADD',
#    'KLHL32',
#    'PRELID2',
#    'PRG2',
#    'RHD',
#    'PLCD1',
#    'AKR1C1',
#    'FPR3',
#    'AGMO',
#    'TCL6',
#    'TRPV2',
#    'LIN28B',
#    'FAM69C',
#    'C17orf99',
#    'ARL4C',
#    'C22orf34',
#    'HBA2',
#    'RHCE',
#    'RELN',
#    'APOD',
#    'AC069277.1',
#    'FHIT',
#    'AKR1C3',
#    'S100A4',
#    'GREB1',
#    'SIRPB2',
#    'RYR1',
#    'EVL',
#    'MME',
#    'SULF2',
#    'HBG2',
#    'ZNF846',
#    'MMP1',
#    'TCF4',
#    'SLC30A10',
#    'TLR7',
#    'DAPK1',
#    'ANXA4',
#    'SULT1A2',
#    'ZNF655',
#    'DCHS2',
#    'GYPE',
#    'SPN',
#    'KCNMB2',
#    'AC068051.1',
#    'CR1L',
#    'ZNF677',
#    'S100A6',
#    'KEL',
#    'AKR1B10',
#    'HSD17B11',
#    'TMEM116',
#    'CARD11',
#    'MYL4',
#    'ASPH',
#    'TXNRD1',
#    'SLC5A3',
#    'COLGALT2',
#    'RCSD1',
#    'ZNF521',
#    'SUCNR1',
#    'DMD',
#    'TGM2',
#    'RNU5F-1',
#    'Y_RNA-251',
#    'U3-12',
#    'LINC01317',
#    'LINC01285',
#    'RBM20',
#    'C10orf128',
#    'COL5A2',
#    'COL15A1',
#    'SLC44A4',
#    'FAM155A',
#    'LST1',
#    'TBC1D8',
#    'MALRD1',
#    'AC007389.1',
#    'CCDC144NL',
#    'LGR4',
#    'KRT6A',
#    'KRT81',
#    'LINC01597',
#    'LINC01446',
#    'MFSD2B',
#    'C1QTNF9B',
#    'HBA1',
#    'GPSM3',
#    'HBE1',
#    'HBG1',
#    'PLIN5',
#    'CPEB1',
#    'MS4A4E',
#    'MTCP1',
#    'ISPD',
#    'AC131097.1',
#    'ALOX12-AS1',
#    'MUC5AC',
#    'MIR17HG',
#    'LY86-AS1',
#    'TMEM14EP',
#    'AC098613.1',
#    'SMPD4P1',
#    'DSCR4-IT1',
#    'AF230666.1',
#    'RAD17P2',
#    'CCDC18-AS1',
#    'AC073365.1',
#    'AC007319.1',
#    'MIR548XHG',
#    'MIR3681HG',
#    'LINC01708',
#    'AL513164.1',
#    'AL160162.1',
#    'AL662890.2',
#    'AKR1C5P',
#    'AC002480.1',
#    'LINC02476',
#    'LINC00431',
#    'PROSER2-AS1',
#    'NRIR',
#    'AP000561.1',
#    'LINC00351',
#    'LINC01811',
#    'LINC02089',
#    'LINC01876',
#    'SLC16A1-AS1',
#    'AC135371.1',
#    'ANKRD18DP',
#    'LINC02542',
#    'LINC01748',
#    'AC007271.1',
#    'LINC01203',
#    'LINC00511',
#    'LINC00355',
#    'AL033504.1',
#    'AL713998.1',
#    'AL671277.1',
#    'TARID',
#    'LINC01820',
#    'LINC01344',
#    'CCDC26',
#    'AC011287.1',
#    'XIST',
#    'AC068533.2',
#    'AC012499.1',
#    'TRPM2-AS',
#    'AL022316.1',
#    'AL359382.1',
#    'NFE4',
#    'AC005208.1',
#    'AL160408.3',
#    'AC024084.1',
#    'CEACAM22P',
#    'AC092650.1',
#    'AL391807.1',
#    'AC092625.1',
#    'AC105402.3',
#    'SPRY4-AS1',
#    'SGO1-AS1',
#    'LINC01090',
#    'DOC2GP',
#    'AC005537.1',
#    'ZBED9',
#    'AC078845.1',
#    'AC004870.4',
#    'Z98949.3',
#    'AL136987.1',
#    'LINC01162',
#    'LINC01399',
#    'CCDC144NL-AS1',
#    'LINC01794',
#    'LINC01687',
#    'AP001171.1',
#    'LINC00656',
#    'AC098617.1',
#    'AJ006995.1',
#    'LINC01675',
#    'AC009264.1',
#    'AL138930.1',
#    'AL139042.1',
#    'AL359873.1',
#    'LINC01287',
#    'LINC01524',
#    'AC016723.1',
#    'LINC02154',
#    'AL035681.1',
#    'LINC01036',
#    'AC006369.1',
#    'AC010894.3',
#    'AL354794.1',
#    'FOXD2-AS1',
#    'AL138828.1',
#    'AL365226.2',
#    'AL109615.3',
#    'IRGM',
#    'NFYAP1',
#    'EEF1A1P31',
#    'LINC01885',
#    'LINC00649',
#    'LINC02096',
#    'LINC00879',
#    'AC108718.1',
#    'LINC01192',
#    'HNF1A-AS1',
#    'XACT',
#    'AC109466.1',
#    'LINC00996',
#    'AC092957.1',
#    'GATA2-AS1',
#    'ERVFRD-1',
#    'APOBEC3C',
#    'FCGR2C',
#    'AC010230.1',
#    'LINC02458',
#    'NR2F2-AS1',
#    'LINC01194',
#    'CR545473.1',
#    'LINC02505',
#    'MEF2C-AS1',
#    'LUCAT1',
#    'AC093772.1',
#    'ASNSP1',
#    'LINC02267',
#    'AC139491.2',
#    'LINC02484',
#    'LINC02428',
#    'LINC02432',
#    'AC097512.1',
#    'FLJ46284',
#    'LINC01033',
#    'AC106744.1',
#    'LINC01088',
#    'LINC02405',
#    'AC112206.2',
#    'AC112178.1',
#    'AC138819.1',
#    'TMEM158',
#    'AC109588.1',
#    'AC091976.1',
#    'AC093607.1',
#    'AC106791.1',
#    'GYPB',
#    'AC106798.1',
#    'AC008825.1',
#    'AC079160.1',
#    'LINC00491',
#    'AC111000.4',
#    'AC010343.3',
#    'AC025419.1',
#    'AC016687.3',
#    'ZFPM2-AS1',
#    'AC097478.1',
#    'F11-AS1',
#    'AC109830.1',
#    'LINC00923',
#    'LINC00958',
#    'LINC01099',
#    'HNRNPKP3',
#    'AC099520.1',
#    'AC096711.3',
#    'LINC02241',
#    'RNU6-1219P',
#    'LINC02143',
#    'AC090809.1',
#    'AC068672.2',
#    'LINC00534',
#    'AC103853.1',
#    'AF279873.3',
#    'ZFHX4-AS1',
#    'AC011632.1',
#    'AC105999.2',
#    'AC246817.1',
#    'LINC01608',
#    'AC123767.1',
#    'AC025524.2',
#    'AC091901.1',
#    'AC024681.2',
#    'AC103770.1',
#    'AC246817.2',
#    'MIR2052HG',
#    'BBOX1-AS1',
#    'AP000781.2',
#    'AP003181.1',
#    'MIR100HG',
#    'CARD18',
#    'JRKL-AS1',
#    'LINC00944',
#    'AC010197.1',
#    'AC090630.1',
#    'AC124947.1',
#    'AC123905.1',
#    'AC020656.1',
#    'LINC01481-1',
#    'LINC02327',
#    'AC025575.2',
#    'AL110292.1',
#    'HIF1A-AS2',
#    'LINC02328',
#    'LINC02296',
#    'AL390334.1',
#    'LINC02307',
#    'AL356804.1',
#    'AC008050.1',
#    'LINC01169',
#    'LINC01583',
#    'AC013452.1',
#    'AC020687.1',
#    'LINC02109',
#    'AC097374.1',
#    'AC010601.1',
#    'AL138756.1',
#    'AC106729.1',
#    'AC005307.1',
#    'PECAM1',
#    'AL592164.1',
#    'DISC1FP1',
#    'GOLGA6L7P',
#    'LINC00922',
#    'AC105243.1',
#    'AP005328.1',
#    'AC079062.1',
#    'AC024267.1',
#    'AC036222.1',
#    'LINC00526',
#    'AC119868.2',
#    'LINC01029',
#    'AC019183.1',
#    'AC008109.1',
#    'AC079466.1',
#    'AC008105.3',
#    'AC011476.3',
#    'AC009271.1',
#    'LINC01835',
#    'AC123912.2',
#    'AC123912.4',
#    'IGFL2-AS1',
#    'AC020922.2',
#    'AL627309.7',
#    'FBXO17',
#    'AC079880.1',
#    'AC010719.1',
#    'CCL5',
#    'TPTE2P2',
#    'AC006238.1',
#    'AC099568.2',
#    'CEACAM20',
#    'TBC1D3',
#    'ZNF280B',
#    'AC015574.1',
#    'FCGBP',
#    'AL445584.2',
#    'PRSS2',
#    'LINC00540',
#    'AL772337.4',
#    'AC087633.2',
#    'LINC00624',
#    'AC130469.2',
#    'AC117500.6',
#    'AC020907.5',
#    'AC079801.1',
#    'AL356585.4',
#    'AC019080.5',
#    'LINC02204',
#    'EIF1B-AS1',
#    'SCHLAP1',
#    'AL157778.1',
#    'LINC00976',
#    'MGC4859',
#    'AC087280.2',
#    'EXOC3L2',
#    'AC002472.2',
#    'AC016912.1',
#    'AL354702.2',
#    'PDE11A-1']},
#  {'feature_selection_method': 'cell_ranger',
#   'n_features': 2000,
#   'genes': ['CFH',
#    'GCLC',
#    'HECW1',
#    'TFPI',
#    'PDK4',
#    'SLC4A1',
#    'CALCR',
#    'THSD7A',
#    'ACSM3',
#    'PRKAR2B',
#    'TSPOAP1',
#    'ITGA2B',
#    'ETV1',
#    'ALDH3B1',
#    'TBXA2R',
#    'PRSS21',
#    'PAX6',
#    'TENM1',
#    'TRAF3IP3',
#    'GIPR',
#    'CD4',
#    'BTK',
#    'FYN',
#    'ABHD5',
#    'PLAUR',
#    'DCN',
#    'TYROBP',
#    'GABRA3',
#    'ALOX5',
#    'IGF1',
#    'SLC38A5',
#    'CNTN1',
#    'WWTR1',
#    'AGPS',
#    'ZNF582',
#    'CYP24A1',
#    'SAMD4A',
#    'NRXN3',
#    'CPS1',
#    'GRAMD1B',
#    'ABCC2',
#    'GCLM',
#    'VIM',
#    'CD44',
#    'AGPAT4',
#    'TNFRSF1B',
#    'ANK1',
#    'LRRC7',
#    'GAB2',
#    'APBA2',
#    'STAP1',
#    'FBXO42',
#    'VCAN',
#    'MSR1',
#    'RAI14',
#    'MYO16',
#    'RIPOR3',
#    'LCP2',
#    'HSPA5',
#    'MAGEC2',
#    'CP',
#    'ARHGAP6',
#    'CELF2',
#    'ADAMTS6',
#    'TNFRSF9',
#    'LTBP1',
#    'LIMA1',
#    'PTGER3',
#    'MCF2L2',
#    'PTPRN',
#    'KCNH2',
#    'DCBLD2',
#    'DGKG',
#    'TBXAS1',
#    'SLC2A3',
#    'COL11A1',
#    'BCAT1',
#    'LTK',
#    'APPBP2',
#    'LIMCH1',
#    'TSPAN32',
#    'ABCA7',
#    'MYLK',
#    'PRKCQ',
#    'FAM107B',
#    'PDE4A',
#    'ASPM',
#    'CD84',
#    'SPI1',
#    'ACSL4',
#    'PRR11',
#    'KIF2A',
#    'PAGE1',
#    'PITX1',
#    'TGFBR3',
#    'RAB27A',
#    'UFD1',
#    'SPTB',
#    'CLTCL1',
#    'ST6GALNAC1',
#    'FRMPD1',
#    'ASNS',
#    'EIF2B3',
#    'CAMK2A',
#    'OSBPL3',
#    'MYO3B',
#    'CYBRD1',
#    'ASIC4',
#    'TFRC',
#    'RHOBTB1',
#    'FCGR2B',
#    'TP63',
#    'CLCN4',
#    'GSDMB',
#    'PTGS2',
#    'IGF2BP2',
#    'ST6GAL1',
#    'CA12',
#    'NTN4',
#    'LMAN1',
#    'TXK',
#    'WSCD2',
#    'SEMA3A',
#    'SEMA3C',
#    'ADD2',
#    'FSCN1',
#    'PLD1',
#    'ARHGAP15',
#    'MCAM',
#    'RAP1GAP',
#    'NAALAD2',
#    'ITM2A',
#    'OSBPL6',
#    'CDC14A',
#    'DUSP13',
#    'PTPRH',
#    'CPOX',
#    'COL4A4',
#    'ARG2',
#    'MEF2C',
#    'PTPRC',
#    'IL12RB2',
#    'FYB1',
#    'FAM135A',
#    'TRPM3',
#    'GRHL2',
#    'OXCT1',
#    'ZNF671',
#    'FAT1',
#    'SMAP2',
#    'GSTP1',
#    'SLCO1A2',
#    'AKR1B1',
#    'HBQ1',
#    'CEACAM6',
#    'ERO1B',
#    'FTL',
#    'CASS4',
#    'RFX2',
#    'GP6',
#    'ARHGAP28',
#    'TESC',
#    'SLC23A2',
#    'FXYD5',
#    'HEPH',
#    'ARHGAP4',
#    'ICAM1',
#    'LYZ',
#    'P3H2',
#    'LAMB1',
#    'SEL1L3',
#    'NLRP1',
#    'ESR1',
#    'ANGPT2',
#    'CCDC80',
#    'JPH4',
#    'TBX15',
#    'CLSPN',
#    'UNC13D',
#    'CDC45',
#    'COMT',
#    'PTGS1',
#    'CYP26A1',
#    'SORBS1',
#    'SMIM24',
#    'FKBP5',
#    'ABL1',
#    'PCSK5',
#    'MAGEB2',
#    'KLHL22',
#    'CRKL',
#    'P2RX6',
#    'DERL3',
#    'RNF215',
#    'PPIL2',
#    'UPB1',
#    'YPEL1',
#    'MAPK1',
#    'PPM1F',
#    'TOP3B',
#    'CYTH4',
#    'HIRA',
#    'LGALS1',
#    'TPTEP1',
#    'APOL4',
#    'APOL1',
#    'GRAP2',
#    'FAM118A',
#    'MLC1',
#    'DHRS2',
#    'PLTP',
#    'PROCR',
#    'HNF4A',
#    'BMP7',
#    'CTSZ',
#    'TUBB1',
#    'MYL9',
#    'SNTA1',
#    'PPP1R16B',
#    'MYOM1',
#    'MID1',
#    'RHOXF1',
#    'ATP1B4',
#    'PLS3',
#    'RENBP',
#    'SMARCA1',
#    'PIM2',
#    'GATA1',
#    'TIMP1',
#    'GABRE',
#    'SGCG',
#    'FLT1',
#    'CENPT',
#    'SLC7A5',
#    'CPPED1',
#    'AQP9',
#    'ACSBG1',
#    'CEMIP',
#    'ATP8B4',
#    'SCG3',
#    'CPQ',
#    'CALB1',
#    'NDRG1',
#    'NCALD',
#    'ERI1',
#    'TUSC3',
#    'BNIP3L',
#    'TULP2',
#    'TUBB4A',
#    'LYL1',
#    'TNNT1',
#    'TGFB1',
#    'SIGLEC8',
#    'ICAM4',
#    'ICAM5',
#    'CD33',
#    'GRIN2D',
#    'SIGLEC6',
#    'ZNF175',
#    'HAS1',
#    'PLEKHA4',
#    'KLF1',
#    'KCNN1',
#    'PDE4C',
#    'ISYNA1',
#    'COPE',
#    'TFPI2',
#    'NAMPT',
#    'PIK3CG',
#    'PON3',
#    'PON2',
#    'STEAP1B',
#    'DFNA5',
#    'CPED1',
#    'CPVL',
#    'GRB10',
#    'FKBP14',
#    'EPHB6',
#    'CCL24',
#    'HSPB1',
#    'CYP3A5',
#    'TFR2',
#    'SERPINE1',
#    'ANKMY2',
#    'ACTR3C',
#    'POU6F2',
#    'CLIP2',
#    'CNTNAP3',
#    'MEGF9',
#    'CORO2A',
#    'C5',
#    'PTGR1',
#    'SUSD1',
#    'DOCK8',
#    'KANK1',
#    'PIP5K1B',
#    'GLIS3',
#    'PTGDS',
#    'SHB',
#    'GATA3',
#    'UNC5B',
#    'VSIR',
#    'ARHGAP21',
#    'SH3PXD2A',
#    'SORCS1',
#    'UBTF',
#    'TRIM37',
#    'P2RX1',
#    'HOXB6',
#    'ALDH3A1',
#    'ICAM2',
#    'ABCC3',
#    'ALDOC',
#    'NMU',
#    'INPP4B',
#    'CPZ',
#    'CTSC',
#    'VWA5A',
#    'IL10RA',
#    'CARS',
#    'SOX6',
#    'CD69',
#    'CLEC2B',
#    'SELPLG',
#    'WNT5B',
#    'SH2B3',
#    'LDHB',
#    'KLRB1',
#    'GCNT2',
#    'CEP85L',
#    'ADTRP',
#    'FAM184A',
#    'MAN1A1',
#    'PPARD',
#    'RHAG',
#    'BACH2',
#    'COL9A1',
#    'EYA4',
#    'TRIM38',
#    'PDE10A',
#    'CCND3',
#    'MRPL2',
#    'VEGFA',
#    'TBX18',
#    'HMGCS1',
#    'SPARC',
#    'PDE4D',
#    'PDGFRB',
#    'BCL6',
#    'HGD',
#    'KAT2B',
#    'PFKFB4',
#    'GBE1',
#    'IL1A',
#    'ACVR1',
#    'CCDC88A',
#    'FN1',
#    'IGFBP5',
#    'IL1R1',
#    'IL1RL1',
#    'DLX2',
#    'PLCL1',
#    'KYNU',
#    'AC087235.1',
#    'PLEK',
#    'EPAS1',
#    'EPHA4',
#    'PAPPA2',
#    'ARHGEF2',
#    'DNAJC6',
#    'LEPR',
#    'PLA2G4A',
#    'KIF21B',
#    'AKT3',
#    'ACADM',
#    'SSX2IP',
#    'P3H1',
#    'RSRP1',
#    'NSL1',
#    'CENPF',
#    'MUC5B',
#    'KIF14',
#    'LRMP',
#    'FILIP1',
#    'CNR1',
#    'SGIP1',
#    'PLAGL1',
#    'TNFAIP3',
#    'RARRES1',
#    'CCND2',
#    'ELL2',
#    'GDA',
#    'PHF19',
#    'CSF3R',
#    'IRF2BPL',
#    'ESRRB',
#    'HOXB8',
#    'HOXB3',
#    'MOB3B',
#    'ARAP3',
#    'PLXDC2',
#    'TGFBI',
#    'CLU',
#    'TNFRSF10B',
#    'PTK2B',
#    'TNFRSF8',
#    'EPX',
#    'TEX14',
#    'FAM117A',
#    'ADCY7',
#    'CD80',
#    'CCRL2',
#    'TMEM156',
#    'PAEP',
#    'LRRC39',
#    'FAM126A',
#    'CALD1',
#    'SRGN',
#    'BICC1',
#    'P4HA1',
#    'HVCN1',
#    'ARHGAP9',
#    'NCKAP1L',
#    'NFE2',
#    'G0S2',
#    'CTCFL',
#    'WFDC3',
#    'PARD6B',
#    'PEX6',
#    'HIST1H2BJ',
#    'DNAH8',
#    'EREG',
#    'ABCC4',
#    'SEPT6',
#    'SLC25A23',
#    'CD70',
#    'C3',
#    'TNFSF14',
#    'GPCPD1',
#    'FOXA2',
#    'TCF15',
#    'TMEM74B',
#    'UROD',
#    'TSKS',
#    'STAT5A',
#    'IFI6',
#    'SSX1',
#    'WDR60',
#    'FAM78A',
#    'NUP214',
#    'CTAG2',
#    'ZC4H2',
#    'MASP1',
#    'PTPRB',
#    'LRRC61',
#    'ADGRE2',
#    'F2RL3',
#    'MGAT3',
#    'TPST2',
#    'RAC2',
#    'KRT17',
#    'STRIP2',
#    'FLNC',
#    'PDE11A',
#    'GAD1',
#    'ALDH1A2',
#    'PSMA1',
#    'CSRP3',
#    'MTUS1',
#    'SIGLEC9',
#    'EGLN3',
#    'RNASE1',
#    'EPB41L4A',
#    'ARHGEF6',
#    'FGF13',
#    'CDKN1C',
#    'SYT5',
#    'TNNI3',
#    'CBFA2T3',
#    'SAT1',
#    'CNN1',
#    'APOE',
#    'APOC1',
#    'LRCH2',
#    'BST2',
#    'SNX9',
#    'UNC13A',
#    'KLHDC7B',
#    'GDF15',
#    'HRC',
#    'UBAC1',
#    'HBZ',
#    'GATA5',
#    'GMFG',
#    'SESN2',
#    'ZNF426',
#    'SLC6A8',
#    'PNCK',
#    'MPP1',
#    'FBP2',
#    'AKAP12',
#    'ACSS2',
#    'LRRC4B',
#    'PDLIM4',
#    'MAP1B',
#    'TNS4',
#    'TOP2A',
#    'RTBDN',
#    'FCRLA',
#    'LINC00470',
#    'TRIM5',
#    'GPS2',
#    'NES',
#    'MORC4',
#    'LGALS12',
#    'RARRES3',
#    'LARGE1',
#    'MYO18B',
#    'ZDHHC8P1',
#    'NTS',
#    'CA1',
#    'AMPD3',
#    'MICAL2',
#    'TEX15',
#    'CATSPERB',
#    'LOXL2',
#    'BHLHE40',
#    'MEIS2',
#    'IL6ST',
#    'DOCK2',
#    'SOX5',
#    'YARS',
#    'ZCCHC11',
#    'SLC43A3',
#    'APLNR',
#    'FADS2',
#    'TCN1',
#    'ANXA1',
#    'GOLM1',
#    'ADAM19',
#    'KCP',
#    'ADGRB3',
#    'MRAP2',
#    'CGA',
#    'LMO2',
#    'AMHR2',
#    'TESPA1',
#    'TFCP2',
#    'KRT7',
#    'TEC',
#    'EGLN1',
#    'GLUL',
#    'NPL',
#    'FAM129A',
#    'DOCK10',
#    'TMBIM1',
#    'ALDH1L2',
#    'LCP1',
#    'TNS3',
#    'IGF2BP3',
#    'MYO1G',
#    'BRIP1',
#    'GALNT5',
#    'RPS6KC1',
#    'GYPC',
#    'TMOD1',
#    'HEMGN',
#    'TLN1',
#    'PIM1',
#    'GMPR',
#    'KIAA0319',
#    'TUBB2B',
#    'HMGA1',
#    'TPMT',
#    'SLCO2B1',
#    'SYTL2',
#    'PI15',
#    'ITPKA',
#    'PLCB2',
#    'TTLL7',
#    'SLC44A5',
#    'PLCE1',
#    'ADAMTS14',
#    'TET1',
#    'FASTKD1',
#    'SLC40A1',
#    'CILP',
#    'PARP16',
#    'SEMA7A',
#    'FAM13A',
#    'GPAT3',
#    'BMPR1B',
#    'TRPC3',
#    'BMP2K',
#    'CENPE',
#    'LEF1',
#    'EGF',
#    'CPNE8',
#    'C1RL',
#    'RBP5',
#    'INHBE',
#    'DHH',
#    'DIAPH3',
#    'MBNL2',
#    'KCNH5',
#    'STON2',
#    'WARS',
#    'HDC',
#    'IGF1R',
#    'CYP11A1',
#    'PCSK6',
#    'NTRK3',
#    'MFGE8',
#    'ITGAX',
#    'MYLK3',
#    'KIFC3',
#    'RPL3L',
#    'SPACA3',
#    'ABCA8',
#    'BCAS3',
#    'SLC39A6',
#    'TMC6',
#    'NARF',
#    'RNF157',
#    'PNMT',
#    'VAV1',
#    'DMRTC2',
#    'EMP3',
#    'ADAMTS10',
#    'MYO1F',
#    'SIGLEC10',
#    'HSPG2',
#    'TINAGL1',
#    'BEST4',
#    'CD53',
#    'FCGR2A',
#    'ECM1',
#    'ADAMTSL4',
#    'SEMA6C',
#    'DTL',
#    'AQP10',
#    'PKLR',
#    'MBOAT2',
#    'LBR',
#    'EPHX1',
#    'REN',
#    'PTPN7',
#    'GALM',
#    'ST6GAL2',
#    'PTH2R',
#    'GADL1',
#    'MYH15',
#    'IGSF11',
#    'TMEM108',
#    'ALDH1L1',
#    'TM4SF19',
#    'SNCA',
#    'CAMK2D',
#    'MYO10',
#    'SSBP2',
#    'IQGAP2',
#    'LIX1',
#    'TSLP',
#    'TNFAIP8',
#    'ADAMTS19',
#    'ARHGAP26',
#    'RNF145',
#    'CPLX2',
#    'GFOD1',
#    'RNF217',
#    'RSPO3',
#    'ARHGAP18',
#    'SLC18B1',
#    'AIG1',
#    'SLC22A3',
#    'VWDE',
#    'SDK1',
#    'CREB5',
#    'EGFR',
#    'IGFBP3',
#    'SSC4D',
#    'TMEM209',
#    'MSN',
#    'IL2RG',
#    'DOCK11',
#    'CSGALNACT1',
#    'DOK2',
#    'SLC25A37',
#    'DOCK5',
#    'STAR',
#    'DPYS',
#    'LRP12',
#    'FAM83A',
#    'PLIN2',
#    'PTGES',
#    'FAM171A1',
#    'ST8SIA6',
#    'ANKRD30A',
#    'ADD3',
#    'MKI67',
#    'ITPRIP',
#    'SLC5A12',
#    'SLC43A1',
#    'CCDC82',
#    'FADS1',
#    'MS4A2',
#    'KIRREL3',
#    'FERMT3',
#    'CNTN5',
#    'KLRF1',
#    'SEC24D',
#    'ITPR1',
#    'SLC7A11',
#    'ENKUR',
#    'NGLY1',
#    'BTBD11',
#    'NPAS3',
#    'AKR1C2',
#    'VENTX',
#    'NBAS',
#    'SLC35F4',
#    'GFRA1',
#    'GRID2',
#    'PSTPIP2',
#    'SPC25',
#    'PDK1',
#    'PDE3B',
#    'OLAH',
#    'DAB2',
#    'SYCP2L',
#    'BMP6',
#    'PTPRR',
#    'FAM81B',
#    'CNKSR3',
#    'C7orf31',
#    'CACNA2D1',
#    'HS3ST3A1',
#    'UBASH3B',
#    'CDH12',
#    'ANGPT1',
#    'ENPP3',
#    'UCHL1',
#    'TNIK',
#    'PPP1R3A',
#    'FAM69A',
#    'CNTNAP3B',
#    'PDE1C',
#    'SAMSN1',
#    'SLC16A1',
#    'SLC7A7',
#    'TTN',
#    'SPAG17',
#    'PPARGC1B',
#    'ELMO1',
#    'SLC24A2',
#    'CLIC2',
#    'KIF5A',
#    'MAGEA8',
#    'CFAP70',
#    'ADAMTS3',
#    'CFAP161',
#    'ART3',
#    'NAA11',
#    'BACH1',
#    'UNC5D',
#    'FRRS1',
#    'NRG1',
#    'SSBP3',
#    'ST3GAL2',
#    'MYO1E',
#    'KCNJ6',
#    'DGKI',
#    'TNFRSF14',
#    'WDR66',
#    'UBXN11',
#    'CDC25C',
#    'HIST1H4H',
#    'DNAH3',
#    'ALAS2',
#    'PAGE5',
#    'ZSCAN12',
#    'ADAMTS4',
#    'MPZ',
#    'EPB41',
#    'RUNX1',
#    'IGF2BP1',
#    'DRC7',
#    'GNE',
#    'BSDC1',
#    'TFF1',
#    'GAB3',
#    'C21orf33',
#    'ICOSLG',
#    'SPATC1L',
#    'ZNF208',
#    'CD3G',
#    'S100A1',
#    'COL26A1',
#    'FOXH1',
#    'FBXL13',
#    'TUBA3FP',
#    'YDJC',
#    'CCDC116',
#    'ZNF577',
#    'ITGA5',
#    'ZNF385A',
#    'FMNL3',
#    'MEIOB',
#    'TAL1',
#    'DHRS3',
#    'LAPTM5',
#    'SDC3',
#    'MXRA8',
#    'IL23R',
#    'DIRAS3',
#    'NFIA',
#    'LRRC53',
#    'BRINP3',
#    'KCNT2',
#    'TRIM58',
#    'SLAMF6',
#    'FCRLB',
#    'SLC9C2',
#    'ARL5A',
#    'NOSTRIN',
#    'HPGDS',
#    'CTSS',
#    'SPRR2D',
#    'ARHGAP25',
#    'ANTXR2',
#    'COL6A3',
#    'PROK2',
#    'LMOD1',
#    'PDCL2',
#    'FEV',
#    'CRYBA2',
#    'SPTA1',
#    'IFI16',
#    'AIM2',
#    'C4orf36',
#    'APBB2',
#    'CXCL3',
#    'CDCP1',
#    'HAND2',
#    'HPGD',
#    'ADGRV1',
#    'ANKRD33B',
#    'RICTOR',
#    'EBF1',
#    'ACSL6',
#    'SHROOM1',
#    'STXBP5',
#    'ANKRD55',
#    'PI16',
#    'GPR85',
#    'KIAA1324L',
#    'HEY1',
#    'COL1A2',
#    'SLC30A8',
#    'CA3',
#    'ALDH1A1',
#    'NLGN4Y',
#    'CLDN2',
#    'MARCH8',
#    'C10orf10',
#    'CDX2',
#    'SSX3',
#    'VSTM4',
#    'SLC18A2',
#    'GFI1B',
#    'BTNL9',
#    'LIPC',
#    'AC126323.1',
#    'RAB8B',
#    'CKB',
#    'GABRB3',
#    'TPP1',
#    'DCHS1',
#    'CYB5R2',
#    'WDR72',
#    'PRKCB',
#    'CDH16',
#    'RRAD',
#    'ACSM1',
#    'YPEL4',
#    'LDHC',
#    'MAP1A',
#    'MAPRE2',
#    'EVA1C',
#    'DPEP2',
#    'RBFOX3',
#    'CD3D',
#    'MVD',
#    'CORO6',
#    'AXL',
#    'PPP1R14A',
#    'YIF1B',
#    'RILP',
#    'KLK1',
#    'KLK4',
#    'ANGPTL4',
#    'CD300A',
#    'NLRC3',
#    'TRANK1',
#    'SCARA5',
#    'DDIT4',
#    'XIRP1',
#    'RHOH',
#    'TXNDC2',
#    'PHYHIP',
#    'CAVIN2',
#    'LRP1B',
#    'FAM178B',
#    'TSPAN5',
#    'SLC35G2',
#    'TM4SF20',
#    'ROR2',
#    'PCSK9',
#    'RAB3B',
#    'CXCL11',
#    'KCNAB1',
#    'CXCL8',
#    'SCN9A',
#    'CD52',
#    'SPRR1B',
#    'PLEKHA2',
#    'GPR183',
#    'CCDC8',
#    'MUC15',
#    'ZEB2',
#    'HIC2',
#    'BUB1',
#    'ROBO1',
#    'CTNND2',
#    'AHSP',
#    'ITGAM',
#    'TM4SF4',
#    'TM4SF1',
#    'ZFPM2',
#    'GYPA',
#    'FAXDC2',
#    'C7orf33',
#    'CST1',
#    'ZNF804A',
#    'DENND5B',
#    'KRT4',
#    'NPAS2',
#    'HSD17B13',
#    'SERPINB9',
#    'GTSF1',
#    'HOXB9',
#    'HTRA3',
#    'TANC2',
#    'PDGFD',
#    'S1PR1',
#    'GRIK1',
#    'LRG1',
#    'SOSTDC1',
#    'CHST11',
#    'KRT19',
#    'PDE7B',
#    'FGG',
#    'FGA',
#    'OR2AT4',
#    'FGB',
#    'DSCAM',
#    'NMUR1',
#    'PIK3CD',
#    'S100Z',
#    'NMRAL2P',
#    'RASGRP4',
#    'BCL2',
#    'C3AR1',
#    'KLF17',
#    'MIR31HG',
#    'FRMD3',
#    'IL16',
#    'CFAP53',
#    'GTPBP2',
#    'PDE3A',
#    'PURG',
#    'TMEM217',
#    'COL6A5',
#    'EGFL7',
#    'MYEOV',
#    'MIR4435-2HG',
#    'XKR3',
#    'HSPA6',
#    'SNCG',
#    'PTPRM',
#    'MOB1B',
#    'NUDT4',
#    'AP000769.1',
#    'STAT5B',
#    'CD7',
#    'HOXB2',
#    'MARCH3',
#    'KLHL15',
#    'SNX31',
#    'SLC6A19',
#    ...]},
#  {'feature_selection_method': 'cell_ranger',
#   'n_features': 3000,
#   'genes': ['CFH',
#    'GCLC',
#    'HECW1',
#    'CASP10',
#    'TFPI',
#    'SLC7A2',
#    'PDK4',
#    'ST7',
#    'SLC4A1',
#    'CALCR',
#    'THSD7A',
#    'ACSM3',
#    'PRKAR2B',
#    'TSPOAP1',
#    'ITGA2B',
#    'TMEM98',
#    'ETV1',
#    'ALDH3B1',
#    'CCL26',
#    'TBXA2R',
#    'SCIN',
#    'PRSS21',
#    'SCN4A',
#    'PAX6',
#    'SYN1',
#    'CYTH3',
#    'MGST1',
#    'MED24',
#    'TENM1',
#    'TRAF3IP3',
#    'GIPR',
#    'CD4',
#    'BTK',
#    'SCMH1',
#    'FYN',
#    'ABHD5',
#    'PLAUR',
#    'DCN',
#    'TYROBP',
#    'GABRA3',
#    'PRICKLE3',
#    'ELOVL5',
#    'ALOX5',
#    'ZC3H3',
#    'IGF1',
#    'SLC38A5',
#    'CNTN1',
#    'WWTR1',
#    'AGPS',
#    'ATP1A2',
#    'ZNF582',
#    'CYP24A1',
#    'HGF',
#    'SAMD4A',
#    'SERPINB1',
#    'NRXN3',
#    'CPS1',
#    'GRAMD1B',
#    'ABCC2',
#    'GCLM',
#    'EHD2',
#    'VIM',
#    'CD44',
#    'AGPAT4',
#    'INSRR',
#    'SH2D2A',
#    'TNFRSF1B',
#    'ANK1',
#    'LRRC7',
#    'GAB2',
#    'APBA2',
#    'STAP1',
#    'FBXO42',
#    'VCAN',
#    'MSR1',
#    'RAI14',
#    'MYO16',
#    'RIPOR3',
#    'LCP2',
#    'TRIT1',
#    'HSPA5',
#    'MAGEC2',
#    'CP',
#    'ARHGAP6',
#    'HDAC9',
#    'CELF2',
#    'ADAMTS6',
#    'TNFRSF9',
#    'LTBP1',
#    'LIMA1',
#    'PTGER3',
#    'MSMO1',
#    'MCF2L2',
#    'PTPRN',
#    'KCNH2',
#    'DCBLD2',
#    'DGKG',
#    'TBXAS1',
#    'SLC2A3',
#    'COL11A1',
#    'BCAT1',
#    'LZTS1',
#    'LTK',
#    'APPBP2',
#    'LIMCH1',
#    'TSPAN32',
#    'SLC12A2',
#    'ABCA7',
#    'OAT',
#    'MYLK',
#    'PRKCQ',
#    'TLE2',
#    'FAM107B',
#    'ME1',
#    'PDE4A',
#    'ASPM',
#    'CD84',
#    'SPI1',
#    'TNFRSF1A',
#    'RASSF1',
#    'ACSL4',
#    'PRR11',
#    'KIF2A',
#    'PAGE1',
#    'PITX1',
#    'TGFBR3',
#    'RAB27A',
#    'UFD1',
#    'SPTB',
#    'DAPP1',
#    'CLTCL1',
#    'DGCR2',
#    'ST6GALNAC1',
#    'FRMPD1',
#    'ASNS',
#    'EIF2B3',
#    'CAMK2A',
#    'OSBPL3',
#    'TRIB2',
#    'MBD3',
#    'MYO3B',
#    'CYBRD1',
#    'ASIC4',
#    'TFRC',
#    'RHOBTB1',
#    'TRHDE',
#    'FCGR2B',
#    'SCARB1',
#    'TP63',
#    'CLCN4',
#    'GSDMB',
#    'PTGS2',
#    'IGF2BP2',
#    'ST6GAL1',
#    'GLI2',
#    'CA12',
#    'NTN4',
#    'SCARF1',
#    'LMAN1',
#    'TXK',
#    'WSCD2',
#    'SEMA3A',
#    'SEMA3C',
#    'ADD2',
#    'FSCN1',
#    'PLD1',
#    'ARHGAP15',
#    'PLXNA2',
#    'MCAM',
#    'RAP1GAP',
#    'RARB',
#    'SPAG6',
#    'NAALAD2',
#    'FGFR1',
#    'ITM2A',
#    'OSBPL6',
#    'TNS1',
#    'CDC14A',
#    'CEACAM1',
#    'DUSP13',
#    'PTPRH',
#    'DCT',
#    'CPOX',
#    'COL4A4',
#    'IMPG2',
#    'ARG2',
#    'MEF2C',
#    'PTPRC',
#    'HSPB11',
#    'IL12RB2',
#    'FYB1',
#    'FAM135A',
#    'TRPM3',
#    'GRHL2',
#    'PLOD1',
#    'OXCT1',
#    'SLC27A5',
#    'ZNF671',
#    'FAT1',
#    'SMAP2',
#    'GSTP1',
#    'SLCO1A2',
#    'CD82',
#    'ABCB1',
#    'AKR1B1',
#    'WNT11',
#    'ORC1',
#    'HBQ1',
#    'CEACAM6',
#    'ERO1B',
#    'PPP1R15A',
#    'FTL',
#    'CASS4',
#    'PIR',
#    'RFX2',
#    'GP6',
#    'KHSRP',
#    'ANKRD10',
#    'ARHGAP28',
#    'SMOX',
#    'TESC',
#    'P2RX7',
#    'SLC23A2',
#    'TMEM230',
#    'FXYD5',
#    'HEPH',
#    'ARHGAP4',
#    'ICAM1',
#    'LYZ',
#    'P3H2',
#    'USP48',
#    'LAMB1',
#    'TXNL1',
#    'SEL1L3',
#    'NLRP1',
#    'ZFHX4',
#    'ZC3HC1',
#    'ESR1',
#    'ANGPT2',
#    'CCDC80',
#    'JPH4',
#    'TYRO3',
#    'SNAP23',
#    'TBX15',
#    'PHGDH',
#    'CLSPN',
#    'UNC13D',
#    'CDC45',
#    'COMT',
#    'PTGS1',
#    'CYP26A1',
#    'SORBS1',
#    'SMIM24',
#    'FKBP5',
#    'DSP',
#    'ABL1',
#    'PCSK5',
#    'PRTFDC1',
#    'MAGEB2',
#    'PRKY',
#    'MKNK2',
#    'KLHL22',
#    'MED15',
#    'SERPIND1',
#    'SNAP29',
#    'CRKL',
#    'P2RX6',
#    'DERL3',
#    'RNF215',
#    'PPIL2',
#    'UPB1',
#    'YPEL1',
#    'MAPK1',
#    'PPM1F',
#    'TOP3B',
#    'CYTH4',
#    'HIRA',
#    'LGALS1',
#    'TPTEP1',
#    'HMOX1',
#    'APOL4',
#    'APOL1',
#    'GRAP2',
#    'SLC25A17',
#    'FAM118A',
#    'MLC1',
#    'DHRS2',
#    'PLTP',
#    'PROCR',
#    'HNF4A',
#    'BMP7',
#    'CTSZ',
#    'TUBB1',
#    'RNF24',
#    'RSPO4',
#    'MYL9',
#    'SNTA1',
#    'PPP1R16B',
#    'LPIN2',
#    'MYOM1',
#    'MID1',
#    'RHOXF1',
#    'ATP1B4',
#    'TLR8',
#    'CACNA1F',
#    'SYP',
#    'LUZP4',
#    'PLS3',
#    'RENBP',
#    'SMARCA1',
#    'MTMR8',
#    'ZC3H12B',
#    'PIM2',
#    'GATA1',
#    'TIMP1',
#    'GABRE',
#    'BEX4',
#    'FGF14',
#    'SGCG',
#    'FLT1',
#    'CENPT',
#    'COTL1',
#    'SLC7A5',
#    'CPPED1',
#    'CORO7-PAM16',
#    'TOX3',
#    'TMC5',
#    'AQP9',
#    'ACSBG1',
#    'CEMIP',
#    'CEP152',
#    'ATP8B4',
#    'SCG3',
#    'INTS9',
#    'CPQ',
#    'CALB1',
#    'NDRG1',
#    'NCALD',
#    'ANXA13',
#    'ERI1',
#    'GSR',
#    'TNFRSF10A',
#    'TUSC3',
#    'FGL1',
#    'ASAH1',
#    'BNIP3L',
#    'TULP2',
#    'TUBB4A',
#    'CD37',
#    'LYL1',
#    'TNNT1',
#    'EBI3',
#    'TGFB1',
#    'SIGLEC8',
#    'ICAM4',
#    'ICAM5',
#    'CD33',
#    'GRIN2D',
#    'SIGLEC6',
#    'ZNF175',
#    'HAS1',
#    'PLEKHA4',
#    'KLF1',
#    'KCNN1',
#    'PDE4C',
#    'ISYNA1',
#    'COPE',
#    'CDK6',
#    'TFPI2',
#    'BET1',
#    'NAMPT',
#    'PIK3CG',
#    'PON3',
#    'PON2',
#    'STEAP1B',
#    'DFNA5',
#    'CPED1',
#    'CPVL',
#    'GRB10',
#    'FKBP14',
#    'EPHB6',
#    'CCL24',
#    'HSPB1',
#    'CYP3A5',
#    'TFR2',
#    'SERPINE1',
#    'ANKMY2',
#    'ACTR3C',
#    'POU6F2',
#    'AGR2',
#    'CLIP2',
#    'CNTNAP3',
#    'MEGF9',
#    'CORO2A',
#    'C5',
#    'PTGR1',
#    'SUSD1',
#    'DOCK8',
#    'KANK1',
#    'CA9',
#    'PIP5K1B',
#    'GLIS3',
#    'PTGDS',
#    'SHB',
#    'GATA3',
#    'CUBN',
#    'UNC5B',
#    'VSIR',
#    'ARHGAP21',
#    'SH3PXD2A',
#    'MAP3K8',
#    'SORCS1',
#    'FBXL20',
#    'UBTF',
#    'TRIM37',
#    'P2RX1',
#    'HOXB6',
#    'ALDH3A1',
#    'ICAM2',
#    'UTP6',
#    'EZH1',
#    'COL1A1',
#    'HDAC5',
#    'ABCC3',
#    'ALDOC',
#    'RAB34',
#    'GNRHR',
#    'NMU',
#    'UCP1',
#    'INPP4B',
#    'CPZ',
#    'RAPGEF2',
#    'SNX25',
#    'LRP2BP',
#    'CTSC',
#    'VWA5A',
#    'IL10RA',
#    'CARS',
#    'SOX6',
#    'EXPH5',
#    'CD69',
#    'CLEC2B',
#    'SELPLG',
#    'CORO1C',
#    'WNT5B',
#    'SH2B3',
#    'ALDH2',
#    'ARHGDIB',
#    'RERGL',
#    'STX2',
#    'ADGRD1',
#    'LDHB',
#    'KLRB1',
#    'GCNT2',
#    'CEP85L',
#    'ADTRP',
#    'FAM184A',
#    'MAN1A1',
#    'PPARD',
#    'RHAG',
#    'PHACTR1',
#    'MDGA1',
#    'BACH2',
#    'GPR63',
#    'COL9A1',
#    'EYA4',
#    'TRIM38',
#    'UNC93A',
#    'PDE10A',
#    'CCND3',
#    'MRPL2',
#    'VEGFA',
#    'TBX18',
#    'HMGCS1',
#    'SPARC',
#    'PDE4D',
#    'LIFR',
#    'PDGFRB',
#    'CPEB4',
#    'DBN1',
#    'BCL6',
#    'HGD',
#    'KAT2B',
#    'PFKFB4',
#    'USP9Y',
#    'GBE1',
#    'MORC1',
#    'PLSCR4',
#    'PLCH1',
#    'TNNC1',
#    'IL1A',
#    'CYTIP',
#    'ACVR1',
#    'FNDC4',
#    'PDE1A',
#    'CCDC88A',
#    'FN1',
#    'IGFBP5',
#    'ST3GAL5',
#    'IL1R1',
#    'IL1RL1',
#    'IL18R1',
#    'IL18RAP',
#    'SLC25A12',
#    'DLX2',
#    'PLCL1',
#    'KYNU',
#    'AC087235.1',
#    'PLEK',
#    'ATF2',
#    'AAK1',
#    'KISS1R',
#    'EPAS1',
#    'ARID3A',
#    'EPHA4',
#    'PAPPA2',
#    'ARHGEF2',
#    'DNAJC6',
#    'LEPR',
#    'PLA2G4A',
#    'CTH',
#    'KIF21B',
#    'AKT3',
#    'ACADM',
#    'SSX2IP',
#    'HMGCL',
#    'P3H1',
#    'SLC2A1',
#    'TNFSF4',
#    'HSD11B1',
#    'RSRP1',
#    'NSL1',
#    'CENPF',
#    'MUC5B',
#    'KIF14',
#    'NRP2',
#    'LRMP',
#    'FILIP1',
#    'CNR1',
#    'SGIP1',
#    'PLAGL1',
#    'TNFAIP3',
#    'MYB',
#    'SPP1',
#    'RARRES1',
#    'CCND2',
#    'ELL2',
#    'GDA',
#    'TRIM67',
#    'CTNNAL1',
#    'PHF19',
#    'GALNT12',
#    'CSF3R',
#    'NEK9',
#    'IRF2BPL',
#    'ESRRB',
#    'IFIT3',
#    'IFIT2',
#    'HOXB8',
#    'HOXB5',
#    'HOXB3',
#    'MOB3B',
#    'ARAP3',
#    'SLC10A7',
#    'PLXDC2',
#    'SOHLH2',
#    'TGFBI',
#    'CLU',
#    'TNFRSF10B',
#    'PTK2B',
#    'TNFRSF8',
#    'EPX',
#    'TEX14',
#    'FAM117A',
#    'ADCY7',
#    'CD80',
#    'CCRL2',
#    'TMEM156',
#    'LRIF1',
#    'PAEP',
#    'CD244',
#    'LRRC39',
#    'WIPF3',
#    'FAM126A',
#    'CALD1',
#    'SRGN',
#    'BICC1',
#    'P4HA1',
#    'HVCN1',
#    'CCDC91',
#    'ADGRE5',
#    'ARHGAP9',
#    'NCKAP1L',
#    'NFE2',
#    'STIL',
#    'HJURP',
#    'LPGAT1',
#    'G0S2',
#    'CTCFL',
#    'SLPI',
#    'WFDC3',
#    'PARD6B',
#    'MCEE',
#    'SERPINB6',
#    'PEX6',
#    'HIST1H2BJ',
#    'DNAH8',
#    'CPNE5',
#    'EREG',
#    'MYRF',
#    'GPR18',
#    'CLYBL',
#    'ABCC4',
#    'SOX21',
#    'SEPT6',
#    'TMEM255A',
#    'SLC25A23',
#    'TNFSF9',
#    'CD70',
#    'C3',
#    'TNFSF14',
#    'GPCPD1',
#    'FOXA2',
#    'PCSK2',
#    'TCF15',
#    'TMEM74B',
#    'ID1',
#    'UROD',
#    'CCR7',
#    'TSKS',
#    'STAT5A',
#    'WNK4',
#    'IFI6',
#    'SSX1',
#    'WDR60',
#    'FAM78A',
#    'NUP214',
#    'CTAG2',
#    'ZC4H2',
#    'MASP1',
#    'PTPRB',
#    'LRRC61',
#    'TRPV5',
#    'ADGRE2',
#    'F2RL3',
#    'TUBA4A',
#    'MGAT3',
#    'TPST2',
#    'RAC2',
#    'KRT17',
#    'POT1',
#    'STRIP2',
#    'FLNC',
#    'OPN1SW',
#    'PDE11A',
#    'GAD1',
#    'ALDH1A2',
#    'PSMA1',
#    'CSRP3',
#    'MTUS1',
#    'SIGLEC9',
#    'EGLN3',
#    'RNASE1',
#    'EPB41L4A',
#    'ARHGEF6',
#    'FGF13',
#    'ASH2L',
#    'CDKN1C',
#    'PLPPR3',
#    'SYT5',
#    'TNNI3',
#    'CBFA2T3',
#    'SAT1',
#    'CNN1',
#    'APOE',
#    'APOC1',
#    'LRCH2',
#    'BST2',
#    'SNX9',
#    'UNC13A',
#    'KLHDC7B',
#    'GDF15',
#    'HRC',
#    'UBAC1',
#    'HBZ',
#    'GATA5',
#    'GMFG',
#    'SESN2',
#    'ZNF426',
#    'SLC6A8',
#    'PNCK',
#    'MPP1',
#    'FBP2',
#    'AKAP12',
#    'GGT7',
#    'ACSS2',
#    'IDO1',
#    'SLC6A6',
#    'LRRC4B',
#    'PDLIM4',
#    'BARX1',
#    'MAP1B',
#    'TNS4',
#    'TOP2A',
#    'RTBDN',
#    'FCRLA',
#    'LINC00470',
#    'EMILIN2',
#    'ARFIP2',
#    'TRIM5',
#    'PRKAA1',
#    'CARD6',
#    'SERPINF1',
#    'ZRANB2',
#    'GPS2',
#    'SNAP25',
#    'NES',
#    'BCAN',
#    'CASP9',
#    'MORC4',
#    'LGALS12',
#    'RARRES3',
#    'LARGE1',
#    'MYO18B',
#    'ZDHHC8P1',
#    'NTS',
#    'CA1',
#    'AMPD3',
#    'MICALCL',
#    'MICAL2',
#    'TEX15',
#    'CATSPERB',
#    'LOXL2',
#    'IRAK2',
#    'BHLHE40',
#    'MEIS2',
#    'PTPN22',
#    'LPIN1',
#    'IL6ST',
#    'CRB1',
#    'IL15RA',
#    'DOCK2',
#    'SOX5',
#    'YARS',
#    'ZCCHC11',
#    'TPGS2',
#    'SLC43A3',
#    'APLNR',
#    'FADS2',
#    'TCN1',
#    'DZIP1',
#    'ETS1',
#    'ANXA1',
#    'GOLM1',
#    'PSAT1',
#    'ADAM19',
#    'KCP',
#    'TES',
#    'ADGRB3',
#    'MRAP2',
#    'CGA',
#    'LMO2',
#    'AMHR2',
#    'TESPA1',
#    'TFCP2',
#    'KRT7',
#    'TEC',
#    'MDM2',
#    'EGLN1',
#    'GLUL',
#    'NPL',
#    'FAM129A',
#    'DOCK10',
#    'TMBIM1',
#    'ALDH1L2',
#    'USP44',
#    'LCP1',
#    'TNS3',
#    'IGF2BP3',
#    'IL6',
#    'MYO1G',
#    'CIB2',
#    'BRIP1',
#    'SCN2A',
#    'GALNT5',
#    'RPS6KC1',
#    'GYPC',
#    'TMOD1',
#    'ANGPTL2',
#    'HEMGN',
#    'TLN1',
#    'PIM1',
#    'GMPR',
#    'KIAA0319',
#    'TUBB2B',
#    'HMGA1',
#    'TPMT',
#    'SLCO2B1',
#    'SYTL2',
#    'PI15',
#    'NEK1',
#    'PAQR5',
#    'ITPKA',
#    'PLCB2',
#    'TTLL7',
#    'GIPC2',
#    'SLC44A5',
#    'PLCE1',
#    'ADAMTS14',
#    'TET1',
#    'FASTKD1',
#    'IDH1',
#    'SLC40A1',
#    'CILP',
#    'PARP16',
#    'SEMA7A',
#    'FAM13A',
#    'NDST4',
#    'FGF5',
#    'GPAT3',
#    'FGF2',
#    'BMPR1B',
#    'TRPC3',
#    'BMP2K',
#    'CENPE',
#    'LEF1',
#    'EGF',
#    'FBN2',
#    'CPNE8',
#    'C1RL',
#    'RBP5',
#    'INHBE',
#    'DHH',
#    'ACVRL1',
#    'DIAPH3',
#    'MBNL2',
#    'KCNH5',
#    'STON2',
#    'WARS',
#    'HDC',
#    'GCNT3',
#    'IGF1R',
#    'CYP11A1',
#    'PCSK6',
#    'NTRK3',
#    'MFGE8',
#    'SH3GL3',
#    'ITGAX',
#    'MYLK3',
#    'KIFC3',
#    'RPL3L',
#    'KSR1',
#    'SPACA3',
#    'ABCA8',
#    'BCAS3',
#    'SLC39A6',
#    'TMC6',
#    'TTYH2',
#    'NARF',
#    'RNF157',
#    'PNMT',
#    'SLC39A3',
#    'VAV1',
#    'DMRTC2',
#    'URB1',
#    'EMP3',
#    'ADAMTS10',
#    'MYO1F',
#    'SIGLEC10',
#    'PGD',
#    'HSPG2',
#    'ITGB3BP',
#    'TINAGL1',
#    'KIF2C',
#    'BEST4',
#    'CD53',
#    'MGST3',
#    'ADCY10',
#    'FCGR2A',
#    'ECM1',
#    'ADAMTSL4',
#    'SEMA6C',
#    'DTL',
#    'INTS7',
#    'AQP10',
#    'PKLR',
#    'CEP170',
#    'CDC42BPA',
#    'MBOAT2',
#    'LBR',
#    'EPHX1',
#    'REN',
#    'PPFIA4',
#    'PTPN7',
#    'GALM',
#    'ST6GAL2',
#    'FAHD2B',
#    'GALNT13',
#    'LNPK',
#    'PTH2R',
#    'GADL1',
#    'ZNF660',
#    'MYH15',
#    'IGSF11',
#    'TMEM108',
#    'ALDH1L1',
#    'TM4SF19',
#    'MUC4',
#    'SNCA',
#    'CAMK2D',
#    'MYO10',
#    'SSBP2',
#    'IQGAP2',
#    'LIX1',
#    'TSLP',
#    'TNFAIP8',
#    'ADAMTS19',
#    'ARHGAP26',
#    'RNF145',
#    'TNIP1',
#    'CPLX2',
#    'GFOD1',
#    'KLHL3',
#    'DCDC2',
#    'PPP1R18',
#    'LGSN',
#    'RNF217',
#    'RSPO3',
#    'ARHGAP18',
#    'SLC18B1',
#    'SLC2A12',
#    'AIG1',
#    'SLC22A3',
#    'VWDE',
#    'SDK1',
#    'CREB5',
#    'EGFR',
#    'IGFBP3',
#    'SSC4D',
#    'TMEM168',
#    'TMEM209',
#    'MSN',
#    'IL2RG',
#    'DOCK11',
#    'CSGALNACT1',
#    'DOK2',
#    'SLC25A37',
#    'DOCK5',
#    'STAR',
#    'RGS20',
#    'DPYS',
#    'LRP12',
#    'FAM83A',
#    'PLIN2',
#    'SIGMAR1',
#    'GBGT1',
#    'PTGES',
#    'USP6NL',
#    'FAM171A1',
#    'ST8SIA6',
#    'ANKRD30A',
#    'ADD3',
#    'MKI67',
#    'ITPRIP',
#    'GAS2',
#    'SLC5A12',
#    'IMMP1L',
#    'ZNF215',
#    'SLC43A1',
#    'PTPRJ',
#    'CCDC82',
#    'CAPN5',
#    'NPAT',
#    'HYOU1',
#    'FADS1',
#    'MS4A3',
#    'MS4A2',
#    'KIRREL3',
#    'FERMT3',
#    'CNTN5',
#    'KLRF1',
#    'IL18',
#    'CRIM1',
#    'SEC24D',
#    'ITPR1',
#    'SLC7A11',
#    'ENKUR',
#    'NGLY1',
#    'BTBD11',
#    'NPAS3',
#    'AKR1C2',
#    'VENTX',
#    'RNF144A',
#    'AMN1',
#    'NBAS',
#    'ZNF385D',
#    'SLC35F4',
#    'GFRA1',
#    'ASTN1',
#    'POU4F1',
#    ...]},
#  {'feature_selection_method': 'cell_ranger',
#   'n_features': 4000,
#   'genes': ['CFH',
#    'GCLC',
#    'WNT16',
#    'HECW1',
#    'KLHL13',
#    'CASP10',
#    'TFPI',
#    'SLC7A2',
#    'AK2',
#    'CD38',
#    'PDK4',
#    'ST7',
#    'SLC4A1',
#    'CALCR',
#    'THSD7A',
#    'ACSM3',
#    'PRKAR2B',
#    'TSPOAP1',
#    'ITGA2B',
#    'TMEM98',
#    'MAP3K14',
#    'BAIAP2L1',
#    'ETV1',
#    'ALDH3B1',
#    'CCL26',
#    'USH1C',
#    'TBXA2R',
#    'SCIN',
#    'PRSS21',
#    'SCN4A',
#    'PAX6',
#    'SELE',
#    'MYLIP',
#    'NOX1',
#    'SYN1',
#    'CYTH3',
#    'MGST1',
#    'PKD1',
#    'MED24',
#    'TENM1',
#    'TRAF3IP3',
#    'GIPR',
#    'PRSS3',
#    'CD4',
#    'LRRC23',
#    'BTK',
#    'SCMH1',
#    'FYN',
#    'ABHD5',
#    'PLAUR',
#    'DCN',
#    'TYROBP',
#    'GABRA3',
#    'BRCA1',
#    'PRICKLE3',
#    'ELOVL5',
#    'ALOX5',
#    'ZC3H3',
#    'IGF1',
#    'SLC38A5',
#    'CNTN1',
#    'WWTR1',
#    'AGPS',
#    'ATP1A2',
#    'ZNF582',
#    'CYP24A1',
#    'SYT13',
#    'HGF',
#    'SAMD4A',
#    'SERPINB1',
#    'CYP3A43',
#    'NRXN3',
#    'CPS1',
#    'NLRP2',
#    'SLC45A4',
#    'GRAMD1B',
#    'BIRC3',
#    'ABCC2',
#    'GCLM',
#    'EHD2',
#    'VIM',
#    'CD44',
#    'AGPAT4',
#    'SLAMF7',
#    'BTN3A1',
#    'INSRR',
#    'SH2D2A',
#    'TNFRSF1B',
#    'POU2F2',
#    'ANK1',
#    'RANBP3',
#    'ABCF2',
#    'LRRC7',
#    'GAB2',
#    'APBA2',
#    'VCL',
#    'STAP1',
#    'FBXO42',
#    'TLL1',
#    'VCAN',
#    'MSR1',
#    'RAI14',
#    'MYO16',
#    'RIPOR3',
#    'LCP2',
#    'TRIT1',
#    'CNTLN',
#    'HSPA5',
#    'MAGEC2',
#    'PREX2',
#    'CP',
#    'XK',
#    'ARHGAP6',
#    'HDAC9',
#    'CELF2',
#    'ADAMTS6',
#    'TNFRSF9',
#    'LTBP1',
#    'LIMA1',
#    'PTGER3',
#    'MSMO1',
#    'ALX4',
#    'MCF2L2',
#    'NRIP2',
#    'OPN3',
#    'PTPRN',
#    'KCNH2',
#    'NPFFR2',
#    'DCBLD2',
#    'PRDM1',
#    'ATP2B4',
#    'DGKG',
#    'TBXAS1',
#    'SLC2A3',
#    'SNRNP40',
#    'COL11A1',
#    'BCAT1',
#    'HDAC7',
#    'LZTS1',
#    'LTK',
#    'APPBP2',
#    'CA11',
#    'LIMCH1',
#    'TSPAN32',
#    'TMEM161A',
#    'SLC12A2',
#    'ABCA7',
#    'FAR2',
#    'OAT',
#    'TBC1D22B',
#    'MYLK',
#    'PRKCQ',
#    'TLE2',
#    'FAM107B',
#    'ME1',
#    'PDE4A',
#    'ASPM',
#    'CD84',
#    'SPI1',
#    'FECH',
#    'PLPP1',
#    'TNFRSF1A',
#    'EVI5',
#    'SYT1',
#    'RASSF1',
#    'ACSL4',
#    'PRR11',
#    'KIF2A',
#    'PPP2R5B',
#    'PAGE1',
#    'PITX1',
#    'TGFBR3',
#    'RAB27A',
#    'UFD1',
#    'SPTB',
#    'DAPP1',
#    'CLTCL1',
#    'DGCR2',
#    'ST6GALNAC1',
#    'FRMPD1',
#    'ASNS',
#    'EIF2B3',
#    'CAMK2A',
#    'OSBPL3',
#    'TRIB2',
#    'MBD3',
#    'MYO3B',
#    'CYBRD1',
#    'ASIC4',
#    'TFRC',
#    'RHOBTB1',
#    'TRHDE',
#    'P4HA2',
#    'FCGR2B',
#    'ACAP1',
#    'MRVI1',
#    'SCARB1',
#    'MOV10L1',
#    'TP63',
#    'CLCN4',
#    'FNDC8',
#    'GSDMB',
#    'DHRS9',
#    'PTGS2',
#    'IGF2BP2',
#    'ST6GAL1',
#    'GLI2',
#    'CA12',
#    'NTN4',
#    'SCARF1',
#    'LMAN1',
#    'TUBE1',
#    'TXK',
#    'WSCD2',
#    'SEMA3A',
#    'SEMA3C',
#    'ADD2',
#    'FSCN1',
#    'PLD1',
#    'ARHGAP15',
#    'PLXNA2',
#    'MCAM',
#    'RAP1GAP',
#    'RARB',
#    'SPAG6',
#    'NAALAD2',
#    'FGFR1',
#    'ITM2A',
#    'CDH17',
#    'FKBP7',
#    'OSBPL6',
#    'TNS1',
#    'REXO1',
#    'CDC14A',
#    'CEACAM1',
#    'DUSP13',
#    'FDFT1',
#    'SCGN',
#    'PTPRH',
#    'DCT',
#    'SLC4A4',
#    'CPOX',
#    'CXCL2',
# ...
#    'KATNAL1',
#    'INTS6',
#    'PHKB',
#    'CENPT',
#    'CYB5B',
#    'SLC38A7',
#    'VAC14',
#    'SMPD3',
#    'FA2H',
#    'NPRL3',
#    'COTL1',
#    'CRISPLD2',
#    'ABCC1',
#    'CLCN7',
#    'SLC7A5',
#    'CRYM',
#    'CPPED1',
#    'CORO7-PAM16',
#    'TOX3',
#    'QPRT',
#    'RPGRIP1L',
#    'TMC5',
#    'AQP9',
#    'RASL12',
#    'ACSBG1',
#    'IGDCC4',
#    'CEMIP',
#    'RPAP1',
#    'TMEM87A',
#    'ZNF106',
#    'CEP152',
#    'ATP8B4',
#    'OCA2',
#    'SCG3',
#    'DNAJC17',
#    'SPG11',
#    'ZFAND1',
#    'INTS9',
#    'TRPA1',
#    'CPQ',
#    'CALB1',
#    'SFRP1',
#    'LAPTM4B',
#    'PLAT',
#    'NDRG1',
#    'IL7',
#    'TRPS1',
#    'NCALD',
#    'ANXA13',
#    'ERI1',
#    'GSR',
#    'TNFRSF10A',
#    'PPP2CB',
#    'TUSC3',
#    'KCTD9',
#    'FGL1',
#    'ASAH1',
#    'BNIP3L',
#    'KCNN4',
#    'TULP2',
#    'DHDH',
#    'HNRNPL',
#    'TUBB4A',
#    'RELB',
#    'PIH1D1',
#    'CKM',
#    'DOT1L',
#    'SLC17A7',
#    'CD37',
#    'LYL1',
#    'TRMT1',
#    'DMPK',
#    'TLE6',
#    'AES',
#    'SGTA',
#    'TIMM44',
#    'TNNT1',
#    'ANKRD27',
#    'FBL',
#    'PRX',
#    'NUMBL',
#    'EBI3',
#    'SHD',
#    'ZFR2',
#    'BBC3',
#    'TGFB1',
#    'PLIN3',
#    'SIGLEC8',
#    'ICAM4',
#    'ICAM5',
#    'CD33',
#    'CEACAM5',
#    'SULT2A1',
#    'PTPRS',
#    'GRIN2D',
#    'CCDC114',
#    'CARD8',
#    'SIGLEC6',
#    'ZNF175',
#    'CABP5',
#    'HAS1',
#    'RASIP1',
#    'BCAT2',
#    'MIER2',
#    'PLEKHA4',
#    'KLF1',
#    'JAK3',
#    'KCNN1',
#    'PDE4C',
#    'ISYNA1',
#    'ELL',
#    'COPE',
#    'FKBP8',
#    'ERF',
#    'GRIK5',
#    'RASA4',
#    'CDK6',
#    'TFPI2',
#    'BET1',
#    'NAMPT',
#    'TWISTNB',
#    'PIK3CG',
#    'PON3',
#    'PON2',
#    'MTPN',
#    'STEAP1B',
#    'DFNA5',
#    'ZC3HAV1',
#    'TFEC',
#    'MET',
#    'HOXA1',
#    'HOXA3',
#    'ANKRD7',
#    'CPED1',
#    'HIBADH',
#    'CPVL',
#    'CHN2',
#    'GRB10',
#    'FKBP14',
#    'NOD1',
#    'GARS',
#    'EPHB6',
#    'GHRHR',
#    'CHCHD2',
#    'CCL24',
#    'CYP3A5',
#    'TFR2',
#    'RBM28',
#    'SERPINE1',
#    'CLDN15',
#    'NOBOX',
#    'EZH2',
#    'SFRP4',
#    'ANKMY2',
#    'ACTR3C',
#    'POU6F2',
#    'AGR2',
#    'GIMAP2',
#    'TMEM176B',
#    'RHEB',
#    'TBL2',
#    'CLIP2',
#    'SPATA6L',
#    'CNTNAP3',
#    'MEGF9',
#    'CORO2A',
#    'TGFBR1',
#    'C5',
#    'OGN',
#    'ASPN',
#    'ECM2',
#    'PTGR1',
#    'SUSD1',
#    'AMBP',
#    'AKNA',
#    'ENG',
#    'DOCK8',
#    'KANK1',
#    'CA9',
#    'DDX58',
#    'PIP5K1B',
#    'GLIS3',
#    'RAPGEF1',
#    'PTGDS',
#    'SHB',
#    'EXOSC3',
#    'ZFAND5',
#    'PDLIM1',
#    'GATA3',
#    'ATRNL1',
#    'HPS1',
#    'RASSF4',
#    'CUBN',
#    'TRDMT1',
#    'ATE1',
#    'UNC5B',
#    'VSIR',
#    'PPP3CB',
#    'NPM3',
#    'ARHGAP21',
#    'CPEB3',
#    'SH3PXD2A',
#    'MAP3K8',
#    'SORCS1',
#    'XPNPEP1',
#    'UBE2S',
#    'DNAJC12',
#    'UBTF',
#    'RNF43',
#    'WNT3',
#    'P2RX1',
#    'HOXB6',
#    'CHRNE',
#    'BLMH',
#    'ALDH3A1',
#    'ICAM2',
#    'UTP6',
#    'C17orf75',
#    'CYTH1',
#    'LGALS3BP',
#    'ASIC2',
#    'CCL2',
#    'PEX12',
#    'EZH1',
#    'COL1A1',
#    'MRPL27',
#    'VAT1',
#    'ALOX12',
#    'HDAC5',
#    'ABCC3',
#    'EFTUD2',
#    'WSB1',
#    'VTN',
#    'PMP22',
#    'ALDOC',
#    'RAB34',
#    'PHF12',
#    'GNRHR',
#    'CHIC2',
#    'NMU',
#    'AREG',
#    'MANBA',
#    'UBE2D3',
#    'UCP1',
#    'TBC1D9',
#    'INPP4B',
#    'CPE',
#    'CLCN3',
#    'CPZ',
#    'SLC2A9',
#    'FBXW7',
#    'SH3D19',
#    'RAPGEF2',
#    'SNX25',
#    'LRP2BP',
#    'UFSP2',
#    'PPARGC1A',
#    'CRYAB',
#    'CTSC',
#    'CCDC34',
#    'ELP4',
#    'ZPR1',
#    'VWA5A',
#    'LPXN',
#    'ATG2A',
#    'OSBP',
#    'PUS3',
#    'MS4A4A',
#    'HPX',
#    'TRIM3',
#    'CHORDC1',
#    'IL10RA',
#    'FBXO3',
#    'CARS',
#    'SLC35F2',
#    'SOX6',
#    'PITPNM1',
#    'NUP98',
#    'EXPH5',
#    'HPS5',
#    'P3H3',
#    'CD69',
#    'CLEC2B',
#    'SELPLG',
#    'CORO1C',
#    'CAPRIN2',
#    'ATP5B',
#    'PPM1H',
#    'WNT5B',
#    'SH2B3',
#    'DUSP16',
#    'ALDH2',
#    'GSG1',
#    'MGP',
#    'ARHGDIB',
#    'RERGL',
#    'STX2',
#    'ADGRD1',
#    'CHD4',
#    'ACRBP',
#    'ENO2',
#    'LPCAT3',
#    'NT5DC3',
#    'GYS2',
#    'LDHB',
#    'ST8SIA1',
#    'KLRB1',
#    ...]},
#  {'feature_selection_method': 'seurat',
#   'n_features': 8000,
#   'genes': ['CFH',
#    'GCLC',
#    'STPG1',
#    'LAS1L',
#    'KRIT1',
#    'HS3ST1',
#    'AOC1',
#    'WNT16',
#    'HECW1',
#    'MAD1L1',
#    'M6PR',
#    'KLHL13',
#    'CYP26B1',
#    'ALS2',
#    'CASP10',
#    'TFPI',
#    'AK2',
#    'CD38',
#    'CAMKK1',
#    'RECQL',
#    'HSPB6',
#    'PDK4',
#    'ZMYND10',
#    'ARX',
#    'SLC25A13',
#    'ST7',
#    'SLC4A1',
#    'CALCR',
#    'DVL2',
#    'SKAP2',
#    'THSD7A',
#    'RPAP3',
#    'ACSM3',
#    'CIAPIN1',
#    'FAM214B',
#    'PRKAR2B',
#    'TSPOAP1',
#    'PON1',
#    'RHBDD2',
#    'IBTK',
#    'ZNF195',
#    'MYCBP2',
#    'FBXL3',
#    'ITGA3',
#    'LAMP2',
#    'ITGA2B',
#    'TMEM98',
#    'MAP3K14',
#    'AP2B1',
#    'BAIAP2L1',
#    'KDM7A',
#    'ETV1',
#    'ALDH3B1',
#    'PHTF2',
#    'CCL26',
#    'USH1C',
#    'TBXA2R',
#    'VPS41',
#    'SCIN',
#    'PNPLA4',
#    'MYH13',
#    'CDKL3',
#    'UPP2',
#    'PRSS21',
#    'PROM1',
#    'CEACAM21',
#    'MATK',
#    'SCN4A',
#    'ST7L',
#    'PAX6',
#    'LUC7L',
#    'SELE',
#    'DNAJC11',
#    'MYLIP',
#    'NOX1',
#    'E2F2',
#    'PSMB1',
#    'SYN1',
#    'CYTH3',
#    'MGST1',
#    'CRY1',
#    'ST3GAL1',
#    'PKD1',
#    'MED24',
#    'TENM1',
#    'MASP2',
#    'TRAF3IP3',
#    'MLXIPL',
#    'RANBP9',
#    'ETV7',
#    'ZNF207',
#    'UQCRC1',
#    'GIPR',
#    'PRSS3',
#    'CD4',
#    'LRRC23',
#    'BTK',
#    'SCMH1',
#    'FYN',
#    'APBA3',
#    'ABHD5',
#    'DPF1',
#    'PIK3C2A',
#    'PLAUR',
#    'DCN',
#    'TYROBP',
#    'GABRA3',
#    'ERCC1',
#    'PRICKLE3',
#    'LTF',
#    'NR1H4',
#    'ELOVL5',
#    'ALOX5',
#    'KDM5D',
#    'CALCOCO1',
#    'CLDN11',
#    'SLC25A39',
#    'PGM3',
#    'GPRC5A',
#    'ZC3H3',
#    'YAF2',
#    'CLCA1',
#    'GLT8D1',
#    'IGF1',
#    'SLC38A5',
#    'CNTN1',
#    'SLC11A1',
#    'WWTR1',
#    'AGPS',
#    'ATP1A2',
#    'ZNF582',
#    'CYP24A1',
#    'SYT13',
#    'CD74',
#    'HGF',
#    'NCDN',
#    'SAMD4A',
#    'RUNX3',
#    'MRE11',
#    'SERPINB1',
#    'CYP3A43',
#    'NRXN3',
#    'AQR',
#    'CPS1',
#    'NLRP2',
#    'SLC45A4',
#    'GRAMD1B',
#    'RB1CC1',
#    'ERP44',
#    'ALAS1',
#    'BIRC3',
#    'ABCC2',
#    'DEF6',
#    'GCLM',
#    'EHD2',
#    'TYMP',
#    'SEC63',
#    'VIM',
#    'RNASET2',
#    'CD44',
#    'KCNG1',
#    'AGPAT4',
#    'SLAMF7',
#    'BTN3A1',
#    'INSRR',
#    'IFNGR1',
#    'SH2D2A',
#    'TNFRSF1B',
#    'POU2F2',
#    'TBPL1',
#    'ARNTL2',
#    'ANK1',
#    'TFB1M',
#    'NUP160',
#    'FAM13B',
#    'RANBP3',
#    'ABCF2',
#    'LRRC7',
#    'UBA6',
#    'GAB2',
#    'ATP6V0A1',
#    'APBA2',
#    'RNF19A',
#    'VCL',
#    'NSMAF',
#    'STAP1',
#    'RFC1',
#    'ZZZ3',
#    'USP2',
#    'FBXO42',
#    'HOXC8',
#    'TLL1',
#    'VCAN',
#    'MSR1',
#    'RAI14',
#    'PNKP',
#    'STAU2',
#    'PHF23',
#    'CDH10',
#    'RAB27B',
#    'MYO16',
#    'TNC',
#    'RIPOR3',
#    'AIFM2',
#    'CAPG',
#    'AP2S1',
#    'ADAM28',
#    'DCUN1D1',
#    'LCP2',
#    'TRIT1',
#    'CUL7',
#    'PHKA2',
#    'CNTLN',
#    'HSPA5',
#    'GEMIN8',
#    'MAGEC2',
#    'PREX2',
#    'CP',
#    'DTNBP1',
#    'XK',
#    'ARHGAP6',
#    'GOPC',
#    'USP28',
#    'HDAC9',
#    'ZNF800',
#    'LMO3',
#    'MRPS10',
#    'VPS13D',
#    'CELF2',
#    'ADAMTS6',
#    'UTS2',
#    'TNFRSF9',
#    'LTBP1',
#    'RFC2',
#    'NEDD4L',
#    'NFE2L3',
#    'LIMA1',
#    'PTGER3',
#    'TNIP3',
#    'COL23A1',
#    'FAM160A2',
#    'HERPUD1',
#    'POLQ',
#    'MPHOSPH9',
#    'RRP12',
#    'FNIP2',
#    'MSMO1',
#    'ALX4',
#    'FSTL4',
#    'MCF2L2',
#    'NRIP2',
#    'OPN3',
#    'SDCCAG8',
#    'PTPRN',
#    'KCNH2',
#    'FAM114A2',
#    'HPF1',
#    'NPFFR2',
#    'TRAF1',
#    'DCBLD2',
#    'MSH4',
#    'PRDM1',
#    'ATG5',
#    'ATP11B',
#    'RASGRF1',
#    'ATP2B4',
#    'YIPF1',
#    'NDC1',
#    'DGKG',
#    'UNKL',
#    'TBXAS1',
#    'PARP12',
#    'GATB',
#    'CDK17',
#    'SLC2A3',
#    'SNRNP40',
#    'COL11A1',
#    'MPC1',
#    'BCAT1',
#    'HDAC7',
#    'LZTS1',
#    'SPAG4',
#    'NCKAP1',
#    'LTK',
#    'SEZ6',
#    'SLC6A16',
#    'CA11',
#    'ZNF275',
#    'LIMCH1',
#    'TSPAN32',
#    'TAF2',
#    'TMEM161A',
#    'SLC12A2',
#    'ABCA7',
#    'FAR2',
#    'BCAS1',
#    'CALCRL',
#    'AP3D1',
#    'NTHL1',
#    'OAT',
#    'PKN2',
#    'TRAM2',
#    'TBC1D22B',
#    'MYLK',
#    'TMEM206',
#    'PRKCQ',
#    'TLE2',
#    'FAM107B',
#    'ME1',
#    'PDE4A',
#    'PPP2R5A',
#    'CTNNA2',
#    'ELAVL1',
#    'SLC9A3',
#    'ASPM',
#    'CD84',
#    'SPI1',
#    'LRRC40',
#    'FECH',
#    'KLF6',
#    'PLPP1',
#    'TRAM1',
#    'PHKA1',
#    'TNFRSF1A',
#    'CACNB1',
#    'EVI5',
#    'DNTTIP2',
#    'TP53BP1',
#    'RHOA',
#    'SYT1',
#    'HDAC4',
#    'RASSF1',
#    'OTUD5',
#    'TFE3',
#    'ACSL4',
#    'PRR11',
#    'POLR1A',
#    'SRBD1',
#    'KIF2A',
#    'RASGRP2',
#    'IFT80',
#    'SIRT2',
#    'PPP2R5B',
#    'PAGE1',
#    'PITX1',
#    'NUP133',
#    'VPS35',
#    'KCNAB2',
#    'ABCC9',
#    'DRD4',
#    'TGFBR3',
#    'ATP1B3',
#    'NEDD4',
#    'RAB27A',
#    'UFD1',
#    'LRP6',
#    'GUCY2C',
#    'ELP1',
#    'SPTB',
#    'DAPP1',
#    'CLTCL1',
#    'DGCR2',
#    'RNF126',
#    'MNT',
#    'JMJD6',
#    'ST6GALNAC1',
#    'FRMPD1',
#    'ASNS',
#    'TESK2',
#    'CSNK2A2',
#    'EIF2B3',
#    'CAMK2A',
#    'OSBPL3',
#    'RAD18',
#    'WDR1',
#    'SEL1L',
#    'TCF3',
#    'TRIB2',
#    'MBD3',
#    'HLTF',
#    'CPSF1',
#    'MYO3B',
#    'CYBRD1',
#    'CDH19',
#    'PDCD2',
#    'ADGRL1',
#    'LIMS2',
#    'ASIC4',
#    'ALDH3A2',
#    'TFRC',
#    'SREBF1',
#    'RHOBTB1',
#    'SMC1A',
#    'HMMR',
#    'TRHDE',
#    'P4HA2',
#    'FCGR2B',
#    'ACAP1',
#    'MRVI1',
#    'XRCC1',
#    'SCARB1',
#    'MOV10L1',
#    'TP63',
#    'CLCN4',
#    'FNDC8',
#    'GSDMB',
#    'KDM5A',
#    'ABCB11',
#    'DHRS9',
#    'CD5L',
#    'PTGS2',
#    'IGF2BP2',
#    'ST6GAL1',
#    'PICALM',
#    'GLI2',
#    'CLNS1A',
#    'TEAD2',
#    'ATP2A3',
#    'CA12',
#    'NTN4',
#    'SCARF1',
#    'LMAN1',
#    'MYDGF',
#    'ANO8',
#    'TUBE1',
#    'TXK',
#    'WSCD2',
#    'TIPIN',
#    'SEMA3A',
#    'SEMA3C',
#    'SLC25A40',
#    'ADD2',
#    'FNDC3B',
#    'FSCN1',
#    'ACTB',
#    'PLD1',
#    'SEC31B',
#    'SART3',
#    'ARHGAP15',
#    'KIFAP3',
#    'MCM6',
#    'RBMS2',
#    'BAZ2A',
#    'PLXNA2',
#    'SPAG5',
#    'MCAM',
#    'RAP1GAP',
#    'XAB2',
#    'DGKD',
#    'ACTL6B',
#    'RARB',
#    'USP33',
#    'SPAG6',
#    'EXOSC5',
#    'FAM76B',
#    'ACTN2',
#    'NAALAD2',
#    'FGFR1',
#    'PIAS2',
#    'LAMP3',
#    'FAP',
#    'PIK3C3',
#    'SYNJ2',
#    'PPP2R5C',
#    'EDN1',
#    'ITM2A',
#    'MYH7B',
#    'CDH17',
#    'THOC1',
#    'FKBP7',
#    'OSBPL6',
#    'LXN',
#    'MKNK1',
#    'TNS1',
#    'REXO1',
#    'CDC14A',
#    'CEACAM1',
#    'DUSP13',
#    'LIPE',
#    'FDFT1',
#    'OPHN1',
#    'SCGN',
#    'EPB41L2',
#    'RIMS1',
#    'STX7',
#    'PTPRH',
#    'DCT',
#    'SCTR',
#    'RFX3',
#    'SLC4A4',
#    'SESN1',
#    'PUM3',
#    'CPB2',
#    'KCNN2',
#    'CNOT4',
#    'CPOX',
#    'CLDND1',
#    'RBL1',
#    'NDC80',
#    'RSBN1',
#    'CXCL2',
#    'COL4A4',
#    'IMPG2',
#    'ARG2',
#    'MEF2C',
#    'PTPRC',
#    'STK17B',
#    'CDC14B',
#    'HSPB11',
#    'PHLPP1',
#    'ATP8B1',
#    'IL12RB2',
#    'FYB1',
#    'MPP4',
#    'C1QTNF3',
#    'FAM135A',
#    'TRPM3',
#    'KAT6A',
#    'GRHL2',
#    'PLOD1',
#    'DIS3',
#    'PIBF1',
#    'OXCT1',
#    'SLC27A5',
#    'ZNF671',
#    'ZNF416',
#    'ZNF586',
#    'ZNF264',
#    'FAT1',
#    'SMAP2',
#    'SSH1',
#    'GSTP1',
#    'SLCO1A2',
#    'KIF3C',
#    'GCKR',
#    'HADHA',
#    'CD82',
#    'PREP',
#    'HACE1',
#    'WDFY1',
#    'MAP3K4',
#    'ABCB1',
#    'AKR1B1',
#    'WNT11',
#    'ORC1',
#    'CHERP',
#    'USP40',
#    'B4GALT1',
#    'DIMT1',
#    'MRPL28',
#    'HBQ1',
#    'CEACAM6',
#    'ERO1B',
#    'ZW10',
#    'ALG9',
#    'MTMR2',
#    'PPP1R15A',
#    'HSD17B14',
#    'ACHE',
#    'FTL',
#    'PIGS',
#    'ATXN7L3',
#    'PTHLH',
#    'AURKA',
#    'CASS4',
#    'PIR',
#    'AAMDC',
#    'RFX2',
#    'GP6',
#    'KHSRP',
#    'ASAP3',
#    'DNMT3B',
#    'TPX2',
#    'EPB41L1',
#    'DOCK9',
#    'ANKRD10',
#    'TGDS',
#    'C3orf18',
#    'ARHGAP28',
#    'SMOX',
#    'FKBP1A',
#    'NSFL1C',
#    'SLC4A11',
#    'C20orf194',
#    'ZNF343',
#    'CPXM1',
#    'LZTS3',
#    'KIZ',
#    'TESC',
#    'P2RX7',
#    'SLC23A2',
#    'SLC8B1',
#    'TMEM230',
#    'KDM2B',
#    'FXYD5',
#    'GRAMD1A',
#    'HEPH',
#    'KCNH4',
#    'GANAB',
#    'ARHGAP4',
#    'LTBP4',
#    'BLVRB',
#    'ICAM1',
#    'LYZ',
#    'MUL1',
#    'P3H2',
#    'FLT3LG',
#    'PABPC4',
#    'USP48',
#    'AARS',
#    'KIF4A',
#    'PITPNM2',
#    'OSBPL8',
#    'PUS7',
#    'LAMB1',
#    'SLC26A4',
#    'TXNL1',
#    'IL5RA',
#    'ABCC6',
#    'CMTM6',
#    'ITGA6',
#    'FH',
#    'SEL1L3',
#    'TF',
#    'APOH',
#    'NLRP1',
#    'ZFHX4',
#    'ZC3HC1',
#    'ESR1',
#    'ANGPT2',
#    'CCDC80',
#    'JPH4',
#    'SLC7A8',
#    'TBL1Y',
#    'TYRO3',
#    'SNAP23',
#    'TBX15',
#    'PHGDH',
#    'AGO1',
#    'CLSPN',
#    'RFFL',
#    'UNC13D',
#    'MFSD11',
#    'TGFB2',
#    'CDC45',
#    'COMT',
#    'ECHDC1',
#    'LRRFIP2',
#    'SEC22C',
#    'AAAS',
#    'CBX5',
#    'PSMD5',
#    'PTGS1',
#    'CRAT',
#    'SH2D3C',
#    'CYP26A1',
#    'SORBS1',
#    'CRTAC1',
#    'SMIM24',
#    'HIVEP1',
#    'FKBP5',
#    'DSP',
#    'IL12RB1',
#    'ABL1',
#    'PCSK5',
#    'ABLIM1',
#    'PRTFDC1',
#    'PALMD',
#    'MZF1',
#    'MYO9B',
#    'MAGEB2',
#    'CBARP',
#    'PRKY',
#    'TIMM13',
#    'POLR2E',
#    'POLRMT',
#    'MKNK2',
#    'ARVCF',
#    'TRMT2A',
#    'KLHL22',
#    'MED15',
#    'SERPIND1',
#    'SNAP29',
#    'CRKL',
#    'LZTR1',
#    'P2RX6',
#    'DERL3',
#    'BCL2L13',
#    'RNF215',
#    'PPIL2',
#    'UPB1',
#    'YPEL1',
#    'PES1',
#    'MAPK1',
#    'PPM1F',
#    'TOP3B',
#    'CYTH4',
#    'ESS2',
#    'SLC25A1',
#    'LGALS2',
#    'HIRA',
#    'LGALS1',
#    'HPS4',
#    'SOX10',
#    'TPTEP1',
#    'DDX17',
#    'DMC1',
#    'RSPH14',
#    'TIMP3',
#    'SBF1',
#    'SUN2',
#    'LMF2',
#    'PACSIN2',
#    'NEFH',
#    'HMOX1',
#    'TTLL12',
#    'RBFOX2',
#    'APOL4',
#    'APOL1',
#    'CACNA1I',
#    'GRAP2',
#    'SLC25A17',
#    'FAM118A',
#    'DESI1',
#    'CERK',
#    'MLC1',
#    'HDAC10',
#    'KCNK10',
#    'POLE2',
#    'CDKL1',
#    'TRIM9',
#    'C14orf105',
#    'ASB2',
#    'CEP128',
#    'SLC10A1',
#    'PAPLN',
#    'RPS6KA5',
#    'DHRS2',
#    'PLTP',
#    'VSX1',
#    'TRPC4AP',
#    'PROCR',
#    'CD40',
#    'UQCC1',
#    'HNF4A',
#    'BMP7',
#    'RAE1',
#    'CTSZ',
#    'TUBB1',
#    'EEF1A2',
#    'C20orf27',
#    'RNF24',
#    'RASSF2',
#    'RSPO4',
#    'SNPH',
#    'MYL9',
#    'MROH8',
#    'IDH3B',
#    'JAG1',
#    'CDK5RAP1',
#    'SNTA1',
#    'PPP1R16B',
#    'FAM83D',
#    'VAPA',
#    'METTL4',
#    'LPIN2',
#    'MYOM1',
#    'CEP76',
#    'LIPG',
#    'ANKRD12',
#    'NOL4',
#    'RIOK3',
#    'VSIG1',
#    'POLA1',
#    'MID1',
#    'RHOXF1',
#    'ATP1B4',
#    'TLR8',
#    'WDR13',
#    'SRPX',
#    'CACNA1F',
#    'SYP',
#    'LUZP4',
#    'PLS3',
#    'RENBP',
#    'SMARCA1',
#    'MTMR8',
#    'ZC3H12B',
#    'KCND1',
#    'PIM2',
#    'SCML2',
#    'SLC35A2',
#    'PGK1',
#    'GATA1',
#    'UBL4A',
#    'CD99L2',
#    'PCYT1B',
#    'TIMP1',
#    'KLHL4',
#    'GABRE',
#    'BEX4',
#    'NALCN',
#    'FGF14',
#    'KLF5',
#    'ACP5',
#    'UGGT2',
#    'SGCG',
#    'PARP4',
#    'FLT1',
#    'VWA8',
#    'KATNAL1',
#    'INTS6',
#    'PHKB',
#    'CENPT',
#    'CYB5B',
#    'SLC38A7',
#    'VAC14',
#    'SMPD3',
#    'FA2H',
#    'NPRL3',
#    'COTL1',
#    'CRISPLD2',
#    'ABCC1',
#    'CLCN7',
#    'SLC7A5',
#    'CRYM',
#    'CPPED1',
#    'CORO7-PAM16',
#    'TOX3',
#    'QPRT',
#    'RPGRIP1L',
#    'TMC5',
#    'AQP9',
#    'RASL12',
#    'ACSBG1',
#    'IGDCC4',
#    'CTSH',
#    'FAH',
#    'CEMIP',
#    'RPAP1',
#    'TMEM87A',
#    'ZNF106',
#    'CEP152',
#    'ATP8B4',
#    'OCA2',
#    'FAM189A1',
#    'SCG3',
#    'DNAJC17',
#    'SPG11',
#    'OIP5',
#    'BRF2',
#    'ZFAND1',
#    'RP1',
#    'INTS9',
#    'TRPA1',
#    'CPQ',
#    'CALB1',
#    'SFRP1',
#    'LAPTM4B',
#    'PLAT',
#    'NDRG1',
#    'IL7',
#    'TRPS1',
#    'NCALD',
#    'GSDMD',
#    'ANXA13',
#    'ERI1',
#    'GSR',
#    'TNFRSF10A',
#    'UBXN8',
#    'PPP2CB',
#    'TUSC3',
#    'KCTD9',
#    'FGL1',
#    'ASAH1',
#    'BNIP3L',
#    'KCNN4',
#    'TULP2',
#    'NUCB1',
#    'DHDH',
#    'GYS1',
#    'HNRNPL',
#    'TUBB4A',
#    'SARS2',
#    'RELB',
#    'PIH1D1',
#    'CKM',
#    'DOT1L',
#    'SLC17A7',
#    'CD37',
#    'LYL1',
#    'TRMT1',
#    'DMPK',
#    'RSPH6A',
#    'TLE6',
#    'AES',
#    'SGTA',
#    'TIMM44',
#    'IL27RA',
#    'TNNT1',
#    'VRK3',
#    'PPP6R1',
#    'AURKC',
#    'ANKRD27',
#    'FBL',
#    'AKT2',
#    'PRX',
#    'NUMBL',
#    'EBI3',
#    'SHD',
#    'ZFR2',
#    'CACTIN',
#    'BBC3',
#    'TGFB1',
#    'PLIN3',
#    'SIGLEC8',
#    'ICAM4',
#    'ICAM5',
#    'ETFB',
#    'CD33',
#    'CEACAM5',
#    'TYK2',
#    'SULT2A1',
#    'CDC37',
#    'RABAC1',
#    'PTPRS',
#    'GRIN2D',
#    'CCDC114',
#    'CARD8',
#    'SIGLEC6',
#    'ZNF175',
#    'CABP5',
#    'HAS1',
#    'RASIP1',
#    'BCAT2',
#    'MIER2',
#    'PLEKHA4',
#    'TNPO2',
#    'KLF1',
#    'JAK3',
#    'KCNN1',
#    'PDE4C',
#    'ISYNA1',
#    'ELL',
#    'COMP',
#    'COPE',
#    'FKBP8',
#    'PBX4',
#    'ERF',
#    'GSK3A',
#    'GRIK5',
#    'ETHE1',
#    'CADM4',
#    'SMG9',
#    'RASA4',
#    'CDK6',
#    'TFPI2',
#    'BET1',
#    'NAMPT',
#    'TWISTNB',
#    'PIK3CG',
#    'PON3',
#    'PON2',
#    'WDR91',
#    'MTPN',
#    'STEAP1B',
#    'DFNA5',
#    'ZC3HAV1',
#    'TFEC',
#    'MET',
#    'HOXA1',
#    'HOXA3',
#    'ANKRD7',
#    'CPED1',
#    'HIBADH',
#    'CPVL',
#    'CHN2',
#    'GRB10',
#    'FKBP14',
#    'NOD1',
#    'GARS',
#    'EPHB6',
#    'GHRHR',
#    'CHCHD2',
#    'CCL24',
#    'CYP3A5',
#    'WASL',
#    'TFR2',
#    'RBM28',
#    'SERPINE1',
#    'MOGAT3',
#    'CLDN15',
#    'NOBOX',
#    'EZH2',
#    'SFRP4',
#    'ANKMY2',
#    'ACTR3C',
#    'POU6F2',
#    'AGR2',
#    'GIMAP2',
#    ...]}]

# %%
with open("./genes_per_pp_condition.pkl", 'wb') as f:
    pkl.dump(feature_agreement, f)

# %% [markdown]
# ## DEGS included in each pp condition

# %%
def inspect_degs_overlap(adata_pp, all_degs):
    results = list()
    
    for feature_select_method in ['cell_ranger', 'seurat_v3', 'seurat']:
        for feature_number in [500, 1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000]:

            adata = adata_pp.copy()
            adata.obs['drug_celltype_dose'] = adata.obs['cell_type'].astype(str) + "_" + adata.obs['product_name'].astype(str) + "_" + adata.obs['dose'].astype(str)

            print("Runnign HVG Selection for:", feature_select_method, feature_number)
            
            if feature_select_method == "random":
                sc.pp.normalize_total(adata, inplace=True)
                sc.pp.log1p(adata)
                genes_random = random.sample(list(adata.var_names), feature_number)
                adata = adata[:, adata.var_names.isin(genes_random)].copy()

            elif feature_select_method == "seurat":
                sc.pp.normalize_total(adata, inplace=True)
                sc.pp.log1p(adata)
                sc.pp.highly_variable_genes(adata, flavor='seurat', n_top_genes=feature_number)
                adata = adata[:, adata.var['highly_variable']].copy()

            elif feature_select_method == "seurat_v3":
                sc.pp.highly_variable_genes(adata, flavor='seurat_v3', n_top_genes=feature_number)
                sc.pp.normalize_total(adata, inplace=True)
                sc.pp.log1p(adata)
                adata = adata[:, adata.var['highly_variable']].copy()

            elif feature_select_method == "cell_ranger":
                sc.pp.normalize_total(adata, inplace=True)
                sc.pp.log1p(adata)
                sc.pp.highly_variable_genes(adata, flavor='cell_ranger', n_top_genes=feature_number)
                adata = adata[:, adata.var['highly_variable']].copy()

            if adata.n_obs == 0:
                continue

            genes_adata = list(adata.var_names)
            
            for cond in tqdm(adata.obs.drug_celltype_dose.unique()):
                if cond not in all_degs:
                    print(cond, "not in DEGs, skipping...")
                    continue

                common_genes = list(set(all_degs[cond]) & set(genes_adata))

                if len(all_degs[cond]) == 0:
                    pct_included = None
                else:
                    pct_included = len(common_genes)/len(all_degs[cond])
                

                results.append({
                    "cell_type": cond.split("_")[0],
                    "drug": cond.split("_")[1],
                    "dosage": cond.split("_")[2],
                    "feature_selection_method": feature_select_method,
                    "n_features": feature_number,
                    "all_degs": all_degs[cond],
                    "all_genes": genes_adata,
                    "common_genes": common_genes,
                    "pct_included": pct_included,
                    "number_of_degs": len(all_degs[cond])
                })

    return results

# %%
degs_overlap = inspect_degs_overlap(adata_pp, all_degs)

# %%
with open("./degs_overlap_stats.pkl", 'wb') as f:
    pkl.dump(degs_overlap, f)

# %% [markdown]
# ## DEGs enrichment

# %%
import gseapy as gp
import pandas as pd

genesets = gp.get_library(name="MSigDB_Hallmark_2020", organism="Human")  # dict

results_summary = dict()

for cond, degs in all_degs.items():
    if not degs:
        continue

    enr = gp.enrich(
        gene_list=list(set(degs)),
        gene_sets=genesets,        # dict here
        outdir=None,
        cutoff=0.05,
    )

    res = enr.results
    
    if res is None or len(res) == 0:
        results_summary[cond] = []
        continue

    df_enr = res.copy() if isinstance(res, pd.DataFrame) else pd.DataFrame(res)
    df_enr = df_enr[df_enr["Adjusted P-value"] <= 0.05]
    
    if df_enr.empty:
        results_summary[cond] = []

    
    results_summary[cond] = list(df_enr['Term'])
# Out:
# 2025-08-21 14:48:52,869 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:52,893 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:52,909 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:52,912 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:52,920 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:52,927 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:52,993 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,003 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,019 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,045 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,048 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,051 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,071 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,074 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,084 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,091 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,098 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,115 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,129 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,136 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,142 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,201 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,204 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,207 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,216 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,223 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,226 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,254 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,266 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,278 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,306 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,336 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,354 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,364 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,370 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,373 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,385 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,418 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,421 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,435 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,445 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,457 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,463 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,466 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,478 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,490 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,493 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,495 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,498 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,501 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,525 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,545 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,548 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,554 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,566 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,577 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,654 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,660 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,674 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,707 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,716 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,751 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,758 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,768 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,788 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,886 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,910 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,918 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,928 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,935 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,938 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,951 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,958 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,961 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,964 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,967 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,974 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,977 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,993 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:53,997 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,021 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,024 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,030 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,045 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,048 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,055 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,057 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,060 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,073 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,086 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,089 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,092 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,099 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,102 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,108 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,121 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,131 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,141 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,149 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,152 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,167 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,182 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,215 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,221 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,234 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,247 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,273 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,275 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,278 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,311 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,315 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,332 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,339 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,343 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,354 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,375 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,398 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,401 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,438 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,440 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,443 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,460 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,463 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,476 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,479 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,503 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,510 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,558 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,565 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,578 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,591 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,594 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,617 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,626 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,633 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,656 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,659 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,696 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,714 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,736 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,740 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,743 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,750 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,771 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,778 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,780 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,783 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,813 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,820 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,827 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,890 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,899 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,917 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,936 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,946 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:54,952 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,025 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,039 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,042 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,052 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,055 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,066 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,069 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,072 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,078 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,090 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,093 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,124 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,127 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,134 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,137 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,144 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,147 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,189 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,203 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,214 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,217 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,229 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,248 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,251 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,266 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,280 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,291 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,302 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,331 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,334 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,353 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,368 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,379 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,406 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,409 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,416 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,424 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,439 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,504 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,515 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,527 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,538 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,552 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,567 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,570 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,573 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,588 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,618 [ERROR] No hits returned for all input gene sets!
# 2025-08-21 14:48:55,621 [ERROR] No hits returned for all input gene sets!

# %%
results_summary
# Out:
# {'A549_Enzastaurin (LY317615)_1000.0': [],
#  'A549_MLN8054_100.0': [],
#  'A549_Thalidomide_1000.0': ['Hypoxia', 'mTORC1 Signaling'],
#  'A549_Linifanib (ABT-869)_10000.0': ['Xenobiotic Metabolism'],
#  'A549_Resminostat_1000.0': ['Androgen Response'],
#  'A549_Quisinostat (JNJ-26481585) 2HCl_10.0': ['Androgen Response',
#   'Complement',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'Xenobiotic Metabolism',
#   'mTORC1 Signaling'],
#  'A549_Temsirolimus (CCI-779, NSC 683864)_100.0': [],
#  'A549_ENMD-2076_1000.0': ['p53 Pathway'],
#  'A549_Crizotinib (PF-02341066)_1000.0': ['p53 Pathway'],
#  'A549_Panobinostat (LBH589)_1000.0': ['Androgen Response',
#   'Cholesterol Homeostasis',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'Fatty Acid Metabolism',
#   'G2-M Checkpoint',
#   'Mitotic Spindle',
#   'UV Response Dn',
#   'Xenobiotic Metabolism',
#   'mTORC1 Signaling'],
#  'A549_Sorafenib Tosylate_1000.0': [],
#  'A549_Mesna _1000.0': [],
#  'A549_Trametinib (GSK1120212)_1000.0': [],
#  'A549_Roscovitine (Seliciclib,CYC202)_1000.0': [],
#  'A549_S-Ruxolitinib (INCB018424)_10000.0': [],
#  'A549_Tofacitinib (CP-690550) Citrate_1000.0': [],
#  'A549_Hesperadin_10000.0': [],
#  'A549_Triamcinolone Acetonide_1000.0': ['Androgen Response',
#   'Estrogen Response Early',
#   'Mitotic Spindle'],
#  'A549_AT9283_10.0': ['p53 Pathway'],
#  'A549_Momelotinib (CYT387)_10000.0': ['p53 Pathway'],
#  'A549_AT9283_10000.0': [],
#  'A549_Glesatinib?(MGCD265)_10000.0': ['Androgen Response',
#   'mTORC1 Signaling'],
#  'A549_Belinostat (PXD101)_1000.0': ['Estrogen Response Late',
#   'G2-M Checkpoint',
#   'Hypoxia'],
#  'A549_Hesperadin_1000.0': [],
#  'A549_Alisertib (MLN8237)_10.0': ['p53 Pathway'],
#  'A549_AR-42_10000.0': ['Androgen Response',
#   'Cholesterol Homeostasis',
#   'Complement',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'Fatty Acid Metabolism',
#   'TGF-beta Signaling',
#   'UV Response Dn',
#   'Xenobiotic Metabolism',
#   'mTORC1 Signaling'],
#  'A549_Dacinostat (LAQ824)_1000.0': ['Androgen Response',
#   'Cholesterol Homeostasis',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint',
#   'UV Response Dn',
#   'Xenobiotic Metabolism',
#   'mTORC1 Signaling'],
#  'A549_Enzastaurin (LY317615)_10000.0': ['Myc Targets V1'],
#  'A549_Patupilone (EPO906, Epothilone B)_10.0': [],
#  'A549_AR-42_100.0': ['Apoptosis'],
#  'A549_UNC0631_1000.0': [],
#  'A549_Obatoclax Mesylate (GX15-070)_1000.0': ['Apical Junction',
#   'Mitotic Spindle'],
#  'A549_MK-5108 (VX-689)_10000.0': [],
#  'A549_Valproic acid sodium salt (Sodium valproate)_10000.0': [],
#  'A549_AC480 (BMS-599626)_10000.0': ['Androgen Response', 'mTORC1 Signaling'],
#  'A549_Sorafenib Tosylate_10000.0': [],
#  'A549_ENMD-2076_10000.0': [],
#  'A549_Navitoclax (ABT-263)_1000.0': [],
#  'A549_Abexinostat (PCI-24781)_1000.0': ['Androgen Response',
#   'Apoptosis',
#   'Estrogen Response Early',
#   'Estrogen Response Late'],
#  'A549_Mocetinostat (MGCD0103)_100.0': ['Apoptosis',
#   'Estrogen Response Early',
#   'Protein Secretion'],
#  'A549_Pracinostat (SB939)_100.0': [],
#  'A549_CYC116_100.0': ['Fatty Acid Metabolism', 'Xenobiotic Metabolism'],
#  'A549_Motesanib Diphosphate (AMG-706)_10000.0': ['Fatty Acid Metabolism',
#   'Xenobiotic Metabolism'],
#  'A549_Alisertib (MLN8237)_100.0': ['p53 Pathway'],
#  'A549_Mercaptopurine (6-MP)_100.0': [],
#  'A549_Quercetin_10.0': [],
#  'A549_M344_100.0': [],
#  'A549_Lapatinib (GW-572016) Ditosylate_10000.0': ['Fatty Acid Metabolism'],
#  'A549_Resminostat_10000.0': ['Androgen Response',
#   'Cholesterol Homeostasis',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'UV Response Dn',
#   'Xenobiotic Metabolism',
#   'mTORC1 Signaling'],
#  'A549_Triamcinolone Acetonide_100.0': ['Androgen Response',
#   'Estrogen Response Early',
#   'Mitotic Spindle'],
#  'A549_PD173074_10000.0': ['mTORC1 Signaling'],
#  'A549_SL-327_1000.0': [],
#  'A549_Rucaparib (AG-014699,PF-01367338) phosphate_1000.0': [],
#  'A549_Entinostat (MS-275)_1000.0': ['Estrogen Response Early'],
#  'A549_Regorafenib (BAY 73-4506)_10000.0': ['Complement',
#   'TNF-alpha Signaling via NF-kB',
#   'Xenobiotic Metabolism'],
#  'A549_BMS-536924_1000.0': [],
#  'A549_JNJ-26854165 (Serdemetan)_10000.0': ['mTORC1 Signaling'],
#  'A549_A-366_10000.0': [],
#  'A549_(+)-JQ1_1000.0': ['Reactive Oxygen Species Pathway',
#   'mTORC1 Signaling'],
#  'A549_PD98059_1000.0': [],
#  'A549_AMG-900_10000.0': [],
#  'A549_M344_1000.0': [],
#  'A549_Cyclocytidine HCl_10000.0': ['p53 Pathway'],
#  'A549_BMS-265246_100.0': [],
#  'A549_Momelotinib (CYT387)_1000.0': ['Fatty Acid Metabolism',
#   'Xenobiotic Metabolism'],
#  'A549_Alvespimycin (17-DMAG) HCl_1000.0': [],
#  'A549_Nintedanib (BIBF 1120)_10000.0': ['Androgen Response',
#   'mTORC1 Signaling'],
#  'A549_BRD4770_10000.0': [],
#  'A549_Pirarubicin_1000.0': [],
#  'A549_AC480 (BMS-599626)_1000.0': [],
#  'A549_ZM 447439_1000.0': ['p53 Pathway'],
#  'A549_CUDC-101_10.0': [],
#  'A549_Barasertib (AZD1152-HQPA)_100.0': ['p53 Pathway'],
#  'A549_CUDC-907_100.0': ['Apoptosis'],
#  'A549_Tacedinaline (CI994)_10000.0': [],
#  'A549_Barasertib (AZD1152-HQPA)_1000.0': [],
#  'A549_Dasatinib_100.0': [],
#  'A549_AG-14361_10000.0': [],
#  'A549_TAK-901_1000.0': [],
#  'A549_(+)-JQ1_10000.0': ['Androgen Response',
#   'Glycolysis',
#   'Reactive Oxygen Species Pathway',
#   'mTORC1 Signaling'],
#  'A549_CEP-33779_10000.0': ['Fatty Acid Metabolism', 'Xenobiotic Metabolism'],
#  'A549_SL-327_10000.0': ['Estrogen Response Late'],
#  'A549_Navitoclax (ABT-263)_10000.0': ['Apical Junction',
#   'Glycolysis',
#   'Hypoxia'],
#  'A549_GSK1070916_10000.0': ['Cholesterol Homeostasis', 'mTORC1 Signaling'],
#  'A549_Pelitinib (EKB-569)_10000.0': [],
#  'A549_Triamcinolone Acetonide_10.0': ['Androgen Response', 'Mitotic Spindle'],
#  'A549_Tranylcypromine (2-PCPA) HCl_10000.0': [],
#  'A549_Tubastatin A HCl_10000.0': [],
#  'A549_Meprednisone_1000.0': [],
#  'A549_Azacitidine _10000.0': ['Myc Targets V1', 'Myc Targets V2'],
#  'A549_Tacedinaline (CI994)_100.0': [],
#  'A549_SGI-1776 free base_10000.0': ['Androgen Response',
#   'Bile Acid Metabolism',
#   'Cholesterol Homeostasis',
#   'mTORC1 Signaling'],
#  'A549_Droxinostat_10000.0': [],
#  'A549_Mercaptopurine (6-MP)_10000.0': [],
#  'A549_Cyclocytidine HCl_1000.0': [],
#  'A549_SNS-314_1000.0': ['p53 Pathway'],
#  'A549_Flavopiridol HCl_10.0': ['Apoptosis',
#   'Estrogen Response Early',
#   'Protein Secretion'],
#  'A549_Raltitrexed_100.0': ['p53 Pathway'],
#  'A549_BMS-265246_1000.0': ['Fatty Acid Metabolism', 'Xenobiotic Metabolism'],
#  'A549_SNS-314_100.0': ['p53 Pathway'],
#  'A549_Triamcinolone Acetonide_10000.0': ['Androgen Response',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'Mitotic Spindle'],
#  'A549_Tofacitinib (CP-690550) Citrate_10000.0': [],
#  'A549_Obatoclax Mesylate (GX15-070)_10000.0': ['Apoptosis',
#   'PI3K/AKT/mTOR  Signaling',
#   'TNF-alpha Signaling via NF-kB',
#   'UV Response Up',
#   'mTORC1 Signaling'],
#  'A549_Raltitrexed_10000.0': ['Apoptosis',
#   'Epithelial Mesenchymal Transition',
#   'TNF-alpha Signaling via NF-kB',
#   'p53 Pathway'],
#  'A549_Andarine_100.0': [],
#  'A549_Belinostat (PXD101)_10000.0': ['Androgen Response',
#   'Cholesterol Homeostasis',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'Fatty Acid Metabolism',
#   'TNF-alpha Signaling via NF-kB',
#   'UV Response Dn',
#   'Xenobiotic Metabolism',
#   'mTORC1 Signaling'],
#  'A549_Hesperadin_100.0': [],
#  'A549_Valproic acid sodium salt (Sodium valproate)_1000.0': [],
#  'A549_Barasertib (AZD1152-HQPA)_10.0': ['p53 Pathway'],
#  'A549_Dacinostat (LAQ824)_10.0': [],
#  'A549_TAK-901_10000.0': [],
#  'A549_TAK-901_100.0': ['Fatty Acid Metabolism',
#   'Xenobiotic Metabolism',
#   'p53 Pathway'],
#  'A549_Quisinostat (JNJ-26481585) 2HCl_10000.0': ['Androgen Response',
#   'Cholesterol Homeostasis',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'UV Response Dn',
#   'Xenobiotic Metabolism',
#   'mTORC1 Signaling'],
#  'A549_Tanespimycin (17-AAG)_100.0': ['KRAS Signaling Dn'],
#  'A549_Azacitidine _100.0': [],
#  'A549_KW-2449_1000.0': [],
#  'A549_Panobinostat (LBH589)_10000.0': ['Androgen Response',
#   'Cholesterol Homeostasis',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'Fatty Acid Metabolism',
#   'TGF-beta Signaling',
#   'UV Response Dn',
#   'Xenobiotic Metabolism',
#   'mTORC1 Signaling'],
#  'A549_Rigosertib (ON-01910)_1000.0': [],
#  'A549_Flavopiridol HCl_100.0': ['UV Response Dn'],
#  'A549_Carmofur_10000.0': ['Apoptosis', 'p53 Pathway'],
#  'A549_Temsirolimus (CCI-779, NSC 683864)_1000.0': [],
#  'A549_CUDC-101_100.0': [],
#  'A549_MLN8054_10.0': ['p53 Pathway'],
#  'A549_Alendronate sodium trihydrate_1000.0': ['Estrogen Response Early',
#   'Estrogen Response Late',
#   'Hypoxia'],
#  'A549_AZD1480_10000.0': ['Apoptosis'],
#  'A549_KW-2449_10000.0': ['p53 Pathway'],
#  'A549_Ofloxacin_100.0': [],
#  'A549_SNS-314_10.0': [],
#  'A549_UNC0631_10000.0': ['Apoptosis',
#   'PI3K/AKT/mTOR  Signaling',
#   'TNF-alpha Signaling via NF-kB',
#   'UV Response Up',
#   'mTORC1 Signaling'],
#  'A549_SB431542_1000.0': [],
#  'A549_Abexinostat (PCI-24781)_10.0': [],
#  'A549_S3I-201_1000.0': [],
#  'A549_Dasatinib_10000.0': [],
#  'A549_Thalidomide_10000.0': ['Hypoxia', 'mTORC1 Signaling'],
#  'A549_CUDC-101_10000.0': ['Androgen Response',
#   'Cholesterol Homeostasis',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'Reactive Oxygen Species Pathway',
#   'UV Response Dn',
#   'mTORC1 Signaling'],
#  'A549_Trichostatin A (TSA)_1000.0': [],
#  'A549_MLN8054_10000.0': [],
#  'A549_Danusertib (PHA-739358)_1000.0': ['TNF-alpha Signaling via NF-kB'],
#  'A549_CUDC-907_10.0': ['Apoptosis', 'G2-M Checkpoint'],
#  'A549_Entinostat (MS-275)_10000.0': ['Androgen Response',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'mTORC1 Signaling'],
#  'A549_MLN8054_1000.0': [],
#  'A549_GSK1070916_10.0': ['p53 Pathway'],
#  'A549_CUDC-907_10000.0': ['Androgen Response',
#   'Cholesterol Homeostasis',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'Fatty Acid Metabolism',
#   'TNF-alpha Signaling via NF-kB',
#   'UV Response Dn',
#   'Xenobiotic Metabolism',
#   'mTORC1 Signaling'],
#  'A549_Decitabine_1000.0': [],
#  'A549_Tacedinaline (CI994)_1000.0': [],
#  'A549_JNJ-7706621_1000.0': ['Fatty Acid Metabolism', 'Xenobiotic Metabolism'],
#  'A549_ZM 447439_10000.0': [],
#  'A549_Rigosertib (ON-01910)_100.0': ['p53 Pathway'],
#  'A549_Fulvestrant_1000.0': [],
#  'A549_2-Methoxyestradiol (2-MeOE2)_10000.0': [],
#  'A549_BMS-536924_10000.0': [],
#  'A549_SGI-1776 free base_1000.0': [],
#  'A549_Alvespimycin (17-DMAG) HCl_10000.0': ['mTORC1 Signaling'],
#  'A549_Dasatinib_1000.0': [],
#  'A549_Vandetanib (ZD6474)_10000.0': [],
#  'A549_Tubastatin A HCl_1000.0': ['Apical Junction', 'Mitotic Spindle'],
#  'A549_PF-3845_1000.0': [],
#  'A549_Lapatinib (GW-572016) Ditosylate_1000.0': [],
#  'A549_BMS-265246_10000.0': ['Estrogen Response Early'],
#  'A549_CUDC-907_1000.0': ['Apoptosis',
#   'Estrogen Response Early',
#   'mTORC1 Signaling'],
#  'A549_PCI-34051_10000.0': [],
#  'A549_Belinostat (PXD101)_100.0': [],
#  'A549_Trametinib (GSK1120212)_10000.0': ['Estrogen Response Late',
#   'TNF-alpha Signaling via NF-kB',
#   'Xenobiotic Metabolism'],
#  'A549_Disulfiram _1000.0': [],
#  'A549_ABT-737_1000.0': [],
#  'A549_Aminoglutethimide _1000.0': [],
#  'A549_Baricitinib (LY3009104, INCB028050)_10000.0': [],
#  'A549_NVP-BSK805 2HCl_1000.0': [],
#  'A549_Givinostat (ITF2357)_1000.0': [],
#  'A549_M344_10000.0': ['Androgen Response',
#   'Cholesterol Homeostasis',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'UV Response Dn',
#   'mTORC1 Signaling'],
#  'A549_Mocetinostat (MGCD0103)_10000.0': [],
#  'A549_Tucidinostat (Chidamide)_10000.0': [],
#  'A549_PJ34_100.0': [],
#  'A549_Crizotinib (PF-02341066)_10000.0': ['mTORC1 Signaling'],
#  'A549_PFI-1 (PF-6405761)_10000.0': ['Reactive Oxygen Species Pathway'],
#  'A549_Alvespimycin (17-DMAG) HCl_100.0': [],
#  'A549_Raltitrexed_1000.0': ['p53 Pathway'],
#  'A549_Givinostat (ITF2357)_10.0': [],
#  'A549_ENMD-2076 L-(+)-Tartaric acid _10.0': [],
#  'A549_MK-5108 (VX-689)_1000.0': ['p53 Pathway'],
#  'A549_Pelitinib (EKB-569)_1000.0': [],
#  'A549_Tie2 kinase inhibitor_10000.0': ['mTORC1 Signaling'],
#  'A549_Trametinib (GSK1120212)_100.0': [],
#  'A549_GSK-LSD1 2HCl_10000.0': [],
#  'A549_JNJ-7706621_10000.0': [],
#  'A549_GSK1070916_1000.0': [],
#  'A549_CUDC-101_1000.0': [],
#  'A549_FLLL32_10000.0': ['Apoptosis',
#   'PI3K/AKT/mTOR  Signaling',
#   'TNF-alpha Signaling via NF-kB',
#   'UV Response Up',
#   'mTORC1 Signaling'],
#  'A549_Dacinostat (LAQ824)_100.0': ['Androgen Response',
#   'Estrogen Response Early',
#   'Estrogen Response Late'],
#  'A549_TG101209_10000.0': [],
#  'A549_Roscovitine (Seliciclib,CYC202)_10000.0': ['Fatty Acid Metabolism',
#   'Xenobiotic Metabolism'],
#  'A549_BMS-754807_10000.0': [],
#  'A549_AZ 960_1000.0': ['Fatty Acid Metabolism', 'Xenobiotic Metabolism'],
#  'A549_Mocetinostat (MGCD0103)_1000.0': ['mTORC1 Signaling'],
#  'A549_ENMD-2076 L-(+)-Tartaric acid _10000.0': ['mTORC1 Signaling'],
#  'A549_Pracinostat (SB939)_10000.0': ['Androgen Response',
#   'Cholesterol Homeostasis',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'Fatty Acid Metabolism',
#   'UV Response Dn',
#   'Xenobiotic Metabolism',
#   'mTORC1 Signaling'],
#  'A549_NVP-BSK805 2HCl_10000.0': ['Cholesterol Homeostasis',
#   'Estrogen Response Early',
#   'mTORC1 Signaling'],
#  'A549_Fluorouracil (5-Fluoracil, 5-FU)_10000.0': ['Apoptosis', 'p53 Pathway'],
#  'A549_Cerdulatinib (PRT062070, PRT2070)_10000.0': ['mTORC1 Signaling',
#   'p53 Pathway'],
#  'A549_Gandotinib (LY2784544)_10000.0': ['Myc Targets V1'],
#  'A549_ABT-737_10000.0': [],
#  'A549_Abexinostat (PCI-24781)_100.0': [],
#  'A549_Givinostat (ITF2357)_100.0': ['heme Metabolism'],
#  'A549_Panobinostat (LBH589)_100.0': ['Androgen Response',
#   'Cholesterol Homeostasis',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'UV Response Dn',
#   'Xenobiotic Metabolism',
#   'mTORC1 Signaling'],
#  'A549_Prednisone _1000.0': [],
#  'A549_GSK1070916_100.0': [],
#  'A549_Alendronate sodium trihydrate_100.0': [],
#  'A549_Danusertib (PHA-739358)_100.0': ['p53 Pathway'],
#  'A549_Bosutinib (SKI-606)_10000.0': ['Cholesterol Homeostasis',
#   'mTORC1 Signaling'],
#  'A549_PHA-680632_10000.0': [],
#  'A549_Quercetin_1000.0': [],
#  'A549_Pracinostat (SB939)_1000.0': ['mTORC1 Signaling'],
#  'A549_UNC1999_10000.0': ['Androgen Response', 'mTORC1 Signaling'],
#  'A549_Abexinostat (PCI-24781)_10000.0': ['Androgen Response',
#   'Apoptosis',
#   'Cholesterol Homeostasis',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'Xenobiotic Metabolism',
#   'mTORC1 Signaling'],
#  'A549_Trichostatin A (TSA)_10000.0': ['Androgen Response',
#   'Cholesterol Homeostasis',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'Mitotic Spindle',
#   'PI3K/AKT/mTOR  Signaling',
#   'TGF-beta Signaling',
#   'UV Response Dn',
#   'Xenobiotic Metabolism',
#   'mTORC1 Signaling'],
#  'A549_Pirarubicin_10000.0': ['Apoptosis', 'p53 Pathway'],
#  'A549_AMG-900_10.0': [],
#  'A549_Droxinostat_1000.0': [],
#  'A549_AR-42_1000.0': ['Androgen Response',
#   'Epithelial Mesenchymal Transition',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'TNF-alpha Signaling via NF-kB',
#   'mTORC1 Signaling'],
#  'A549_Celecoxib_1000.0': [],
#  'A549_Dacinostat (LAQ824)_10000.0': ['Androgen Response',
#   'Cholesterol Homeostasis',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'Fatty Acid Metabolism',
#   'Mitotic Spindle',
#   'UV Response Dn',
#   'Xenobiotic Metabolism',
#   'mTORC1 Signaling'],
#  'A549_Panobinostat (LBH589)_10.0': [],
#  'A549_Cediranib (AZD2171)_10000.0': ['Androgen Response', 'mTORC1 Signaling'],
#  'A549_Quisinostat (JNJ-26481585) 2HCl_1000.0': ['Androgen Response',
#   'Cholesterol Homeostasis',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'Mitotic Spindle',
#   'UV Response Dn',
#   'Xenobiotic Metabolism',
#   'mTORC1 Signaling'],
#  'A549_Tanespimycin (17-AAG)_1000.0': [],
#  'A549_Veliparib (ABT-888)_100.0': [],
#  'A549_Alisertib (MLN8237)_1000.0': [],
#  'A549_BMS-754807_1000.0': [],
#  'A549_Danusertib (PHA-739358)_10000.0': [],
#  'A549_Thiotepa_10000.0': [],
#  'A549_Pirarubicin_100.0': [],
#  'A549_Luminespib (AUY-922, NVP-AUY922)_100.0': [],
#  'A549_SNS-314_10000.0': [],
#  'A549_Quisinostat (JNJ-26481585) 2HCl_100.0': ['Androgen Response',
#   'Estrogen Response Early',
#   'TNF-alpha Signaling via NF-kB',
#   'UV Response Dn',
#   'Xenobiotic Metabolism',
#   'mTORC1 Signaling'],
#  'A549_AT9283_1000.0': [],
#  'A549_ABT-737_100.0': [],
#  'A549_AZ 960_10000.0': [],
#  'A549_PHA-680632_1000.0': [],
#  'A549_Aurora A Inhibitor I_10000.0': [],
#  'A549_CYC116_10.0': ['Fatty Acid Metabolism', 'Xenobiotic Metabolism'],
#  'A549_Carmofur_1000.0': ['Fatty Acid Metabolism', 'Xenobiotic Metabolism'],
#  'A549_Tozasertib (VX-680, MK-0457)_1000.0': ['p53 Pathway'],
#  'A549_Givinostat (ITF2357)_10000.0': ['Androgen Response',
#   'Cholesterol Homeostasis',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'Fatty Acid Metabolism',
#   'PI3K/AKT/mTOR  Signaling',
#   'TNF-alpha Signaling via NF-kB',
#   'UV Response Dn',
#   'Xenobiotic Metabolism',
#   'mTORC1 Signaling'],
#  'A549_AMG-900_1000.0': [],
#  'A549_Alendronate sodium trihydrate_10000.0': [],
#  'A549_Tanespimycin (17-AAG)_10000.0': [],
#  'A549_Epothilone A_10000.0': [],
#  'A549_CYC116_10000.0': [],
#  'A549_Barasertib (AZD1152-HQPA)_10000.0': [],
#  'A549_AMG-900_100.0': [],
#  'A549_Hesperadin_10.0': [],
#  'A549_ENMD-2076 L-(+)-Tartaric acid _1000.0': [],
#  'A549_Epothilone A_10.0': ['Xenobiotic Metabolism'],
#  'A549_Trametinib (GSK1120212)_10.0': ['Estrogen Response Late'],
#  'A549_Fedratinib (SAR302503, TG101348)_10000.0': ['Androgen Response',
#   'Apoptosis',
#   'Cholesterol Homeostasis',
#   'Estrogen Response Early',
#   'mTORC1 Signaling'],
#  'A549_UNC0379_10000.0': ['Cholesterol Homeostasis',
#   'Hypoxia',
#   'mTORC1 Signaling'],
#  'A549_Toremifene Citrate_10000.0': [],
#  'MCF7_TAK-901_10000.0': ['Androgen Response',
#   'Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_Abexinostat (PCI-24781)_1000.0': ['Androgen Response',
#   'E2F Targets',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint',
#   'Myc Targets V1',
#   'UV Response Dn'],
#  'MCF7_BMS-265246_100.0': [],
#  'MCF7_BMS-536924_10000.0': ['E2F Targets',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint'],
#  'MCF7_Carmofur_10000.0': ['p53 Pathway'],
#  'MCF7_Tanespimycin (17-AAG)_100.0': ['Apoptosis',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint',
#   'Notch Signaling',
#   'TGF-beta Signaling',
#   'UV Response Dn'],
#  'MCF7_MK-5108 (VX-689)_1000.0': ['p53 Pathway'],
#  'MCF7_Trametinib (GSK1120212)_10000.0': ['Androgen Response',
#   'Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_ENMD-2076 L-(+)-Tartaric acid _1000.0': [],
#  'MCF7_Crizotinib (PF-02341066)_10000.0': ['Apical Surface',
#   'Cholesterol Homeostasis',
#   'Estrogen Response Early',
#   'mTORC1 Signaling'],
#  'MCF7_PHA-680632_1000.0': [],
#  'MCF7_Dasatinib_1000.0': ['Estrogen Response Early'],
#  'MCF7_Toremifene Citrate_1000.0': ['Estrogen Response Early'],
#  'MCF7_A-366_10000.0': [],
#  'MCF7_Alisertib (MLN8237)_10.0': ['p53 Pathway'],
#  'MCF7_PD173074_100.0': [],
#  'MCF7_BMS-754807_1000.0': [],
#  'MCF7_Quercetin_10000.0': ['Apical Junction'],
#  'MCF7_KW-2449_10000.0': ['Estrogen Response Early'],
#  'MCF7_Motesanib Diphosphate (AMG-706)_10000.0': ['p53 Pathway'],
#  'MCF7_WHI-P154_1000.0': [],
#  'MCF7_PF-573228_10000.0': ['Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_Ki8751_1000.0': [],
#  'MCF7_Daphnetin_100.0': [],
#  'MCF7_BMS-265246_10.0': [],
#  'MCF7_NVP-BSK805 2HCl_100.0': [],
#  'MCF7_2-Methoxyestradiol (2-MeOE2)_10000.0': [],
#  'MCF7_SRT3025 HCl_10000.0': [],
#  'MCF7_Daphnetin_1000.0': [],
#  'MCF7_TAK-901_10.0': ['p53 Pathway'],
#  'MCF7_BMS-265246_10000.0': [],
#  'MCF7_Tucidinostat (Chidamide)_100.0': ['Androgen Response',
#   'Apoptosis',
#   'Estrogen Response Early'],
#  'MCF7_Tranylcypromine (2-PCPA) HCl_10000.0': ['Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_Belinostat (PXD101)_10.0': [],
#  'MCF7_MK-5108 (VX-689)_100.0': [],
#  'MCF7_GSK-LSD1 2HCl_100.0': ['Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_Alvespimycin (17-DMAG) HCl_1000.0': ['Apical Surface',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'TGF-beta Signaling'],
#  'MCF7_ZM 447439_10000.0': ['Apical Surface', 'Apoptosis'],
#  'MCF7_(+)-JQ1_1000.0': ['Androgen Response',
#   'E2F Targets',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint',
#   'UV Response Dn'],
#  'MCF7_SRT2104 (GSK2245840)_1000.0': ['Pperoxisome'],
#  'MCF7_Tanespimycin (17-AAG)_10.0': [],
#  'MCF7_Veliparib (ABT-888)_10000.0': [],
#  'MCF7_Tie2 kinase inhibitor_10000.0': [],
#  'MCF7_ITSA-1 (ITSA1)_10000.0': [],
#  'MCF7_Triamcinolone Acetonide_10000.0': ['Androgen Response',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'Notch Signaling'],
#  'MCF7_Dacinostat (LAQ824)_10.0': ['E2F Targets',
#   'Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_SNS-314_1000.0': ['p53 Pathway'],
#  'MCF7_GSK J1_1000.0': [],
#  'MCF7_CUDC-101_1000.0': [],
#  'MCF7_Givinostat (ITF2357)_10.0': ['Complement', 'p53 Pathway'],
#  'MCF7_Mercaptopurine (6-MP)_100.0': [],
#  'MCF7_MC1568_1000.0': [],
#  'MCF7_Pelitinib (EKB-569)_1000.0': [],
#  'MCF7_Quisinostat (JNJ-26481585) 2HCl_1000.0': ['Androgen Response',
#   'Cholesterol Homeostasis',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint',
#   'Mitotic Spindle',
#   'UV Response Dn'],
#  'MCF7_GSK1070916_100.0': ['p53 Pathway'],
#  'MCF7_Tubastatin A HCl_1000.0': [],
#  'MCF7_Hesperadin_10000.0': ['Apical Surface',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint',
#   'UV Response Dn'],
#  'MCF7_Enzastaurin (LY317615)_10000.0': ['Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_Temsirolimus (CCI-779, NSC 683864)_10.0': [],
#  'MCF7_ITSA-1 (ITSA1)_1000.0': [],
#  'MCF7_SL-327_100.0': [],
#  'MCF7_Epothilone A_10.0': [],
#  'MCF7_TGX-221_10000.0': [],
#  'MCF7_Trichostatin A (TSA)_100.0': [],
#  'MCF7_GSK-LSD1 2HCl_1000.0': ['Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_PD173074_10.0': [],
#  'MCF7_GSK1070916_10.0': ['p53 Pathway'],
#  'MCF7_Panobinostat (LBH589)_1000.0': ['Androgen Response',
#   'Cholesterol Homeostasis',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint',
#   'Mitotic Spindle',
#   'TGF-beta Signaling',
#   'UV Response Dn'],
#  'MCF7_Avagacestat (BMS-708163)_10000.0': [],
#  'MCF7_Dacinostat (LAQ824)_10000.0': ['Androgen Response',
#   'Cholesterol Homeostasis',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint',
#   'TGF-beta Signaling',
#   'UV Response Dn'],
#  'MCF7_Resminostat_100.0': [],
#  'MCF7_BMS-265246_1000.0': ['Estrogen Response Early',
#   'IL-2/STAT5 Signaling',
#   'UV Response Dn'],
#  'MCF7_Triamcinolone Acetonide_10.0': ['Estrogen Response Late'],
#  'MCF7_CYC116_10.0': [],
#  'MCF7_CUDC-907_10.0': ['Androgen Response', 'Estrogen Response Early'],
#  'MCF7_Nilotinib (AMN-107)_100.0': [],
#  'MCF7_PCI-34051_10000.0': [],
#  'MCF7_(+)-JQ1_100.0': ['Estrogen Response Early'],
#  'MCF7_AZ 960_10000.0': ['Estrogen Response Early'],
#  'MCF7_Resminostat_1000.0': ['Androgen Response', 'Estrogen Response Early'],
#  'MCF7_S3I-201_100.0': [],
#  'MCF7_Pracinostat (SB939)_100.0': ['E2F Targets'],
#  'MCF7_Temsirolimus (CCI-779, NSC 683864)_1000.0': ['mTORC1 Signaling'],
#  'MCF7_Patupilone (EPO906, Epothilone B)_10000.0': [],
#  'MCF7_Alendronate sodium trihydrate_100.0': [],
#  'MCF7_GSK-LSD1 2HCl_10.0': ['Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_Regorafenib (BAY 73-4506)_10000.0': ['Estrogen Response Early'],
#  'MCF7_M344_1000.0': [],
#  'MCF7_Trametinib (GSK1120212)_10.0': ['Androgen Response',
#   'Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_PHA-680632_10000.0': ['Androgen Response',
#   'Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_Givinostat (ITF2357)_10000.0': ['Androgen Response',
#   'Apical Surface',
#   'Cholesterol Homeostasis',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint',
#   'UV Response Dn',
#   'mTORC1 Signaling'],
#  'MCF7_Tubastatin A HCl_10000.0': ['p53 Pathway'],
#  'MCF7_RG108_100.0': [],
#  'MCF7_FLLL32_1000.0': ['Hypoxia', 'mTORC1 Signaling'],
#  'MCF7_Amisulpride_100.0': [],
#  'MCF7_SB431542_1000.0': ['p53 Pathway'],
#  'MCF7_Quisinostat (JNJ-26481585) 2HCl_10000.0': ['Androgen Response',
#   'Cholesterol Homeostasis',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint',
#   'Mitotic Spindle',
#   'TGF-beta Signaling',
#   'UV Response Dn'],
#  'MCF7_Baricitinib (LY3009104, INCB028050)_1000.0': [],
#  'MCF7_Panobinostat (LBH589)_10000.0': ['Androgen Response',
#   'Cholesterol Homeostasis',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint',
#   'Mitotic Spindle',
#   'Myc Targets V1',
#   'TGF-beta Signaling',
#   'UV Response Dn'],
#  'MCF7_MLN8054_1000.0': ['p53 Pathway'],
#  'MCF7_Sodium Phenylbutyrate_1000.0': [],
#  'MCF7_Hesperadin_1000.0': ['E2F Targets'],
#  'MCF7_Momelotinib (CYT387)_10000.0': ['Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_Abexinostat (PCI-24781)_100.0': ['E2F Targets', 'G2-M Checkpoint'],
#  'MCF7_Obatoclax Mesylate (GX15-070)_10000.0': ['Cholesterol Homeostasis',
#   'mTORC1 Signaling'],
#  'MCF7_MLN8054_10000.0': ['Androgen Response',
#   'Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_Cediranib (AZD2171)_100.0': [],
#  'MCF7_Tozasertib (VX-680, MK-0457)_100.0': [],
#  'MCF7_Alisertib (MLN8237)_10000.0': [],
#  'MCF7_Panobinostat (LBH589)_100.0': ['Androgen Response',
#   'Apical Surface',
#   'E2F Targets',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint',
#   'TGF-beta Signaling',
#   'UV Response Dn'],
#  'MCF7_Pirarubicin_1000.0': ['p53 Pathway'],
#  'MCF7_Raltitrexed_10000.0': ['p53 Pathway'],
#  'MCF7_Entinostat (MS-275)_10000.0': ['Androgen Response',
#   'E2F Targets',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint',
#   'Mitotic Spindle',
#   'UV Response Dn'],
#  'MCF7_Tucidinostat (Chidamide)_10000.0': ['Apical Surface',
#   'E2F Targets',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint'],
#  'MCF7_WHI-P154_10000.0': ['Estrogen Response Early',
#   'Estrogen Response Late',
#   'IL-2/STAT5 Signaling',
#   'Mitotic Spindle',
#   'PI3K/AKT/mTOR  Signaling'],
#  'MCF7_Cerdulatinib (PRT062070, PRT2070)_100.0': [],
#  'MCF7_Zileuton_1000.0': [],
#  'MCF7_Costunolide_10000.0': [],
#  'MCF7_Raltitrexed_1000.0': [],
#  'MCF7_UNC0379_10000.0': ['Androgen Response',
#   'Cholesterol Homeostasis',
#   'E2F Targets',
#   'Estrogen Response Early',
#   'G2-M Checkpoint',
#   'mTORC1 Signaling'],
#  'MCF7_Cediranib (AZD2171)_1000.0': [],
#  'MCF7_Entinostat (MS-275)_1000.0': ['Androgen Response'],
#  'MCF7_S3I-201_10.0': [],
#  'MCF7_Hesperadin_10.0': [],
#  'MCF7_Abexinostat (PCI-24781)_10.0': ['E2F Targets'],
#  'MCF7_Cerdulatinib (PRT062070, PRT2070)_1000.0': [],
#  'MCF7_Bisindolylmaleimide IX (Ro 31-8220 Mesylate)_1000.0': ['Androgen Response',
#   'Estrogen Response Early'],
#  'MCF7_Raltitrexed_100.0': [],
#  'MCF7_Tacedinaline (CI994)_1000.0': ['Androgen Response',
#   'Apical Surface',
#   'Estrogen Response Early'],
#  'MCF7_Dacinostat (LAQ824)_100.0': ['E2F Targets',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint'],
#  'MCF7_Ruxolitinib (INCB018424)_10000.0': [],
#  'MCF7_Toremifene Citrate_10000.0': ['Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_Mocetinostat (MGCD0103)_100.0': ['Androgen Response',
#   'Estrogen Response Early'],
#  'MCF7_Trametinib (GSK1120212)_1000.0': ['Androgen Response',
#   'Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_FLLL32_10000.0': ['Estrogen Response Early',
#   'Estrogen Response Late',
#   'Reactive Oxygen Species Pathway',
#   'mTORC1 Signaling'],
#  'MCF7_Tacedinaline (CI994)_100.0': [],
#  'MCF7_Disulfiram _10.0': [],
#  'MCF7_Tacedinaline (CI994)_10000.0': ['Androgen Response',
#   'Apical Surface',
#   'E2F Targets',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint'],
#  'MCF7_Sorafenib Tosylate_10000.0': ['Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_BMS-754807_10000.0': ['mTORC1 Signaling'],
#  'MCF7_Belinostat (PXD101)_100.0': [],
#  'MCF7_Givinostat (ITF2357)_1000.0': ['Androgen Response',
#   'Apoptosis',
#   'E2F Targets',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint'],
#  'MCF7_Dacinostat (LAQ824)_1000.0': ['Androgen Response',
#   'E2F Targets',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint',
#   'Mitotic Spindle',
#   'Myc Targets V1',
#   'UV Response Dn'],
#  'MCF7_AT9283_10000.0': ['Androgen Response',
#   'Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_SGI-1776 free base_1000.0': [],
#  'MCF7_Decitabine_100.0': [],
#  'MCF7_PD173074_10000.0': [],
#  'MCF7_Givinostat (ITF2357)_100.0': [],
#  'MCF7_M344_10000.0': ['E2F Targets',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint',
#   'UV Response Dn'],
#  'MCF7_Fedratinib (SAR302503, TG101348)_1000.0': ['Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_Aminoglutethimide _100.0': [],
#  'MCF7_Cimetidine _10.0': [],
#  'MCF7_Trichostatin A (TSA)_1000.0': ['E2F Targets',
#   'Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_Nintedanib (BIBF 1120)_10000.0': ['E2F Targets',
#   'Estrogen Response Early',
#   'mTORC1 Signaling'],
#  'MCF7_Meprednisone_10000.0': [],
#  'MCF7_Epothilone A_10000.0': [],
#  'MCF7_UNC0631_10000.0': ['Androgen Response',
#   'Cholesterol Homeostasis',
#   'Myogenesis',
#   'mTORC1 Signaling'],
#  'MCF7_Gandotinib (LY2784544)_10000.0': ['Pperoxisome'],
#  'MCF7_Pracinostat (SB939)_1000.0': ['Androgen Response',
#   'E2F Targets',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint',
#   'TGF-beta Signaling'],
#  'MCF7_SL-327_10000.0': ['Estrogen Response Early',
#   'Estrogen Response Late',
#   'Mitotic Spindle'],
#  'MCF7_CUDC-907_100.0': ['Androgen Response',
#   'E2F Targets',
#   'Estrogen Response Early',
#   'G2-M Checkpoint'],
#  'MCF7_Prednisone _100.0': [],
#  'MCF7_Triamcinolone Acetonide_1000.0': ['Androgen Response',
#   'Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_CYC116_100.0': [],
#  'MCF7_AR-42_10.0': ['Androgen Response',
#   'Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_MK-5108 (VX-689)_10000.0': ['p53 Pathway'],
#  'MCF7_SGI-1776 free base_10000.0': ['mTORC1 Signaling'],
#  'MCF7_(+)-JQ1_10000.0': ['E2F Targets',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint',
#   'UV Response Dn'],
#  'MCF7_Pracinostat (SB939)_10000.0': ['Androgen Response',
#   'Apical Surface',
#   'Cholesterol Homeostasis',
#   'E2F Targets',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint',
#   'Mitotic Spindle',
#   'TGF-beta Signaling',
#   'UV Response Dn'],
#  'MCF7_Cerdulatinib (PRT062070, PRT2070)_10000.0': [],
#  'MCF7_Alvespimycin (17-DMAG) HCl_10.0': ['Fatty Acid Metabolism'],
#  'MCF7_Alendronate sodium trihydrate_10000.0': ['Cholesterol Homeostasis',
#   'Myogenesis'],
#  'MCF7_Resminostat_10000.0': ['Androgen Response',
#   'E2F Targets',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint',
#   'UV Response Dn'],
#  'MCF7_Cediranib (AZD2171)_10000.0': ['Androgen Response',
#   'Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_Danusertib (PHA-739358)_1000.0': [],
#  'MCF7_Raltitrexed_10.0': [],
#  'MCF7_G007-LK_1000.0': [],
#  'MCF7_PFI-1 (PF-6405761)_1000.0': [],
#  'MCF7_Temsirolimus (CCI-779, NSC 683864)_100.0': ['Androgen Response',
#   'Cholesterol Homeostasis',
#   'Myogenesis',
#   'mTORC1 Signaling'],
#  'MCF7_AT9283_100.0': ['Myc Targets V1'],
#  'MCF7_Pelitinib (EKB-569)_100.0': [],
#  'MCF7_TG101209_1000.0': [],
#  'MCF7_Fedratinib (SAR302503, TG101348)_10000.0': ['Estrogen Response Early',
#   'Estrogen Response Late',
#   'UV Response Dn'],
#  'MCF7_Decitabine_10000.0': [],
#  'MCF7_Baricitinib (LY3009104, INCB028050)_100.0': [],
#  'MCF7_ENMD-2076_1000.0': ['p53 Pathway'],
#  'MCF7_AR-42_100.0': ['E2F Targets', 'G2-M Checkpoint'],
#  'MCF7_Panobinostat (LBH589)_10.0': ['E2F Targets',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint'],
#  'MCF7_PFI-1 (PF-6405761)_10000.0': ['Androgen Response',
#   'Apical Surface',
#   'E2F Targets',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint',
#   'UV Response Dn'],
#  'MCF7_Barasertib (AZD1152-HQPA)_100.0': [],
#  'MCF7_AR-42_10000.0': ['Androgen Response',
#   'Cholesterol Homeostasis',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint',
#   'UV Response Dn'],
#  'MCF7_Fluorouracil (5-Fluoracil, 5-FU)_10000.0': [],
#  'MCF7_SB431542_10000.0': [],
#  'MCF7_Entacapone_1000.0': [],
#  'MCF7_Alisertib (MLN8237)_1000.0': ['p53 Pathway'],
#  'MCF7_SNS-314_10.0': ['p53 Pathway'],
#  'MCF7_Trametinib (GSK1120212)_100.0': ['Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_CYC116_10000.0': ['Estrogen Response Early'],
#  'MCF7_Bosutinib (SKI-606)_1000.0': [],
#  'MCF7_Baricitinib (LY3009104, INCB028050)_10000.0': [],
#  'MCF7_JNJ-7706621_1000.0': [],
#  'MCF7_CUDC-907_1000.0': ['Apical Surface',
#   'E2F Targets',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint',
#   'Mitotic Spindle'],
#  'MCF7_Belinostat (PXD101)_10000.0': ['Androgen Response',
#   'Cholesterol Homeostasis',
#   'E2F Targets',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint',
#   'Mitotic Spindle',
#   'TGF-beta Signaling',
#   'UV Response Dn',
#   'mTORC1 Signaling'],
#  'MCF7_Fulvestrant_10.0': ['Estrogen Response Early'],
#  'MCF7_Luminespib (AUY-922, NVP-AUY922)_100.0': ['Androgen Response',
#   'Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_GSK1070916_1000.0': [],
#  'MCF7_JNJ-26854165 (Serdemetan)_10000.0': ['Apical Surface'],
#  'MCF7_Pelitinib (EKB-569)_10000.0': ['Estrogen Response Early'],
#  'MCF7_CUDC-101_100.0': [],
#  'MCF7_Epothilone A_1000.0': ['Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_Trichostatin A (TSA)_10000.0': ['Androgen Response',
#   'Cholesterol Homeostasis',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint',
#   'TGF-beta Signaling',
#   'UV Response Dn'],
#  'MCF7_CUDC-101_10000.0': ['Estrogen Response Early'],
#  'MCF7_M344_100.0': [],
#  'MCF7_Rigosertib (ON-01910)_10000.0': [],
#  'MCF7_Fulvestrant_100.0': ['E2F Targets',
#   'Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_Obatoclax Mesylate (GX15-070)_1000.0': ['Androgen Response',
#   'Cholesterol Homeostasis',
#   'Myogenesis',
#   'mTORC1 Signaling'],
#  'MCF7_Vandetanib (ZD6474)_1000.0': [],
#  'MCF7_AT9283_1000.0': ['p53 Pathway'],
#  'MCF7_AMG-900_10000.0': [],
#  'MCF7_Azacitidine _1000.0': [],
#  'MCF7_Cediranib (AZD2171)_10.0': [],
#  'MCF7_Navitoclax (ABT-263)_10000.0': [],
#  'MCF7_Luminespib (AUY-922, NVP-AUY922)_10.0': [],
#  'MCF7_Mocetinostat (MGCD0103)_10000.0': ['Androgen Response',
#   'E2F Targets',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint',
#   'Mitotic Spindle',
#   'Myc Targets V1',
#   'UV Response Dn'],
#  'MCF7_Mercaptopurine (6-MP)_10000.0': [],
#  'MCF7_Roxadustat (FG-4592)_10000.0': ['Hypoxia', 'mTORC1 Signaling'],
#  'MCF7_Luminespib (AUY-922, NVP-AUY922)_10000.0': ['Androgen Response',
#   'Cholesterol Homeostasis',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'TGF-beta Signaling'],
#  'MCF7_PF-3845_10000.0': [],
#  'MCF7_CEP-33779_10000.0': [],
#  'MCF7_Zileuton_10000.0': [],
#  'MCF7_NVP-BSK805 2HCl_1000.0': [],
#  'MCF7_Patupilone (EPO906, Epothilone B)_1000.0': [],
#  'MCF7_Entinostat (MS-275)_100.0': [],
#  'MCF7_Fulvestrant_1000.0': ['Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_Dasatinib_100.0': [],
#  'MCF7_AG-14361_10000.0': ['Unfolded Protein Response'],
#  'MCF7_JNJ-7706621_10000.0': [],
#  'MCF7_Lapatinib (GW-572016) Ditosylate_10000.0': ['Estrogen Response Early'],
#  'MCF7_Flavopiridol HCl_10.0': ['mTORC1 Signaling'],
#  'MCF7_Rigosertib (ON-01910)_100.0': [],
#  'MCF7_Vandetanib (ZD6474)_10000.0': ['Androgen Response',
#   'Cholesterol Homeostasis',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'Pperoxisome',
#   'mTORC1 Signaling'],
#  'MCF7_Decitabine_1000.0': [],
#  'MCF7_NVP-BSK805 2HCl_10000.0': [],
#  'MCF7_Temsirolimus (CCI-779, NSC 683864)_10000.0': [],
#  'MCF7_UNC1999_10000.0': ['Androgen Response'],
#  'MCF7_Mocetinostat (MGCD0103)_10.0': ['Androgen Response',
#   'Apoptosis',
#   'Estrogen Response Early',
#   'Hypoxia',
#   'mTORC1 Signaling'],
#  'MCF7_Glesatinib?(MGCD265)_10000.0': ['Cholesterol Homeostasis'],
#  'MCF7_Pracinostat (SB939)_10.0': ['E2F Targets'],
#  'MCF7_Tozasertib (VX-680, MK-0457)_1000.0': ['p53 Pathway'],
#  'MCF7_Abexinostat (PCI-24781)_10000.0': ['Androgen Response',
#   'Apical Surface',
#   'E2F Targets',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint',
#   'Mitotic Spindle',
#   'Myc Targets V1',
#   'UV Response Dn'],
#  'MCF7_Belinostat (PXD101)_1000.0': ['Androgen Response',
#   'E2F Targets',
#   'Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_Alvespimycin (17-DMAG) HCl_100.0': ['Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_TAK-901_1000.0': ['Androgen Response',
#   'Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_Quisinostat (JNJ-26481585) 2HCl_10.0': ['Androgen Response',
#   'Apical Surface',
#   'E2F Targets',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint',
#   'TGF-beta Signaling',
#   'UV Response Dn'],
#  'MCF7_Linifanib (ABT-869)_10000.0': ['Androgen Response',
#   'Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_Fulvestrant_10000.0': ['Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_KW-2449_1000.0': ['p53 Pathway'],
#  'MCF7_Streptozotocin (STZ)_1000.0': [],
#  'MCF7_Tanespimycin (17-AAG)_10000.0': ['Androgen Response',
#   'Cholesterol Homeostasis',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'TGF-beta Signaling',
#   'UV Response Dn',
#   'mTORC1 Signaling'],
#  'MCF7_XAV-939_10000.0': [],
#  'MCF7_TG101209_10000.0': ['Androgen Response',
#   'Apical Surface',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint'],
#  'MCF7_Danusertib (PHA-739358)_10000.0': ['Estrogen Response Early'],
#  'MCF7_AR-42_1000.0': ['Androgen Response',
#   'Apical Surface',
#   'Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_AC480 (BMS-599626)_10.0': [],
#  'MCF7_AZD1480_10000.0': ['Estrogen Response Early', 'Estrogen Response Late'],
#  'MCF7_Dasatinib_10000.0': ['Androgen Response',
#   'Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_Ivosidenib (AG-120)_10.0': ['Androgen Response',
#   'Estrogen Response Early'],
#  'MCF7_Alendronate sodium trihydrate_1000.0': ['Cholesterol Homeostasis',
#   'Pperoxisome'],
#  'MCF7_Epothilone A_100.0': [],
#  'MCF7_Iniparib (BSI-201)_10000.0': ['Glycolysis',
#   'Hypoxia',
#   'mTORC1 Signaling'],
#  'MCF7_Triamcinolone Acetonide_100.0': ['Estrogen Response Early'],
#  'MCF7_Meprednisone_100.0': [],
#  'MCF7_Rucaparib (AG-014699,PF-01367338) phosphate_100.0': ['Androgen Response',
#   'Estrogen Response Early'],
#  'MCF7_Lapatinib (GW-572016) Ditosylate_1000.0': [],
#  'MCF7_GSK1070916_10000.0': ['Androgen Response',
#   'Cholesterol Homeostasis',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'UV Response Dn',
#   'mTORC1 Signaling'],
#  'MCF7_ENMD-2076_10000.0': ['Androgen Response',
#   'Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_Alisertib (MLN8237)_100.0': ['p53 Pathway'],
#  'MCF7_ENMD-2076 L-(+)-Tartaric acid _10000.0': [],
#  'MCF7_SNS-314_10000.0': ['Estrogen Response Early'],
#  'MCF7_Luminespib (AUY-922, NVP-AUY922)_1000.0': ['Androgen Response',
#   'Apoptosis',
#   'Estrogen Response Early',
#   'Estrogen Response Late'],
#  'MCF7_AC480 (BMS-599626)_10000.0': [],
#  'MCF7_Bosutinib (SKI-606)_10000.0': ['Androgen Response',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'TGF-beta Signaling',
#   'UV Response Dn'],
#  'MCF7_Quisinostat (JNJ-26481585) 2HCl_100.0': ['Androgen Response',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'UV Response Dn'],
#  'MCF7_Pirarubicin_10000.0': [],
#  'MCF7_Mocetinostat (MGCD0103)_1000.0': ['Apical Surface',
#   'E2F Targets',
#   'Estrogen Response Early'],
#  'MCF7_Rigosertib (ON-01910)_1000.0': [],
#  'MCF7_BMS-911543_10.0': ['Androgen Response', 'Estrogen Response Early'],
#  'MCF7_Patupilone (EPO906, Epothilone B)_100.0': [],
#  'MCF7_Flavopiridol HCl_100.0': ['Estrogen Response Late',
#   'PI3K/AKT/mTOR  Signaling',
#   'UV Response Dn'],
#  'MCF7_Tanespimycin (17-AAG)_1000.0': ['Estrogen Response Early'],
#  'MCF7_Roscovitine (Seliciclib,CYC202)_10000.0': [],
#  'MCF7_Hesperadin_100.0': ['E2F Targets'],
#  'MCF7_CUDC-907_10000.0': ['Androgen Response',
#   'Apical Surface',
#   'Estrogen Response Early',
#   'Estrogen Response Late',
#   'G2-M Checkpoint',
#   'Mitotic Spindle',
#   'Myc Targets V1',
#   'TGF-beta Signaling',
#   'UV Response Dn',
#   'mTORC1 Signaling'],
#  'K562_Navitoclax (ABT-263)_10.0': [],
#  'K562_UNC0631_10.0': [],
#  'K562_Bosutinib (SKI-606)_10.0': [],
#  'K562_GSK-LSD1 2HCl_10.0': [],
#  'K562_ABT-737_10000.0': [],
#  'K562_S3I-201_10.0': [],
#  'K562_CUDC-907_10.0': [],
#  'K562_Mercaptopurine (6-MP)_10000.0': [],
#  'K562_Ofloxacin_10.0': [],
#  'K562_Toremifene Citrate_10.0': [],
#  'K562_JNJ-26854165 (Serdemetan)_10000.0': [],
#  'K562_FLLL32_10000.0': [],
#  'K562_A-366_10000.0': [],
#  'K562_Belinostat (PXD101)_10000.0': [],
#  'K562_Tacedinaline (CI994)_10000.0': [],
#  'K562_Flavopiridol HCl_100.0': [],
#  'K562_ITSA-1 (ITSA1)_1000.0': [],
#  'K562_Triamcinolone Acetonide_10000.0': ['Androgen Response'],
#  'K562_GSK-LSD1 2HCl_100.0': [],
#  'K562_Nintedanib (BIBF 1120)_1000.0': [],
#  'K562_Givinostat (ITF2357)_10000.0': [],
#  'K562_Panobinostat (LBH589)_10.0': ['mTORC1 Signaling'],
#  'K562_Azacitidine _10000.0': [],
#  'K562_Dacinostat (LAQ824)_100.0': ['mTORC1 Signaling'],
#  'K562_AG-490 (Tyrphostin B42)_100.0': [],
#  'K562_PD173074_100.0': [],
#  'K562_Trametinib (GSK1120212)_10000.0': ['heme Metabolism'],
#  'K562_Busulfan _10.0': [],
#  'K562_Cyclocytidine HCl_10000.0': [],
#  'K562_(+)-JQ1_10000.0': [],
#  'K562_Costunolide_100.0': [],
#  'K562_AG-490 (Tyrphostin B42)_10.0': [],
#  'K562_Tanespimycin (17-AAG)_1000.0': [],
#  'K562_Panobinostat (LBH589)_1000.0': [],
#  'K562_NVP-BSK805 2HCl_10000.0': ['mTORC1 Signaling'],
#  'K562_(+)-JQ1_100.0': ['mTORC1 Signaling'],
#  'K562_AR-42_1000.0': ['mTORC1 Signaling'],
#  'K562_Danusertib (PHA-739358)_10000.0': ['heme Metabolism'],
#  'K562_Pracinostat (SB939)_10000.0': [],
#  'K562_CUDC-907_100.0': [],
#  'K562_GSK-LSD1 2HCl_1000.0': [],
#  'K562_Nilotinib (AMN-107)_10.0': ['Apical Junction', 'Mitotic Spindle'],
#  'K562_TG101209_10.0': [],
#  'K562_M344_1000.0': [],
#  'K562_Cyclocytidine HCl_100.0': ['Glycolysis', 'Hypoxia', 'mTORC1 Signaling'],
#  'K562_Vandetanib (ZD6474)_10000.0': [],
#  'K562_Toremifene Citrate_1000.0': [],
#  'K562_SNS-314_10000.0': ['Glycolysis', 'Hypoxia', 'mTORC1 Signaling'],
#  'K562_Quisinostat (JNJ-26481585) 2HCl_10.0': [],
#  'K562_Busulfan _100.0': [],
#  'K562_PFI-1 (PF-6405761)_1000.0': [],
#  'K562_Panobinostat (LBH589)_100.0': [],
#  'K562_Belinostat (PXD101)_1000.0': [],
#  'K562_Toremifene Citrate_100.0': [],
#  'K562_Quisinostat (JNJ-26481585) 2HCl_10000.0': ['mTORC1 Signaling'],
#  'K562_Triamcinolone Acetonide_1000.0': ['Androgen Response'],
#  'K562_Triamcinolone Acetonide_10.0': ['Androgen Response'],
#  'K562_Trametinib (GSK1120212)_100.0': ['heme Metabolism'],
#  'K562_Alendronate sodium trihydrate_10.0': [],
#  'K562_PF-573228_10000.0': [],
#  'K562_Glesatinib?(MGCD265)_10000.0': ['Mitotic Spindle', 'heme Metabolism'],
#  'K562_Nilotinib (AMN-107)_1000.0': [],
#  'K562_TAK-901_1000.0': [],
#  'K562_Cediranib (AZD2171)_100.0': [],
#  'K562_Nilotinib (AMN-107)_100.0': [],
#  'K562_Luminespib (AUY-922, NVP-AUY922)_10000.0': [],
#  'K562_GSK-LSD1 2HCl_10000.0': [],
#  'K562_Cediranib (AZD2171)_10.0': [],
#  'K562_(+)-JQ1_1000.0': ['mTORC1 Signaling'],
#  'K562_Trametinib (GSK1120212)_1000.0': ['heme Metabolism'],
#  'K562_Decitabine_10000.0': [],
#  'K562_Entinostat (MS-275)_1000.0': [],
#  'K562_Cerdulatinib (PRT062070, PRT2070)_10000.0': [],
#  'K562_Veliparib (ABT-888)_10.0': [],
#  'K562_Pracinostat (SB939)_100.0': ['mTORC1 Signaling'],
#  'K562_Hesperadin_10000.0': ['Mitotic Spindle', 'mTORC1 Signaling'],
#  'K562_Tranylcypromine (2-PCPA) HCl_10000.0': ['Epithelial Mesenchymal Transition'],
#  'K562_Enzastaurin (LY317615)_10000.0': [],
#  'K562_Givinostat (ITF2357)_1000.0': ['Androgen Response',
#   'Bile Acid Metabolism',
#   'Pperoxisome',
#   'mTORC1 Signaling'],
#  'K562_Mocetinostat (MGCD0103)_1000.0': [],
#  'K562_Alvespimycin (17-DMAG) HCl_1000.0': ['mTORC1 Signaling'],
#  'K562_Cyclocytidine HCl_1000.0': [],
#  'K562_Mercaptopurine (6-MP)_100.0': [],
#  'K562_Danusertib (PHA-739358)_1000.0': [],
#  'K562_Alvespimycin (17-DMAG) HCl_100.0': [],
#  'K562_UNC0379_10000.0': ['Hypoxia', 'mTORC1 Signaling'],
#  'K562_Triamcinolone Acetonide_100.0': ['Androgen Response'],
#  'K562_Nintedanib (BIBF 1120)_10.0': [],
#  'K562_Cediranib (AZD2171)_10000.0': [],
#  'K562_Crizotinib (PF-02341066)_10000.0': [],
#  'K562_Entinostat (MS-275)_10000.0': ['mTORC1 Signaling'],
#  'K562_Zileuton_100.0': [],
#  'K562_KW-2449_10000.0': [],
#  'K562_Alvespimycin (17-DMAG) HCl_10000.0': ['Hypoxia', 'mTORC1 Signaling'],
#  'K562_Costunolide_10.0': [],
#  'K562_Dasatinib_10000.0': [],
#  'K562_Tozasertib (VX-680, MK-0457)_10000.0': ['heme Metabolism'],
#  'K562_Dacinostat (LAQ824)_10.0': [],
#  'K562_CUDC-907_1000.0': [],
#  'K562_Abexinostat (PCI-24781)_100.0': ['Androgen Response',
#   'Bile Acid Metabolism',
#   'Pperoxisome',
#   'mTORC1 Signaling'],
#  'K562_Dasatinib_10.0': ['heme Metabolism', 'mTORC1 Signaling'],
#  'K562_Hesperadin_100.0': [],
#  'K562_INO-1001 (3-Aminobenzamide)_100.0': [],
#  'K562_Quisinostat (JNJ-26481585) 2HCl_100.0': [],
#  'K562_Raltitrexed_10.0': [],
#  'K562_Dacinostat (LAQ824)_1000.0': [],
#  'K562_Alendronate sodium trihydrate_100.0': [],
#  'K562_Regorafenib (BAY 73-4506)_10000.0': [],
#  'K562_Hesperadin_1000.0': ['Apical Junction', 'Mitotic Spindle'],
#  'K562_Tucidinostat (Chidamide)_10000.0': [],
#  'K562_Capecitabine _10.0': [],
#  'K562_Tanespimycin (17-AAG)_10000.0': ['Mitotic Spindle', 'mTORC1 Signaling'],
#  'K562_CUDC-101_1000.0': [],
#  'K562_Nilotinib (AMN-107)_10000.0': ['Hypoxia',
#   'Mitotic Spindle',
#   'heme Metabolism',
#   'mTORC1 Signaling'],
#  'K562_Sorafenib Tosylate_10000.0': ['mTORC1 Signaling'],
#  'K562_Raltitrexed_1000.0': ['E2F Targets'],
#  'K562_Trametinib (GSK1120212)_10.0': ['heme Metabolism'],
#  'K562_Bosutinib (SKI-606)_1000.0': [],
#  'K562_AR-42_10000.0': [],
#  'K562_Crizotinib (PF-02341066)_1000.0': ['Allograft Rejection',
#   'PI3K/AKT/mTOR  Signaling'],
#  'K562_Raltitrexed_100.0': ['E2F Targets'],
#  'K562_Abexinostat (PCI-24781)_1000.0': [],
#  'K562_Luminespib (AUY-922, NVP-AUY922)_100.0': ['Allograft Rejection',
#   'Mitotic Spindle'],
#  'K562_AT9283_1000.0': ['Allograft Rejection', 'PI3K/AKT/mTOR  Signaling'],
#  'K562_Ki8751_10000.0': ['Apical Junction', 'Mitotic Spindle'],
#  'K562_Resminostat_10000.0': ['mTORC1 Signaling'],
#  'K562_JNJ-7706621_10000.0': [],
#  'K562_PD173074_10.0': [],
#  'K562_Dasatinib_1000.0': ['heme Metabolism'],
#  'K562_Quisinostat (JNJ-26481585) 2HCl_1000.0': ['Notch Signaling',
#   'heme Metabolism'],
#  'K562_Toremifene Citrate_10000.0': [],
#  'K562_Abexinostat (PCI-24781)_10000.0': [],
#  'K562_Bosutinib (SKI-606)_100.0': [],
#  'K562_Meprednisone_10.0': [],
#  'K562_TAK-901_10000.0': [],
#  'K562_PFI-1 (PF-6405761)_10000.0': [],
#  'K562_Rigosertib (ON-01910)_1000.0': [],
#  'K562_Trichostatin A (TSA)_10000.0': [],
#  'K562_Pelitinib (EKB-569)_10000.0': ['Allograft Rejection',
#   'PI3K/AKT/mTOR  Signaling'],
#  'K562_Pracinostat (SB939)_1000.0': [],
#  'K562_MK-5108 (VX-689)_10000.0': [],
#  'K562_Fedratinib (SAR302503, TG101348)_10000.0': ['Glycolysis',
#   'Hypoxia',
#   'mTORC1 Signaling'],
#  'K562_Alisertib (MLN8237)_10000.0': [],
#  'K562_Nintedanib (BIBF 1120)_10000.0': [],
#  'K562_Belinostat (PXD101)_100.0': [],
#  'K562_Capecitabine _100.0': [],
#  'K562_GSK1070916_10000.0': [],
#  'K562_ENMD-2076 L-(+)-Tartaric acid _10000.0': [],
#  'K562_ENMD-2076_10000.0': ['Hypoxia', 'mTORC1 Signaling'],
#  'K562_Luminespib (AUY-922, NVP-AUY922)_1000.0': [],
#  'K562_Obatoclax Mesylate (GX15-070)_10000.0': [],
#  'K562_CUDC-101_10000.0': [],
#  'K562_AR-42_100.0': ['Androgen Response',
#   'Bile Acid Metabolism',
#   'Pperoxisome',
#   'mTORC1 Signaling'],
#  'K562_Dasatinib_100.0': [],
#  'K562_PHA-680632_10000.0': [],
#  'K562_Dacinostat (LAQ824)_10000.0': [],
#  'K562_Mocetinostat (MGCD0103)_100.0': ['Interferon Alpha Response'],
#  'K562_M344_10000.0': [],
#  'K562_TG101209_10000.0': [],
#  'K562_Raltitrexed_10000.0': [],
#  'K562_Panobinostat (LBH589)_10000.0': ['Notch Signaling'],
#  'K562_AT9283_10000.0': [],
#  'K562_Mocetinostat (MGCD0103)_10000.0': []}

# %%
with open("./drug_pathway_enrichment.pkl", 'wb') as f:
    pkl.dump(results_summary, f)
