# %%
import anndata as ad
import scanpy as sc
import pandas as pd
import pertpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 4
#       2 import scanpy as sc
#       3 import pandas as pd
# ----> 4 import pertpy
#
# File /apps/miniconda3/envs/dege-fm/lib/python3.12/site-packages/pertpy/__init__.py:21
#      19 from . import plot as pl
#      20 from . import preprocessing as pp
# ---> 21 from . import tools as tl
#
# File /apps/miniconda3/envs/dege-fm/lib/python3.12/site-packages/pertpy/tools/__init__.py:42
#      32 from pertpy.tools._perturbation_space._discriminator_classifiers import (
#      33     LRClassifierSpace,
#      34     MLPClassifierSpace,
#      35 )
#      36 from pertpy.tools._perturbation_space._simple import (
#      37     CentroidSpace,
#      38     DBSCANSpace,
#      39     KMeansSpace,
#      40     PseudobulkSpace,
#      41 )
# ---> 42 from pertpy.tools._scgen import Scgen
# ...

# %%
adata_raw = pertpy.data.sciplex3_raw()
